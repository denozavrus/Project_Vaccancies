# %% [markdown]
# ## Предобработка данных

# %%
import pandas as pd
import os
import re
pd.set_option('display.max_rows', 500)
import scipy
from scipy.stats import skew
from scipy.stats import kurtosis
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../../data/final_data.csv')

# %%
df['salary_from'] = df['salary_from'].fillna(0)
df['salary_to'] = df['salary_to'].fillna(0)
df['salary'] = df.loc[:,'salary_from'] + df.loc[:,'salary_to']
df.loc[(df.salary_from != 0) & (df.salary_to != 0), 'salary'] = df.salary / 2

# %%
df.loc[df.gross == False, 'salary'] = df.salary * 0.87

# %%
df.dropna(axis = 0, subset = ['currency', 'gross'], inplace = True)

# %%
df.drop(['raw', 'schedule', 'employer', 'salary_from', 'salary_to', 'gross'], axis = 1, inplace = True)

# %%
df.drop('employment', axis = 1, inplace = True)

# %%
df.shape
# Out:
# (30639, 11)

# %%
df.isna().sum()
# Out:
# premium                         0
# name                            0
# response_letter_required        0
# city                        10502
# latitude                    10367
# longtitude                  10367
# experience                      0
# skills                       5989
# has_test                        0
# currency                        0
# salary                          0
# dtype: int64

# %%
df = df.loc[~(df.salary == 0)]
df = df.loc[~(df.latitude == 0)]
df = df.loc[~(df.longtitude == 0)]
df.loc[(df.salary < 1000) & (df.currency == 'RUR'), 'salary'] = df.loc[(df.salary < 1000) & (df.currency == 'RUR'), 'salary'] * 1000
df.loc[df.currency == 'USD', 'salary'] = df.salary * 60
df.loc[df.currency == 'EUR', 'salary'] = df.salary * 66
df.loc[df.currency.isin(['EUR', 'USD']), 'currency'] = 'RUR'

# %%
df.dropna(axis = 0, subset = ['latitude', 'longtitude'], inplace = True)

# %%
df.shape
# Out:
# (20144, 11)

# %%
import pickle 
import matplotlib.path as mplPath

# %%
mapper = {
"Алтайский край":"Южно-Сибирский",
"Республика Алтай":"Южно-Сибирский",
"Курская область":"Центрально-Чернозёмный",
"Тульская область":"Центральный",
"Пермский край":"Волго-Камский",
"Тверская область":"Центральный",
"Липецкая область":"Центрально-Чернозёмный",
"Орловская область":"Центральный",
"Самарская область":"Волго-Уральский",
"Кировская область":"Волго-Камский",
"Брянская область":"Центральный",
"Московская область":"Центральный",
"Смоленская область":"Центральный",
"Рязанская область":"Центральный",
"Калужская область":"Центральный",
"Тамбовская область":"Центрально-Чернозёмный",
"Ростовская область":"Южный",
"Республика Марий Эл":"Волго-Камский",
"Курганская область":"Уральско-Сибирский",
"Мурманская область":"Северно-Западный",
"Республика агестан":"Северно-Кавказский",
"Республика Карелия":"Северно-Западный",
"Ивановская область":"Центральный",
"Кемеровская область":"Южно-Сибирский",
"Вологодская область":"Северно-Западный",
"Магаданская область":"Дальневосточный",
"Республика Татарстан":"Волго-Камский",
"Воронежская область":"Центрально-Чернозёмный",
"Белгородская область":"Центрально-Чернозёмный",
"Ярославская область":"Центральный",
"Ульяновская область":"Волго-Уральский",
"Владимирская область":"Центральный",
"Новосибирская область":"Южно-Сибирский",
"Ленинградская область":"Северно-Западный",
"Астраханская область":"Южный",
"Удмуртская Республика":"Волго-Камский",
"Архангельская область":"Северный",
"Чувашская Республика":"Волго-Камский",
"Республика Калмыкия":"Южный",
"Республика Башкортостан":"Волго-Уральский",
"Республика Саха (Якутия)":"Дальневосточный",
"Кабардино-Балкарская Республика":"Северно-Кавказский",
"Республика Северная Осетия-Алания":"Северно-Кавказский",
"Республика Тыва":"Ангаро-Енисейский",
"Карачаево-Черкесская Республика":"Северно-Кавказский",
"Еврейская автономная область":"Дальневосточный",
"Томская область":"Южно-Сибирский",
"Амурская область":"Дальневосточный",
"Пензенская область":"Волго-Уральский",
"Республика Бурятия":"Дальневосточный",
"Республика Хакасия":"Ангаро-Енисейский",
"Республика Мордовия":"Волго-Камский",
"Саратовская область":"Волго-Уральский",
"Костромская область":"Центральный",
"Республика Ингушетия":"Северно-Кавказский",
"Чеченская Республика":"Северно-Кавказский",
"Калининградская область":"Северно-Западный",
"Псковская область":"Северно-Западный",
"Республика Коми":"Северный",
"Оренбургская область":"Волго-Уральский",
"Новгородская область":"Северно-Западный",
"Челябинская область":"Уральско-Сибирский",
"Ставропольский край":"Северно-Кавказский",
"Свердловская область":"Уральско-Сибирский",
"Волгоградская область":"Южный",
"Республика Адыгея":"Южный",
"Ханты-Мансийский автономный округ":"Уральско-Сибирский",
"Тюменская область":"Уральско-Сибирский",
"Омская область":"Южно-Сибирский",
"Приморский край":"Дальневосточный",
"Хабаровский край":"Дальневосточный",
"Сахалинская область":"Дальневосточный",
"Чукотский автономный округ":"Дальневосточный",
"Красноярский край":"Ангаро-Енисейский",
"Иркутская область":"Ангаро-Енисейский",
"Забайкальский край":"Дальневосточный",
"Камчатский край":"Дальневосточный",
"Ненецкий автономный округ":"Северный",
"Ямало-Ненецкий автономный округ":"Уральско-Сибирский",
"Республика Дагестан":"Северно-Кавказский",
"Краснодарский край":"Южный",
"Нижегородская область":"Волго-Камский",
"Неизвестно" : "Неизвестно" }

# %%
def convert_to_region(lat, long):
    coord = np.array([lat, long])
    for reg, area in loaded_dict.items():
        if area.contains_point(coord):
            return reg
    
    return 'Неизвестно'

with open('../../data/saved_dictionary.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)
    
l = []
for v in loaded_dict.values():
    l.append(mplPath.Path(np.array(v['0'])))
    
loaded_dict = dict(zip(list(loaded_dict.keys()), l))
df.loc[:, 'Region'] = df.apply(lambda x: convert_to_region(x.latitude, x.longtitude), axis = 1)

df.loc[:, 'Region'] = df.loc[:, "Region"].map(mapper)

# %%
df.loc[(df["city"].isin(["посёлок Русский","Владивосток","Артёмовский городской округ",
                        "посёлок городского типа Забайкальск","поселок городского типа Забайкальск",
                        "городской округ Владивостокский"])) & (df["Region"] == 'Неизвестно'), "Region"] = "Дальневосточный"
df.loc[(df["city"].isin(["посёлок городского типа Кореиз","село Скворцово","посёлок Розовый",
                        "село Дубки","Керчь","посёлок Волна","Анапа","Евпатория",
                        "Симферополь", "Ялта", "Севастополь", "Таганрог", 
                        "посёлок городского типа Сириус", "Новороссийск","Дербент",
                        "село Яблочное","посёлок городского типа Гвардейское","село Белоглинка",
                        "Избербаш","Махачкала","Республика Крым","посёлок городского типа Красногвардейское",
                        "Сочи","село Фонтаны",])) & (df["Region"] == 'Неизвестно'), "Region"] = "Северно-Кавказский"
df.loc[(df["city"].isin(["Архангельск","Полярный"])) & (df["Region"] == 'Неизвестно'), "Region"] = "Северный"
df.loc[(df["city"].isin(["Санкт-Петербург","Ломоносов","Сосновый Бор"]) & (df["Region"] == 'Неизвестно')) , "Region"] = "Северно-Западный"
df.loc[(df["city"].isin(["посёлок Новый"])) & (df["Region"] == 'Неизвестно'), "Region"] = "Уральский"

df.loc[:, "Region"] = df['Region'].str.replace('^Уральский$','Северный и Уральский')
df.loc[:, "Region"] = df['Region'].str.replace('^Северный$','Северный и Уральский')

# %%
skills = [i.split('_') for i in df.skills.astype(str)]

# %%
skills = pd.Series([item for sublist in skills for item in sublist]).value_counts()

# %%
df.skills = df.skills.astype(str)

# %%
for v in skills[1:54].index: 
    df.loc[:, v] = df.skills.str.contains(re.compile('(^|_)' + re.escape(v) + '(_|$)')).astype(int)

# %%
df.drop(['city', 'skills', 'premium', 'currency'], axis = 1, inplace = True)

# %%
df.Region.value_counts()
# Out:
# Центральный               5918
# Северно-Западный          2897
# Волго-Камский             2263
# Уральско-Сибирский        1820
# Южно-Сибирский            1769
# Волго-Уральский           1416
# Южный                     1346
# Центрально-Чернозёмный     776
# Ангаро-Енисейский          715
# Дальневосточный            699
# Северно-Кавказский         401
# Северный и Уральский        93
# Неизвестно                  31
# Name: Region, dtype: int64

# %%
df.isna().sum()
# Out:
# name                                       0
# response_letter_required                   0
# latitude                                   0
# longtitude                                 0
# experience                                 0
# has_test                                   0
# salary                                     0
# Region                                     0
# Работа в команде                           0
# Пользователь ПК                            0
# Грамотная речь                             0
# Техническое обслуживание                   0
# 1С программирование                        0
# Linux                                      0
# 1С: Предприятие 8                          0
# Работа в условиях многозадачности          0
# SQL                                        0
# Работа с большим объемом информации        0
# Adobe Photoshop                            0
# Настройка ПК                               0
# Грамотность                                0
# Управление проектами                       0
# Git                                        0
# Умение работать в команде                  0
# Настройка сетевых подключений              0
# Организаторские навыки                     0
# Английский язык                            0
# Деловое общение                            0
# Настройка ПО                               0
# Деловая переписка                          0
# Ремонтные работы                           0
# Аналитическое мышление                     0
# JavaScript                                 0
# Ведение переговоров                        0
# Windows 7                                  0
# MS PowerPoint                              0
# Информационные технологии                  0
# Ремонт ПК                                  0
# Техническая поддержка                      0
# HTML                                       0
# Точность и внимательность к деталям        0
# PHP                                        0
# Администрирование сетевого оборудования    0
# MySQL                                      0
# 1С: Документооборот                        0
# Adobe Illustrator                          0
# CorelDRAW                                  0
# Чтение чертежей                            0
# Python                                     0
# Креативность                               0
# Поиск информации в интернет                0
# TCP/IP                                     0
# Монтаж оборудования                        0
# Станки ЧПУ                                 0
# 1С: Управление Торговлей                   0
# 1С: Зарплата и управление персоналом       0
# CSS                                        0
# ООП                                        0
# Деловая коммуникация                       0
# Информационная безопасность                0
# PostgreSQL                                 0
# dtype: int64

# %%
df.to_csv('../../data/final_data_salary.csv', index = False)

# %% [markdown]
# ## Анализ целевой переменной. Поиск выбросов

# %%
df = pd.read_csv('../../data/final_data_salary.csv')

# %%
df.salary.std()
# Out:
# 44979.8379115297

# %%
df.salary.mean()
# Out:
# 68776.57347001591

# %%
df[(df.salary < df.salary.mean() - 3 * df.salary.std()) | (df.salary > df.salary.mean() + 3 * df.salary.std())].head()
# Out:
#                                                   name  \
# 93                       Программист 1C (производство)
# 154  Технический директор в Zapomni (software devel...
# 213                          Blockchain System Analyst
# 217  Руководитель завода электродвигателей, город С...
# 298  Python-разработчик в Цифровые поверхности Салю...
#
#      response_letter_required   latitude  longtitude          experience  \
# 93                      False  55.807800   37.638737  От 1 года до 3 лет
# 154                      True  55.753534   37.611679       От 3 до 6 лет
# 213                     False  23.608705   53.434111  От 1 года до 3 лет
# 217                     False  55.678747   37.511131         Более 6 лет
# 298                     False  55.741338   37.531127       От 3 до 6 лет
#
#      has_test    salary       Region  Работа в команде  Пользователь ПК  ...  \
# 93      False  217500.0  Центральный                 0                0  ...
# 154     False  304500.0  Центральный                 0                0  ...
# 213     False  208800.0   Неизвестно                 0                0  ...
# 217     False  300000.0  Центральный                 0                0  ...
# 298     False  300000.0  Центральный                 0                0  ...
#
#      TCP/IP  Монтаж оборудования  Станки ЧПУ  1С: Управление Торговлей  \
# 93        0                    0           0                         0
# 154       0                    0           0                         0
# 213       0                    0           0                         0
# 217       0                    0           0                         0
# 298       0                    0           0                         0
#
#      1С: Зарплата и управление персоналом  CSS  ООП  Деловая коммуникация  \
# 93                                      0    0    0                     0
# 154                                     0    0    0                     0
# 213                                     0    0    0                     0
# 217                                     0    0    0                     0
# 298                                     0    0    0                     0
#
#      Информационная безопасность  PostgreSQL
# 93                             0           0
# 154                            0           0
# 213                            0           0
# 217                            0           0
# 298                            0           1
#
# [5 rows x 61 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.salary, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Зарплата')
ax.set_title('Распределение зарплаты')

mean = np.mean(df.salary)
std = np.std(df.salary)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

plt.annotate('Потенциальные выбросы', xy=(320000, 0.0000001), xytext=(435000, 0.00001),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('', xy=(520000, 0.0000001), xytext=(430000, 0.00001),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

ax.grid()
plt.show()

# %% [markdown]
# ## Анализ количественных признаков

# %%
df_numeric = df.loc[:, ['latitude', 'longtitude', 'salary']]

# %%
df_numeric.describe()
# Out:
#            latitude    longtitude         salary
# count  20144.000000  20144.000000   20144.000000
# mean      55.031173     50.673507   68776.573470
# std        4.115035     23.116306   44979.837912
# min       23.608705   -117.780920    8700.000000
# 25%       54.197104     37.544997   40000.000000
# 50%       55.749451     39.807944   55000.000000
# 75%       56.837641     57.498475   82500.000000
# max       69.496790    158.679625  522000.000000

# %%
stats = []

for (i, col) in enumerate(df_numeric.columns):
    val = df_numeric[col]
    
    stats.append ([col, val.mean(), val.median(), val.min(), val.max(), val.std(), 
                     scipy.stats.skew(val, axis=0, bias=True), 
                     kurtosis(val, axis=0, bias=True), 
                     val.quantile(0.05), val.quantile(0.95), 
                     val.quantile(0.75) - val.quantile(0.25),
                     0])

# %%
stats = pd.DataFrame(stats, columns=['Переменная', 'Среднее', 'Медиана', 'Минимум', 'Максимум', 
                                     'Ст. Отклонение', 'Асимметрия', 'Эксцесс', 
                                     '5% Проц', '95% Проц', 'Интерквартильный размах', 'Пропущенные наблюдения'])

# %%
stats
# Out:
#    Переменная       Среднее       Медиана      Минимум       Максимум  \
# 0    latitude     55.031173     55.749451    23.608705      69.496790
# 1  longtitude     50.673507     39.807944  -117.780920     158.679625
# 2      salary  68776.573470  55000.000000  8700.000000  522000.000000
#
#    Ст. Отклонение  Асимметрия   Эксцесс       5% Проц       95% Проц  \
# 0        4.115035   -0.999113  2.253621     45.049750      59.971695
# 1       23.116306    1.800073  3.544598     30.307736      92.981642
# 2    44979.837912    2.418418  8.885286  26100.000000  156600.000000
#
#    Интерквартильный размах  Пропущенные наблюдения
# 0                 2.640537                       0
# 1                19.953478                       0
# 2             42500.000000                       0

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.hist(df.latitude, weights = np.ones_like(df.latitude) / len(df.latitude), bins = len(np.histogram_bin_edges(df.latitude, bins='sturges')) - 1) 
plt.ylabel('Относительная частота')
plt.xlabel('Широта')
ax.set_title('Распределение широты. Стерджес')

plt.annotate('Выбросы', xy=(33, 0.01), xytext=(28, 0.085),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('Ассиметрия влево', xy=(52, 0.2), xytext=(48, 0.35),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

ax.xaxis.set_ticks(np.arange(0, 80, 5))
ax.yaxis.set_ticks(np.arange(0, 0.5, 0.05))

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.hist(df.longtitude, weights = np.ones_like(df.longtitude) / len(df.longtitude), 
         bins = len(np.histogram_bin_edges(df.longtitude, bins='sturges')) - 1) 
plt.ylabel('Относительная частота')
plt.xlabel('Долгота')
ax.set_title('Распределение долготы. Стерджес')

plt.annotate('Выбросы', xy=(-110, 0.001), xytext=(-90, 0.08),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('Ассиметрия вправо', xy=(55, 0.20), xytext=(150, 0.32),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')


ax.yaxis.set_ticks(np.arange(0, 0.5, 0.05))

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.salary, weights = np.ones_like(df.salary) / len(df.salary), 
         bins = len(np.histogram_bin_edges(df.salary, bins='sturges')) - 1)

plt.ylabel('Относительная частота')
plt.xlabel('Зарплата')
ax.set_title('Распределение зарплаты. Стерджес')

plt.annotate('Выбросы', xy=(320000, 0.01), xytext=(435000, 0.32),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('', xy=(520000, 0.01), xytext=(430000, 0.315),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

ax.xaxis.set_ticks(np.arange(0, 550000, 50000))
ax.yaxis.set_ticks(np.arange(0, 0.55, 0.05))

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.salary, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Зарплата')
ax.set_title('Распределение зарплаты')

mean = np.mean(df.salary)
std = np.std(df.salary)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.latitude, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Широта')
ax.set_title('Распределение широты')

mean = np.mean(df.latitude)
std = np.std(df.latitude)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.longtitude, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Долгота')
ax.set_title('Распределение долготы')

mean = np.mean(df.longtitude)
std = np.std(df.longtitude)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

ax.grid()
plt.show()

# %% [markdown]
# ## Анализ качественных признаков

# %% [markdown]
# ## Города

# %% [markdown]
# В большом количестве(10 тысяч) вакансий город не указан. Такие значения мы заполним категорией "Неизвестно". Города, которые попадаются меньше трех раз мы объеденим в одну категорию "Другие", т.к. в таком случае эта категория получается не такой большой по сравнению с другими категориями.

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

le = preprocessing.LabelEncoder()
encoded = pd.Series(le.fit_transform(df.Region))

df1 = encoded.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent', kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Регион', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = le.transform(le.classes_).astype(str)
labels = le.classes_

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['Region'].unique(),
                           pd.value_counts(df['Region'], sort=False),
                           np.around(pd.value_counts(df['Region'], sort=False) / len(df['Region']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['Region'], sort=False) / len(df['Region']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#                     Регион  Количество вакансий  Процент  Накопленный процент
# 0            Волго-Камский                 2263     11.2                 11.2
# 1                    Южный                 1346      6.7                 17.9
# 2           Южно-Сибирский                 1769      8.8                 26.7
# 3              Центральный                 5918     29.4                 56.1
# 4          Дальневосточный                  699      3.5                 59.5
# 5        Ангаро-Енисейский                  715      3.5                 63.1
# 6       Уральско-Сибирский                 1820      9.0                 72.1
# 7         Северно-Западный                 2897     14.4                 86.5
# 8          Волго-Уральский                 1416      7.0                 93.5
# 9       Северно-Кавказский                  401      2.0                 95.5
# 10  Центрально-Чернозёмный                  776      3.9                 99.4
# 11    Северный и Уральский                   93      0.5                 99.8
# 12              Неизвестно                   31      0.2                100.0

# %% [markdown]
# ## Сопроводительное письмо

# %% [markdown]
# Данная переменная очень сильно не сбалансирована и вакансии, для которых сопроводительное письмо обязательно для ~1% вакансий.

# %%
df.response_letter_required.value_counts()
# Out:
# False    19914
# True       230
# Name: response_letter_required, dtype: int64

# %%
df.response_letter_required = df.response_letter_required.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
from matplotlib.pyplot import figure

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.response_letter_required.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость сопроводительного письма', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()}) 
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['response_letter_required'].unique(),
                           pd.value_counts(df['response_letter_required'], sort=False),
                           np.around(pd.value_counts(df['response_letter_required'], sort=False) / len(df['response_letter_required']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['response_letter_required'], sort=False) / len(df['response_letter_required']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#    Регион  Количество вакансий  Процент  Накопленный процент
# 0       0                19914     98.9                 98.9
# 1       1                  230      1.1                100.0

# %% [markdown]
# ## Тест

# %% [markdown]
# Лишь около 1% вакансий требуют прохождение тестового задания для отклика на вакансию, эта переменная очень не сбалансирована

# %%
df.has_test.value_counts()
# Out:
# False    19983
# True       161
# Name: has_test, dtype: int64

# %%
df.has_test = df.has_test.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.has_test.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость прохождения тестового задания', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['has_test'].unique(),
                           pd.value_counts(df['has_test'], sort=False),
                           np.around(pd.value_counts(df['has_test'], sort=False) / len(df['has_test']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['has_test'], sort=False) / len(df['has_test']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#    Регион  Количество вакансий  Процент  Накопленный процент
# 0       0                19983     99.2                 99.2
# 1       1                  161      0.8                100.0

# %% [markdown]
# ## Опыт работы

# %% [markdown]
# Требования к опыту работы несбалансированы

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

le = preprocessing.LabelEncoder()
encoded = pd.Series(le.fit_transform(df.experience))
    
df1 = encoded.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Опыт работы', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = le.transform(le.classes_).astype(str)
labels = le.classes_

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['experience'].unique(),
                           pd.value_counts(df['experience'], sort=False),
                           np.around(pd.value_counts(df['experience'], sort=False) / len(df['experience']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['experience'], sort=False) / len(df['experience']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#                Регион  Количество вакансий  Процент  Накопленный процент
# 0           Нет опыта                 2803     13.9                 13.9
# 1  От 1 года до 3 лет                11810     58.6                 72.5
# 2       От 3 до 6 лет                 5116     25.4                 97.9
# 3         Более 6 лет                  415      2.1                100.0

# %% [markdown]
# ## Навыки

# %%
one_c = df.loc[:, df.columns.str.contains('1С')].sum(axis=1).apply(lambda x: min([x, 1]))

# %%
df.drop(df.columns[df.columns.str.contains('1С')], axis = 1, inplace = True)
df.loc[:, '1С'] = one_c

# %%
skills_count = df.iloc[:, 8:].sum(axis = 0)

# %%
skills_count = skills_count.sort_values(ascending=False)

skills_per = skills_count / skills_count.values.sum()

# %%
skills_df = pd.DataFrame({'ind': range(skills_per.shape[0]), 'skills': skills_per.index, 'percent': skills_per.values})

# %%
skills_df
# Out:
#     ind                                   skills   percent
# 0     0                         Работа в команде  0.085082
# 1     1                          Пользователь ПК  0.069482
# 2     2                                       1С  0.047679
# 3     3                           Грамотная речь  0.044546
# 4     4                 Техническое обслуживание  0.032642
# 5     5                                    Linux  0.027661
# 6     6        Работа в условиях многозадачности  0.027285
# 7     7                                      SQL  0.024247
# 8     8      Работа с большим объемом информации  0.024090
# 9     9                          Adobe Photoshop  0.023933
# 10   10                             Настройка ПК  0.023557
# 11   11                              Грамотность  0.022461
# 12   12                     Управление проектами  0.022461
# 13   13                                      Git  0.022430
# 14   14                Умение работать в команде  0.021740
# 15   15            Настройка сетевых подключений  0.020487
# 16   16                   Организаторские навыки  0.019986
# 17   17                          Английский язык  0.019516
# 18   18                          Деловое общение  0.019328
# 19   19                             Настройка ПО  0.018702
# 20   20                        Деловая переписка  0.017449
# 21   21                         Ремонтные работы  0.016540
# 22   22                   Аналитическое мышление  0.015632
# 23   23                               JavaScript  0.015601
# 24   24                      Ведение переговоров  0.015569
# 25   25                                Windows 7  0.014817
# 26   26                            MS PowerPoint  0.014755
# 27   27                Информационные технологии  0.014128
# 28   28                                Ремонт ПК  0.014003
# 29   29                    Техническая поддержка  0.013878
# 30   30                                     HTML  0.013846
# 31   31      Точность и внимательность к деталям  0.013470
# 32   32                                      PHP  0.013345
# 33   33  Администрирование сетевого оборудования  0.013314
# 34   34                                    MySQL  0.012812
# 35   35                        Adobe Illustrator  0.012625
# 36   36                                CorelDRAW  0.012625
# 37   37                          Чтение чертежей  0.012374
# 38   38                                   Python  0.012123
# 39   39              Поиск информации в интернет  0.012061
# 40   40                             Креативность  0.012061
# 41   41                                   TCP/IP  0.011904
# 42   42                      Монтаж оборудования  0.011716
# 43   43                               Станки ЧПУ  0.011685
# 44   44                                      CSS  0.011121
# 45   45                                      ООП  0.010996
# 46   46                     Деловая коммуникация  0.010870
# 47   47              Информационная безопасность  0.010745
# 48   48                               PostgreSQL  0.010620

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

g = sns.catplot(data = skills_df, x = 'ind', y = 'percent', kind='bar', palette='muted')

g.ax.set_xlabel('Навык', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

handltext = skills_df.ind.astype(str).values
labels = skills_df.skills.values

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()}, loc='upper right')

g.fig.set_figwidth(20)
g.fig.set_figheight(15)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           skills_count.index.unique(),
                           skills_count.values,
                           (skills_per * 100).round(2),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(skills_per * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#                                      Регион  Количество вакансий  Процент  \
# 0                          Работа в команде                 2716     8.51
# 1                           Пользователь ПК                 2218     6.95
# 2                                        1С                 1522     4.77
# 3                            Грамотная речь                 1422     4.45
# 4                  Техническое обслуживание                 1042     3.26
# 5                                     Linux                  883     2.77
# 6         Работа в условиях многозадачности                  871     2.73
# 7                                       SQL                  774     2.42
# 8       Работа с большим объемом информации                  769     2.41
# 9                           Adobe Photoshop                  764     2.39
# 10                             Настройка ПК                  752     2.36
# 11                              Грамотность                  717     2.25
# 12                     Управление проектами                  717     2.25
# 13                                      Git                  716     2.24
# 14                Умение работать в команде                  694     2.17
# 15            Настройка сетевых подключений                  654     2.05
# 16                   Организаторские навыки                  638     2.00
# 17                          Английский язык                  623     1.95
# 18                          Деловое общение                  617     1.93
# 19                             Настройка ПО                  597     1.87
# 20                        Деловая переписка                  557     1.74
# 21                         Ремонтные работы                  528     1.65
# 22                   Аналитическое мышление                  499     1.56
# 23                               JavaScript                  498     1.56
# 24                      Ведение переговоров                  497     1.56
# 25                                Windows 7                  473     1.48
# 26                            MS PowerPoint                  471     1.48
# 27                Информационные технологии                  451     1.41
# 28                                Ремонт ПК                  447     1.40
# 29                    Техническая поддержка                  443     1.39
# 30                                     HTML                  442     1.38
# 31      Точность и внимательность к деталям                  430     1.35
# 32                                      PHP                  426     1.33
# 33  Администрирование сетевого оборудования                  425     1.33
# 34                                    MySQL                  409     1.28
# 35                        Adobe Illustrator                  403     1.26
# 36                                CorelDRAW                  403     1.26
# 37                          Чтение чертежей                  395     1.24
# 38                                   Python                  387     1.21
# 39              Поиск информации в интернет                  385     1.21
# 40                             Креативность                  385     1.21
# 41                                   TCP/IP                  380     1.19
# 42                      Монтаж оборудования                  374     1.17
# 43                               Станки ЧПУ                  373     1.17
# 44                                      CSS                  355     1.11
# 45                                      ООП                  351     1.10
# 46                     Деловая коммуникация                  347     1.09
# 47              Информационная безопасность                  343     1.07
# 48                               PostgreSQL                  339     1.06
#
#     Накопленный процент
# 0                   8.5
# 1                  15.5
# 2                  20.2
# 3                  24.7
# 4                  27.9
# 5                  30.7
# 6                  33.4
# 7                  35.9
# 8                  38.3
# 9                  40.7
# 10                 43.0
# 11                 45.3
# 12                 47.5
# 13                 49.8
# 14                 51.9
# 15                 54.0
# 16                 56.0
# 17                 57.9
# 18                 59.9
# 19                 61.7
# 20                 63.5
# 21                 65.1
# 22                 66.7
# 23                 68.3
# 24                 69.8
# 25                 71.3
# 26                 72.8
# 27                 74.2
# 28                 75.6
# 29                 77.0
# 30                 78.4
# 31                 79.7
# 32                 81.0
# 33                 82.4
# 34                 83.6
# 35                 84.9
# 36                 86.2
# 37                 87.4
# 38                 88.6
# 39                 89.8
# 40                 91.0
# 41                 92.2
# 42                 93.4
# 43                 94.6
# 44                 95.7
# 45                 96.8
# 46                 97.9
# 47                 98.9
# 48                100.0

# %%
df.to_csv('../../data/final_data_models.csv', index = False)

# %% [markdown]
# ## Гипотезы

# %%
df = pd.read_csv('../../data/final_data_models.csv')

# %% [markdown]
# 1-я Гипотеза: Средняя зарплата на вакансиях с требованием знания английского выше, чем без такого требования
# Для проверки этой гипотезы построим диаграмму Бокса-Вискера для категории английский язык

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 15, 10

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
from matplotlib.pyplot import figure

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


g = sns.boxplot(x='Английский язык', y='salary',data=df, palette='muted')

g.set_xlabel('Требования английского языка', fontsize = 15)
g.set_ylabel('Зарплата', fontsize = 15)

handltext = ['0', '1']
labels = [ "Необязателен", "Обязателен"]

t = g.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.patches)]

g.legend(handles, labels, handler_map={tuple : TextHandler()})
g.set_yticks(np.arange(0, 600000, 50000))

plt.show()

# %% [markdown]
# Мы видим, что и медиана, и 75 квартиль для вакансий с требованием английского языка выше вакансий без такого требования. Проверим равенство медиан с помощью критерия Манна-Уитни.

# %%
_, p = scipy.stats.mannwhitneyu(df[df['Английский язык'] == 1].salary, df[df['Английский язык'] == 0].salary)
print('p-value= ', p)
if p < 0.05: 
    print('Отвергаем гипотезу о равенстве медиан')
else: 
    print('Нет оснований отвергнуть гипотезу о равенстве медиан')
# Out:
# p-value=  1.612993629262742e-57
# Отвергаем гипотезу о равенстве медиан

# %% [markdown]
# 2-я Гипотеза: При росте опыта работы зарплата разработчиков с навыками JavaScript растет быстрее чем для разработчиков с навыками 1С

# %%
one_s = (df[df['1С'] == 1].groupby('experience')['salary'].mean().sort_values().pct_change() * 100)[1:]

# %%
js = (df[df['JavaScript'] == 1].groupby('experience')['salary'].mean().sort_values().pct_change() * 100)[1:]

# %%
df_plot = pd.concat([one_s, js], axis = 0).reset_index()

# %%
df_plot
# Out:
#            experience     salary
# 0  От 1 года до 3 лет  50.510920
# 1       От 3 до 6 лет  40.996543
# 2         Более 6 лет  18.412548
# 3  От 1 года до 3 лет  38.277091
# 4       От 3 до 6 лет  76.609596
# 5         Более 6 лет  44.605466

# %%
df_plot['skill'] = ['1С' for _ in range(3)] + ['Javascript' for _ in range(3)]

# %%
df_plot.salary = df_plot.salary.round(1)

# %%
ax = sns.barplot(data=df_plot, x="experience", y="salary", hue='skill')
for container in ax.containers:
    ax.bar_label(container)

plt.title('Увеличение зарплаты в процентах по сравнению с предыдущей категорией')
plt.xlabel('Опыт работы', fontsize=15)
plt.ylabel('%', fontsize=15)
ax.legend(title='Навыки')
plt.show()

# %% [markdown]
# По графику процентного изменения цены от опыта работы мы видим, что разработчики Javascript работающие от трех лет имеют большую прибавку к зарплате, чем разработчики 1С

# %% [markdown]
# 3-я Гипотеза: 3. При росте опыта работы зарплата операторов станка растет быстрее, чем зарплата фрезеровщиков

# %%
mech = (df[df['name'].str.contains('фрезе', flags=re.IGNORECASE)].groupby('experience')['salary'].mean()\
         .reindex(['Нет опыта', 'От 1 года до 3 лет', 'От 3 до 6 лет', 'Более 6 лет']).pct_change() * 100)[1:]

# %%
oper = (df[df['name'].str.contains('Оператор станка', flags=re.IGNORECASE)].groupby('experience')['salary'].mean()\
         .reindex(['Нет опыта', 'От 1 года до 3 лет', 'От 3 до 6 лет', 'Более 6 лет']).pct_change() * 100)[1:]

# %%
df_plot = pd.concat([mech, oper], axis = 0).reset_index()

# %%
df_plot
# Out:
#            experience     salary
# 0  От 1 года до 3 лет  13.410085
# 1       От 3 до 6 лет  19.158108
# 2         Более 6 лет   6.973756
# 3  От 1 года до 3 лет  19.767129
# 4       От 3 до 6 лет  18.006758
# 5         Более 6 лет  30.621765

# %%
df_plot['skill'] = ['Фрезеровщик' for _ in range(3)] + ['Оператор станка' for _ in range(3)]

# %%
df_plot.salary = df_plot.salary.round(1)

# %%
ax = sns.barplot(data=df_plot, x="experience", y="salary", hue='skill')
for container in ax.containers:
    ax.bar_label(container)

plt.title('Увеличение зарплаты в процентах по сравнению с предыдущей категорией')
plt.xlabel('Опыт работы', fontsize=15)
plt.ylabel('%', fontsize=15)
ax.legend(title='Профессия')
plt.show()

# %% [markdown]
# По графику процентного изменения цены от опыта работы мы видим, что операторы станка имеют большую прибавку к зарплате, чем фрезеровщики

# %% [markdown]
# ## Модель

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels. stats.diagnostic import het_white

# %%
RAND = 42

# %%
df_encoder = df.copy()
oneh = pd.get_dummies(df_encoder["Region"], prefix = 'Region', drop_first = True)
df_encoder = pd.concat([df_encoder, oneh], axis=1)
df_encoder.drop('Region', axis = 1, inplace = True)

# oneh = pd.get_dummies(df_encoder["experience"], prefix = 'experience', drop_first = True)
# df_encoder = pd.concat([df_encoder, oneh], axis=1)
# df_encoder.drop('experience', axis = 1, inplace = True)
df_encoder['experience'] = df_encoder['experience'].map({'Нет опыта': 0, 'От 1 года до 3 лет': 1, 
                                                        'От 3 до 6 лет': 2, 'Более 6 лет': 3})

df_encoder = df_encoder.set_index('name')

# %%
X = df_encoder.loc[:, df_encoder.columns != 'salary'] 
y = df_encoder.loc[:, 'salary']

# %%
X = sm.add_constant(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RAND)

# %% [markdown]
# Базовая модель

# %%
model = sm.OLS(y_train, X_train).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     152.7
# Date:                Thu, 22 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:05:50   Log-Likelihood:            -1.9170e+05
# No. Observations:               16115   AIC:                         3.835e+05
# Df Residuals:                   16048   BIC:                         3.840e+05
# Df Model:                          66
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                    2.381e+04   1.11e+04      2.143      0.032    2032.824    4.56e+04
# response_letter_required                   63.7748   2700.765      0.024      0.981   -5230.027    5357.577
# latitude                                  354.1698    167.400      2.116      0.034      26.048     682.292
# longtitude                                -76.6166     71.949     -1.065      0.287    -217.644      64.411
# experience                               1.884e+04    433.505     43.453      0.000     1.8e+04    1.97e+04
# has_test                                 1.682e+04   3130.090      5.374      0.000    1.07e+04     2.3e+04
# Работа в команде                        -2769.8075    899.017     -3.081      0.002   -4531.981   -1007.634
# Пользователь ПК                         -7472.0762    976.885     -7.649      0.000   -9386.880   -5557.272
# Грамотная речь                          -1948.8254   1267.236     -1.538      0.124   -4432.751     535.100
# Техническое обслуживание                -1823.3335   1483.991     -1.229      0.219   -4732.121    1085.454
# Linux                                    3147.7461   1519.750      2.071      0.038     168.866    6126.627
# Работа в условиях многозадачности       -4556.1398   1389.469     -3.279      0.001   -7279.654   -1832.626
# SQL                                      1.313e+04   1581.741      8.301      0.000       1e+04    1.62e+04
# Работа с большим объемом информации     -9384.0084   1553.360     -6.041      0.000   -1.24e+04   -6339.249
# Adobe Photoshop                         -1.001e+04   2263.039     -4.421      0.000   -1.44e+04   -5569.226
# Настройка ПК                            -5426.2571   2362.844     -2.296      0.022   -1.01e+04    -794.818
# Грамотность                             -5604.8384   1655.487     -3.386      0.001   -8849.779   -2359.898
# Управление проектами                     2.299e+04   1670.759     13.758      0.000    1.97e+04    2.63e+04
# Git                                      2.617e+04   1803.585     14.513      0.000    2.26e+04    2.97e+04
# Умение работать в команде               -5332.4983   1567.917     -3.401      0.001   -8405.791   -2259.206
# Настройка сетевых подключений           -4045.4878   2276.349     -1.777      0.076   -8507.387     416.411
# Организаторские навыки                   -825.8288   1691.633     -0.488      0.625   -4141.618    2489.960
# Английский язык                          1.488e+04   1631.616      9.122      0.000    1.17e+04    1.81e+04
# Деловое общение                            37.2880   1836.516      0.020      0.984   -3562.489    3637.065
# Настройка ПО                              -83.0943   2494.392     -0.033      0.973   -4972.382    4806.194
# Деловая переписка                       -8058.0872   1883.334     -4.279      0.000   -1.17e+04   -4366.541
# Ремонтные работы                        -7057.2475   1985.965     -3.554      0.000   -1.09e+04   -3164.534
# Аналитическое мышление                   -505.8391   1862.126     -0.272      0.786   -4155.813    3144.135
# JavaScript                               1.636e+04   2356.936      6.939      0.000    1.17e+04     2.1e+04
# Ведение переговоров                      1.499e+04   1946.045      7.704      0.000    1.12e+04    1.88e+04
# Windows 7                               -8384.4998   1995.272     -4.202      0.000   -1.23e+04   -4473.544
# MS PowerPoint                            3472.5188   1940.879      1.789      0.074    -331.821    7276.858
# Информационные технологии               -3802.5038   2002.862     -1.899      0.058   -7728.336     123.329
# Ремонт ПК                                -668.6550   2286.822     -0.292      0.770   -5151.082    3813.772
# Техническая поддержка                   -8204.7166   1988.039     -4.127      0.000   -1.21e+04   -4307.937
# HTML                                    -7297.5838   2633.187     -2.771      0.006   -1.25e+04   -2136.244
# Точность и внимательность к деталям     -9059.2966   1987.923     -4.557      0.000    -1.3e+04   -5162.744
# PHP                                       443.7024   2744.997      0.162      0.872   -4936.799    5824.204
# Администрирование сетевого оборудования -6258.6186   2190.250     -2.857      0.004   -1.06e+04   -1965.483
# MySQL                                   -2936.2935   2701.090     -1.087      0.277   -8230.733    2358.146
# Adobe Illustrator                        1676.3743   2793.291      0.600      0.548   -3798.789    7151.537
# CorelDRAW                               -9928.6038   2505.197     -3.963      0.000   -1.48e+04   -5018.138
# Чтение чертежей                         -2814.9596   2086.178     -1.349      0.177   -6904.102    1274.183
# Python                                    1.92e+04   2195.237      8.744      0.000    1.49e+04    2.35e+04
# Креативность                            -4704.5474   2218.276     -2.121      0.034   -9052.616    -356.479
# Поиск информации в интернет             -3979.9981   2127.929     -1.870      0.061   -8150.978     190.981
# TCP/IP                                  -4093.8090   2233.319     -1.833      0.067   -8471.363     283.745
# Монтаж оборудования                     -4815.1528   2176.876     -2.212      0.027   -9082.073    -548.232
# Станки ЧПУ                              -3046.3091   2165.566     -1.407      0.160   -7291.061    1198.443
# CSS                                      1788.0801   3118.025      0.573      0.566   -4323.597    7899.757
# ООП                                      8632.4211   2362.950      3.653      0.000    4000.775    1.33e+04
# Деловая коммуникация                     2504.5506   2296.775      1.090      0.276   -1997.384    7006.485
# Информационная безопасность              5143.1524   2299.105      2.237      0.025     636.649    9649.656
# PostgreSQL                               4.342e+04   2369.081     18.329      0.000    3.88e+04    4.81e+04
# 1С                                       2.572e+04   1076.384     23.894      0.000    2.36e+04    2.78e+04
# Region_Волго-Камский                    -5882.6667   3784.355     -1.554      0.120   -1.33e+04    1535.092
# Region_Волго-Уральский                  -9001.1175   3726.532     -2.415      0.016   -1.63e+04   -1696.698
# Region_Дальневосточный                   1.163e+04   3545.818      3.281      0.001    4683.197    1.86e+04
# Region_Неизвестно                        1.379e+05   9283.300     14.850      0.000     1.2e+05    1.56e+05
# Region_Северно-Западный                  6562.2847   5147.038      1.275      0.202   -3526.485    1.67e+04
# Region_Северно-Кавказский               -3513.6970   4957.794     -0.709      0.479   -1.32e+04    6204.134
# Region_Северный и Уральский             -1.193e+04   6136.383     -1.944      0.052    -2.4e+04     101.558
# Region_Уральско-Сибирский               -4473.9594   3026.909     -1.478      0.139   -1.04e+04    1459.121
# Region_Центрально-Чернозёмный           -5010.3261   4634.894     -1.081      0.280   -1.41e+04    4074.585
# Region_Центральный                        2.24e+04   4498.973      4.978      0.000    1.36e+04    3.12e+04
# Region_Южно-Сибирский                   -3088.4704   2016.626     -1.532      0.126   -7041.283     864.342
# Region_Южный                            -3513.7833   4534.097     -0.775      0.438   -1.24e+04    5373.554
# ==============================================================================
# Omnibus:                     7419.196   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            66549.458
# Skew:                           2.001   Prob(JB):                         0.00
# Kurtosis:                      12.115   Cond. No.                     4.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print("Значимость переменных")
p_vals = np.around(model.pvalues,2)
p_vals[p_vals > 0.05]
# Out:
# Значимость переменных
# response_letter_required         0.98
# longtitude                       0.29
# Грамотная речь                   0.12
# Техническое обслуживание         0.22
# Настройка сетевых подключений    0.08
# Организаторские навыки           0.63
# Деловое общение                  0.98
# Настройка ПО                     0.97
# Аналитическое мышление           0.79
# MS PowerPoint                    0.07
# Информационные технологии        0.06
# Ремонт ПК                        0.77
# PHP                              0.87
# MySQL                            0.28
# Adobe Illustrator                0.55
# Чтение чертежей                  0.18
# Поиск информации в интернет      0.06
# TCP/IP                           0.07
# Станки ЧПУ                       0.16
# CSS                              0.57
# Деловая коммуникация             0.28
# Region_Волго-Камский             0.12
# Region_Северно-Западный          0.20
# Region_Северно-Кавказский        0.48
# Region_Уральско-Сибирский        0.14
# Region_Центрально-Чернозёмный    0.28
# Region_Южно-Сибирский            0.13
# Region_Южный                     0.44
# dtype: float64

# %%
print("Коеффициенты при переменных")
print(np.around(model.params,2))
# Out:
# Коеффициенты при переменных
# const                                       23810.33
# response_letter_required                       63.77
# latitude                                      354.17
# longtitude                                    -76.62
# experience                                  18837.06
# has_test                                    16822.04
# Работа в команде                            -2769.81
# Пользователь ПК                             -7472.08
# Грамотная речь                              -1948.83
# Техническое обслуживание                    -1823.33
# Linux                                        3147.75
# Работа в условиях многозадачности           -4556.14
# SQL                                         13129.32
# Работа с большим объемом информации         -9384.01
# Adobe Photoshop                            -10005.03
# Настройка ПК                                -5426.26
# Грамотность                                 -5604.84
# Управление проектами                        22986.53
# Git                                         26174.73
# Умение работать в команде                   -5332.50
# Настройка сетевых подключений               -4045.49
# Организаторские навыки                       -825.83
# Английский язык                             14884.11
# Деловое общение                                37.29
# Настройка ПО                                  -83.09
# Деловая переписка                           -8058.09
# Ремонтные работы                            -7057.25
# Аналитическое мышление                       -505.84
# JavaScript                                  16355.92
# Ведение переговоров                         14993.03
# Windows 7                                   -8384.50
# MS PowerPoint                                3472.52
# Информационные технологии                   -3802.50
# Ремонт ПК                                    -668.66
# Техническая поддержка                       -8204.72
# HTML                                        -7297.58
# Точность и внимательность к деталям         -9059.30
# PHP                                           443.70
# Администрирование сетевого оборудования     -6258.62
# MySQL                                       -2936.29
# Adobe Illustrator                            1676.37
# CorelDRAW                                   -9928.60
# Чтение чертежей                             -2814.96
# Python                                      19195.62
# Креативность                                -4704.55
# Поиск информации в интернет                 -3980.00
# TCP/IP                                      -4093.81
# Монтаж оборудования                         -4815.15
# Станки ЧПУ                                  -3046.31
# CSS                                          1788.08
# ООП                                          8632.42
# Деловая коммуникация                         2504.55
# Информационная безопасность                  5143.15
# PostgreSQL                                  43422.07
# 1С                                          25718.83
# Region_Волго-Камский                        -5882.67
# Region_Волго-Уральский                      -9001.12
# Region_Дальневосточный                      11633.40
# Region_Неизвестно                          137861.36
# Region_Северно-Западный                      6562.28
# Region_Северно-Кавказский                   -3513.70
# Region_Северный и Уральский                -11926.44
# Region_Уральско-Сибирский                   -4473.96
# Region_Центрально-Чернозёмный               -5010.33
# Region_Центральный                          22396.89
# Region_Южно-Сибирский                       -3088.47
# Region_Южный                                -3513.78
# dtype: float64

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif["features"] = X_train.columns

# %%
vif.sort_values('VIF Factor', ascending = False)
# Out:
#      VIF Factor                                 features
# 0   1574.220354                                    const
# 64    53.592853                       Region_Центральный
# 59    41.606687                  Region_Северно-Западный
# 3     35.207875                               longtitude
# 55    18.042387                     Region_Волго-Камский
# 66    16.266150                             Region_Южный
# 56    11.651545                   Region_Волго-Уральский
# 63    10.087669            Region_Центрально-Чернозёмный
# 62     9.597233                Region_Уральско-Сибирский
# 60     6.100943                Region_Северно-Кавказский
# 2      6.022069                                 latitude
# 57     5.285608                   Region_Дальневосточный
# 65     4.222927                    Region_Южно-Сибирский
# 15     2.597200                             Настройка ПК
# 14     2.401146                          Adobe Photoshop
# 24     2.302339                             Настройка ПО
# 49     2.213291                                      CSS
# 61     2.165492              Region_Северный и Уральский
# 20     2.113384            Настройка сетевых подключений
# 37     2.030311                                      PHP
# 35     1.952195                                     HTML
# 40     1.948513                        Adobe Illustrator
# 39     1.849709                                    MySQL
# 58     1.770344                        Region_Неизвестно
# 28     1.702290                               JavaScript
# 41     1.538689                                CorelDRAW
# 33     1.480298                                Ремонт ПК
# 18     1.441727                                      Git
# 9      1.356363                 Техническое обслуживание
# 8      1.337553                           Грамотная речь
# 38     1.292606  Администрирование сетевого оборудования
# 23     1.248042                          Деловое общение
# 10     1.242218                                    Linux
# 26     1.235288                         Ремонтные работы
# 25     1.211951                        Деловая переписка
# 50     1.211460                                      ООП
# 7      1.206953                          Пользователь ПК
# 30     1.198974                                Windows 7
# 16     1.196556                              Грамотность
# 29     1.186125                      Ведение переговоров
# 17     1.185862                     Управление проектами
# 6      1.185592                         Работа в команде
# 32     1.180909                Информационные технологии
# 53     1.179142                               PostgreSQL
# 43     1.174160                                   Python
# 46     1.173495                                   TCP/IP
# 12     1.171192                                      SQL
# 44     1.161487                             Креативность
# 13     1.150688      Работа с большим объемом информации
# 52     1.138802              Информационная безопасность
# 34     1.109795                    Техническая поддержка
# 21     1.101419                   Организаторские навыки
# 31     1.091901                            MS PowerPoint
# 45     1.086039              Поиск информации в интернет
# 27     1.086033                   Аналитическое мышление
# 4      1.083292                               experience
# 51     1.080008                     Деловая коммуникация
# 47     1.071586                      Монтаж оборудования
# 42     1.070322                          Чтение чертежей
# 48     1.064057                               Станки ЧПУ
# 19     1.047988                Умение работать в команде
# 54     1.044797                                       1С
# 22     1.044394                          Английский язык
# 36     1.028889      Точность и внимательность к деталям
# 11     1.023032        Работа в условиях многозадачности
# 1      1.016133                 response_letter_required
# 5      1.015070                                 has_test

# %%
white_test = het_white(model.resid , model.model.exog )

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 3798.8382212678603, 'Test Statistic p-value': 1.1589080013261682e-158, 'F-Statistic': 2.5862894216339507, 'F-Test p-value': 7.147080738627432e-195}

# %% [markdown]
# Мы принимаем гипотезу о том, что в регрессионной модели присутствует гетероскедастичность.

# %%
p_vals = np.around(model.pvalues,2)
p_cols = p_vals[(p_vals > 0.05) & (~p_vals.index.isin(['experience', 'JavaScript', '1С', 'Английский язык']))]

# %%
p_cols
# Out:
# response_letter_required         0.98
# longtitude                       0.29
# Грамотная речь                   0.12
# Техническое обслуживание         0.22
# Настройка сетевых подключений    0.08
# Организаторские навыки           0.63
# Деловое общение                  0.98
# Настройка ПО                     0.97
# Аналитическое мышление           0.79
# MS PowerPoint                    0.07
# Информационные технологии        0.06
# Ремонт ПК                        0.77
# PHP                              0.87
# MySQL                            0.28
# Adobe Illustrator                0.55
# Чтение чертежей                  0.18
# Поиск информации в интернет      0.06
# TCP/IP                           0.07
# Станки ЧПУ                       0.16
# CSS                              0.57
# Деловая коммуникация             0.28
# Region_Волго-Камский             0.12
# Region_Северно-Западный          0.20
# Region_Северно-Кавказский        0.48
# Region_Уральско-Сибирский        0.14
# Region_Центрально-Чернозёмный    0.28
# Region_Южно-Сибирский            0.13
# Region_Южный                     0.44
# dtype: float64

# %%
p_vals = np.around(model.pvalues,2)
p_cols = p_vals[p_vals > 0.05]
X_train_copy = X_train.copy()

while p_cols.any():
    deleted_col = p_cols.index[p_cols.argmax()]
    print('Удаляем колонку ', deleted_col)
    X_train_copy.drop(deleted_col, axis = 1, inplace = True)
    print('Обучаем модель на оставшихся колонках:')
    model = sm.OLS(y_train, X_train_copy).fit()
    print("R-squared:", model.rsquared)
    print("Adj. R-squared:", model.rsquared_adj)
    print("AIC:", model.aic)
    print("Коеффициенты при параметрах")
    print(np.around(model.params, 2))
    
    p_vals = np.around(model.pvalues,2)
    p_cols = p_vals[(p_vals > 0.05) & (~p_vals.index.isin(['experience', 'JavaScript', '1С', 'Английский язык']))]
    
    print('VIF оставшихся колонок:')
    vif = pd.DataFrame()
    vif["VIF Factor"] = [variance_inflation_factor(X_train_copy.values, i) for i in range(X_train_copy.shape[1])]
    vif["features"] = X_train_copy.columns
    print(vif.sort_values('VIF Factor', ascending = False).head(10))
    
    print('Тест Уайта:')
    white_test = het_white(model.resid , model.model.exog )

    #define labels to use for output of White's test
    labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

    #print results of White's test
    print(dict(zip(labels, white_test)))
    print('____________________________________________________________________________________________________________________')
    print('')
# Out:
# Удаляем колонку  Техническое обслуживание
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3856948234599822
# Adj. R-squared: 0.3832068281658766
# AIC: 383524.89727642457
# Коеффициенты при параметрах
# const                                       24027.10
# response_letter_required                       78.61
# latitude                                      349.56
# longtitude                                    -76.78
# experience                                  18830.77
# has_test                                    16719.37
# Работа в команде                            -2772.64
# Пользователь ПК                             -7547.95
# Грамотная речь                              -1918.08
# Linux                                        3174.10
# Работа в условиях многозадачности           -4525.20
# SQL                                         13160.97
# Работа с большим объемом информации         -9376.46
# Adobe Photoshop                             -9965.36
# Настройка ПК                                -5543.71
# Грамотность                                 -5587.57
# Управление проектами                        23033.84
# Git                                         26194.69
# Умение работать в команде                   -5373.21
# Настройка сетевых подключений               -3951.54
# Организаторские навыки                       -854.98
# Английский язык                             14848.45
# Деловое общение                                53.28
# Настройка ПО                                 -169.43
# Деловая переписка                           -8031.25
# Ремонтные работы                            -7998.39
# Аналитическое мышление                       -475.26
# JavaScript                                  16373.33
# Ведение переговоров                         15001.32
# Windows 7                                   -8316.35
# MS PowerPoint                                3485.56
# Информационные технологии                   -3883.65
# Ремонт ПК                                   -1228.82
# Техническая поддержка                       -8255.98
# HTML                                        -7288.75
# Точность и внимательность к деталям         -9010.28
# PHP                                           459.21
# Администрирование сетевого оборудования     -6220.66
# MySQL                                       -2933.74
# Adobe Illustrator                            1679.10
# CorelDRAW                                   -9906.85
# Чтение чертежей                             -2755.19
# Python                                      19212.26
# Креативность                                -4695.64
# Поиск информации в интернет                 -3912.57
# TCP/IP                                      -4112.81
# Монтаж оборудования                         -5273.52
# Станки ЧПУ                                  -3047.01
# CSS                                          1791.25
# ООП                                          8645.90
# Деловая коммуникация                         2528.22
# Информационная безопасность                  5230.84
# PostgreSQL                                  43427.00
# 1С                                          25759.71
# Region_Волго-Камский                        -5858.46
# Region_Волго-Уральский                      -9007.81
# Region_Дальневосточный                      11603.15
# Region_Неизвестно                          137827.31
# Region_Северно-Западный                      6579.28
# Region_Северно-Кавказский                   -3598.00
# Region_Северный и Уральский                -12005.72
# Region_Уральско-Сибирский                   -4474.44
# Region_Центрально-Чернозёмный               -5043.89
# Region_Центральный                          22402.53
# Region_Южно-Сибирский                       -3082.97
# Region_Южный                                -3576.07
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.823397                          const
# 63    53.592797             Region_Центральный
# 58    41.606386        Region_Северно-Западный
# 3     35.207757                     longtitude
# 54    18.041898           Region_Волго-Камский
# 65    16.264117                   Region_Южный
# 55    11.651520         Region_Волго-Уральский
# 62    10.087318  Region_Центрально-Чернозёмный
# 61     9.597233      Region_Уральско-Сибирский
# 59     6.099775      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3744.997207217325, 'Test Statistic p-value': 6.325497762597737e-161, 'F-Statistic': 2.623757985876539, 'F-Test p-value': 7.430839714980765e-197}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  response_letter_required
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38569479103294424
# Adj. R-squared: 0.38324522509064574
# AIC: 383522.8981270795
# Коеффициенты при параметрах
# const                                       24030.42
# latitude                                      349.50
# longtitude                                    -76.78
# experience                                  18830.60
# has_test                                    16722.60
# Работа в команде                            -2772.45
# Пользователь ПК                             -7547.59
# Грамотная речь                              -1918.35
# Linux                                        3173.66
# Работа в условиях многозадачности           -4525.41
# SQL                                         13160.67
# Работа с большим объемом информации         -9376.50
# Adobe Photoshop                             -9965.93
# Настройка ПК                                -5544.20
# Грамотность                                 -5586.22
# Управление проектами                        23035.44
# Git                                         26196.71
# Умение работать в команде                   -5373.08
# Настройка сетевых подключений               -3951.38
# Организаторские навыки                       -855.44
# Английский язык                             14850.29
# Деловое общение                                53.58
# Настройка ПО                                 -169.27
# Деловая переписка                           -8029.97
# Ремонтные работы                            -7998.53
# Аналитическое мышление                       -474.44
# JavaScript                                  16374.36
# Ведение переговоров                         15001.42
# Windows 7                                   -8316.07
# MS PowerPoint                                3485.93
# Информационные технологии                   -3882.65
# Ремонт ПК                                   -1229.20
# Техническая поддержка                       -8255.85
# HTML                                        -7289.07
# Точность и внимательность к деталям         -9009.69
# PHP                                           458.26
# Администрирование сетевого оборудования     -6220.90
# MySQL                                       -2932.52
# Adobe Illustrator                            1680.66
# CorelDRAW                                   -9906.75
# Чтение чертежей                             -2755.84
# Python                                      19211.98
# Креативность                                -4694.95
# Поиск информации в интернет                 -3912.63
# TCP/IP                                      -4112.97
# Монтаж оборудования                         -5274.15
# Станки ЧПУ                                  -3046.75
# CSS                                          1791.66
# ООП                                          8646.07
# Деловая коммуникация                         2528.58
# Информационная безопасность                  5230.07
# PostgreSQL                                  43427.53
# 1С                                          25759.78
# Region_Волго-Камский                        -5858.68
# Region_Волго-Уральский                      -9007.87
# Region_Дальневосточный                      11603.68
# Region_Неизвестно                          137831.25
# Region_Северно-Западный                      6580.17
# Region_Северно-Кавказский                   -3598.40
# Region_Северный и Уральский                -12005.62
# Region_Уральско-Сибирский                   -4474.62
# Region_Центрально-Чернозёмный               -5044.14
# Region_Центральный                          22402.98
# Region_Южно-Сибирский                       -3083.12
# Region_Южный                                -3575.69
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.657452                          const
# 62    53.592178             Region_Центральный
# 57    41.604923        Region_Северно-Западный
# 2     35.207730                     longtitude
# 53    18.041823           Region_Волго-Камский
# 64    16.263985                   Region_Южный
# 54    11.651517         Region_Волго-Уральский
# 61    10.087285  Region_Центрально-Чернозёмный
# 60     9.597194      Region_Уральско-Сибирский
# 58     6.099728      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3533.680678031085, 'Test Statistic p-value': 4.594529320123451e-146, 'F-Statistic': 2.535495539897664, 'F-Test p-value': 1.4341431873805838e-176}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Деловое общение
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38569475844625245
# Adj. R-squared: 0.38328361707076886
# AIC: 383520.8989819225
# Коеффициенты при параметрах
# const                                       24031.82
# latitude                                      349.48
# longtitude                                    -76.76
# experience                                  18829.98
# has_test                                    16722.50
# Работа в команде                            -2770.18
# Пользователь ПК                             -7546.76
# Грамотная речь                              -1913.58
# Linux                                        3174.06
# Работа в условиях многозадачности           -4526.32
# SQL                                         13160.37
# Работа с большим объемом информации         -9375.30
# Adobe Photoshop                             -9966.12
# Настройка ПК                                -5543.50
# Грамотность                                 -5585.36
# Управление проектами                        23035.41
# Git                                         26196.62
# Умение работать в команде                   -5372.75
# Настройка сетевых подключений               -3951.48
# Организаторские навыки                       -854.59
# Английский язык                             14849.98
# Настройка ПО                                 -169.53
# Деловая переписка                           -8014.47
# Ремонтные работы                            -7999.03
# Аналитическое мышление                       -474.79
# JavaScript                                  16374.13
# Ведение переговоров                         15009.15
# Windows 7                                   -8316.52
# MS PowerPoint                                3484.61
# Информационные технологии                   -3882.88
# Ремонт ПК                                   -1230.63
# Техническая поддержка                       -8254.75
# HTML                                        -7287.89
# Точность и внимательность к деталям         -9011.00
# PHP                                           458.35
# Администрирование сетевого оборудования     -6220.96
# MySQL                                       -2932.98
# Adobe Illustrator                            1680.23
# CorelDRAW                                   -9905.92
# Чтение чертежей                             -2756.77
# Python                                      19211.79
# Креативность                                -4696.42
# Поиск информации в интернет                 -3913.35
# TCP/IP                                      -4113.58
# Монтаж оборудования                         -5274.60
# Станки ЧПУ                                  -3047.33
# CSS                                          1790.89
# ООП                                          8645.81
# Деловая коммуникация                         2532.85
# Информационная безопасность                  5230.35
# PostgreSQL                                  43427.92
# 1С                                          25760.08
# Region_Волго-Камский                        -5858.34
# Region_Волго-Уральский                      -9007.75
# Region_Дальневосточный                      11601.87
# Region_Неизвестно                          137831.39
# Region_Северно-Западный                      6580.47
# Region_Северно-Кавказский                   -3598.06
# Region_Северный и Уральский                -12005.60
# Region_Уральско-Сибирский                   -4474.63
# Region_Центрально-Чернозёмный               -5044.71
# Region_Центральный                          22403.44
# Region_Южно-Сибирский                       -3083.78
# Region_Южный                                -3575.45
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.628319                          const
# 61    53.591515             Region_Центральный
# 56    41.604753        Region_Северно-Западный
# 2     35.205485                     longtitude
# 52    18.041648           Region_Волго-Камский
# 63    16.263932                   Region_Южный
# 53    11.651504         Region_Волго-Уральский
# 60    10.087104  Region_Центрально-Чернозёмный
# 59     9.597194      Region_Уральско-Сибирский
# 57     6.099693      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3441.567072770102, 'Test Statistic p-value': 3.108439462013182e-144, 'F-Statistic': 2.544323491463843, 'F-Test p-value': 2.449461142390775e-173}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Настройка ПО
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38569458149085833
# Adj. R-squared: 0.38332185934112206
# AIC: 383518.9036239727
# Коеффициенты при параметрах
# const                                       24031.26
# latitude                                      349.43
# longtitude                                    -76.73
# experience                                  18830.06
# has_test                                    16717.97
# Работа в команде                            -2770.64
# Пользователь ПК                             -7544.50
# Грамотная речь                              -1912.68
# Linux                                        3174.46
# Работа в условиях многозадачности           -4526.54
# SQL                                         13159.19
# Работа с большим объемом информации         -9375.23
# Adobe Photoshop                             -9964.33
# Настройка ПК                                -5616.70
# Грамотность                                 -5586.15
# Управление проектами                        23035.57
# Git                                         26196.53
# Умение работать в команде                   -5373.53
# Настройка сетевых подключений               -3994.45
# Организаторские навыки                       -854.55
# Английский язык                             14851.23
# Деловая переписка                           -8014.08
# Ремонтные работы                            -7998.85
# Аналитическое мышление                       -473.58
# JavaScript                                  16374.47
# Ведение переговоров                         15010.28
# Windows 7                                   -8325.85
# MS PowerPoint                                3484.30
# Информационные технологии                   -3883.38
# Ремонт ПК                                   -1244.94
# Техническая поддержка                       -8258.33
# HTML                                        -7288.47
# Точность и внимательность к деталям         -9011.23
# PHP                                           458.44
# Администрирование сетевого оборудования     -6224.21
# MySQL                                       -2931.20
# Adobe Illustrator                            1679.44
# CorelDRAW                                   -9906.46
# Чтение чертежей                             -2756.28
# Python                                      19212.36
# Креативность                                -4696.41
# Поиск информации в интернет                 -3913.33
# TCP/IP                                      -4106.83
# Монтаж оборудования                         -5273.84
# Станки ЧПУ                                  -3047.56
# CSS                                          1790.64
# ООП                                          8646.29
# Деловая коммуникация                         2532.79
# Информационная безопасность                  5230.33
# PostgreSQL                                  43427.11
# 1С                                          25760.54
# Region_Волго-Камский                        -5857.37
# Region_Волго-Уральский                      -9006.86
# Region_Дальневосточный                      11599.12
# Region_Неизвестно                          137841.43
# Region_Северно-Западный                      6582.15
# Region_Северно-Кавказский                   -3598.73
# Region_Северный и Уральский                -11999.58
# Region_Уральско-Сибирский                   -4473.89
# Region_Центрально-Чернозёмный               -5041.97
# Region_Центральный                          22404.88
# Region_Южно-Сибирский                       -3083.48
# Region_Южный                                -3574.57
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.627459                          const
# 60    53.590323             Region_Центральный
# 55    41.603798        Region_Северно-Западный
# 2     35.203902                     longtitude
# 51    18.041390           Region_Волго-Камский
# 62    16.263797                   Region_Южный
# 52    11.651360         Region_Волго-Уральский
# 59    10.086344  Region_Центрально-Чернозёмный
# 58     9.597072      Region_Уральско-Сибирский
# 56     6.099668      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3431.729487996649, 'Test Statistic p-value': 3.0069927278558475e-150, 'F-Statistic': 2.611111780440576, 'F-Test p-value': 2.8262851813148615e-180}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  PHP
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38569351374705163
# Adj. R-squared: 0.383359202673643
# AIC: 383516.931633943
# Коеффициенты при параметрах
# const                                       24049.61
# latitude                                      349.52
# longtitude                                    -76.97
# experience                                  18830.26
# has_test                                    16728.41
# Работа в команде                            -2769.39
# Пользователь ПК                             -7545.01
# Грамотная речь                              -1912.90
# Linux                                        3169.77
# Работа в условиях многозадачности           -4526.69
# SQL                                         13162.56
# Работа с большим объемом информации         -9375.43
# Adobe Photoshop                             -9967.22
# Настройка ПК                                -5617.60
# Грамотность                                 -5589.47
# Управление проектами                        23037.57
# Git                                         26221.42
# Умение работать в команде                   -5374.75
# Настройка сетевых подключений               -3994.43
# Организаторские навыки                       -856.62
# Английский язык                             14851.41
# Деловая переписка                           -8015.70
# Ремонтные работы                            -7999.87
# Аналитическое мышление                       -474.02
# JavaScript                                  16417.94
# Ведение переговоров                         15009.52
# Windows 7                                   -8321.90
# MS PowerPoint                                3483.75
# Информационные технологии                   -3877.94
# Ремонт ПК                                   -1247.45
# Техническая поддержка                       -8258.50
# HTML                                        -7264.83
# Точность и внимательность к деталям         -9012.51
# Администрирование сетевого оборудования     -6224.54
# MySQL                                       -2684.92
# Adobe Illustrator                            1677.33
# CorelDRAW                                   -9904.58
# Чтение чертежей                             -2757.49
# Python                                      19198.51
# Креативность                                -4698.73
# Поиск информации в интернет                 -3914.23
# TCP/IP                                      -4113.73
# Монтаж оборудования                         -5274.41
# Станки ЧПУ                                  -3049.07
# CSS                                          1853.13
# ООП                                          8703.87
# Деловая коммуникация                         2531.60
# Информационная безопасность                  5226.49
# PostgreSQL                                  43410.79
# 1С                                          25757.80
# Region_Волго-Камский                        -5867.38
# Region_Волго-Уральский                      -9014.61
# Region_Дальневосточный                      11610.24
# Region_Неизвестно                          137872.27
# Region_Северно-Западный                      6566.68
# Region_Северно-Кавказский                   -3610.05
# Region_Северный и Уральский                -12001.12
# Region_Уральско-Сибирский                   -4480.76
# Region_Центрально-Чернозёмный               -5056.09
# Region_Центральный                          22391.55
# Region_Южно-Сибирский                       -3087.51
# Region_Южный                                -3589.12
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.473510                          const
# 59    53.573450             Region_Центральный
# 54    41.590335        Region_Северно-Западный
# 2     35.189965                     longtitude
# 50    18.036861           Region_Волго-Камский
# 61    16.257789                   Region_Южный
# 51    11.649556         Region_Волго-Уральский
# 58    10.082989  Region_Центрально-Чернозёмный
# 57     9.595301      Region_Уральско-Сибирский
# 55     6.098528      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3133.2919860272764, 'Test Statistic p-value': 1.4333288919149327e-120, 'F-Statistic': 2.3865490598839516, 'F-Test p-value': 1.6365465776222893e-142}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Аналитическое мышление
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3856910320998653
# Adj. R-squared: 0.3833951221662657
# AIC: 383514.9967344498
# Коеффициенты при параметрах
# const                                       24053.97
# latitude                                      349.51
# longtitude                                    -77.13
# experience                                  18831.56
# has_test                                    16733.63
# Работа в команде                            -2764.32
# Пользователь ПК                             -7538.89
# Грамотная речь                              -1906.42
# Linux                                        3173.06
# Работа в условиях многозадачности           -4530.55
# SQL                                         13136.45
# Работа с большим объемом информации         -9444.24
# Adobe Photoshop                             -9952.92
# Настройка ПК                                -5608.30
# Грамотность                                 -5587.52
# Управление проектами                        23021.31
# Git                                         26235.01
# Умение работать в команде                   -5366.22
# Настройка сетевых подключений               -3995.25
# Организаторские навыки                       -853.00
# Английский язык                             14842.10
# Деловая переписка                           -8015.59
# Ремонтные работы                            -7999.36
# JavaScript                                  16417.42
# Ведение переговоров                         15003.03
# Windows 7                                   -8320.95
# MS PowerPoint                                3416.75
# Информационные технологии                   -3887.88
# Ремонт ПК                                   -1242.54
# Техническая поддержка                       -8266.89
# HTML                                        -7261.90
# Точность и внимательность к деталям         -9005.96
# Администрирование сетевого оборудования     -6228.56
# MySQL                                       -2683.49
# Adobe Illustrator                            1674.00
# CorelDRAW                                   -9902.54
# Чтение чертежей                             -2751.47
# Python                                      19188.79
# Креативность                                -4697.53
# Поиск информации в интернет                 -3912.14
# TCP/IP                                      -4111.66
# Монтаж оборудования                         -5267.27
# Станки ЧПУ                                  -3043.48
# CSS                                          1851.55
# ООП                                          8713.59
# Деловая коммуникация                         2514.41
# Информационная безопасность                  5232.55
# PostgreSQL                                  43417.83
# 1С                                          25753.71
# Region_Волго-Камский                        -5871.42
# Region_Волго-Уральский                      -9017.18
# Region_Дальневосточный                      11613.79
# Region_Неизвестно                          137833.07
# Region_Северно-Западный                      6556.93
# Region_Северно-Кавказский                   -3624.24
# Region_Северный и Уральский                -12001.05
# Region_Уральско-Сибирский                   -4486.44
# Region_Центрально-Чернозёмный               -5062.22
# Region_Центральный                          22382.66
# Region_Южно-Сибирский                       -3087.46
# Region_Южный                                -3599.01
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.469764                          const
# 58    53.570223             Region_Центральный
# 53    41.588032        Region_Северно-Западный
# 2     35.187250                     longtitude
# 49    18.036544           Region_Волго-Камский
# 60    16.256596                   Region_Южный
# 50    11.649471         Region_Волго-Уральский
# 57    10.082718  Region_Центрально-Чернозёмный
# 56     9.594781      Region_Уральско-Сибирский
# 54     6.097757      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3077.864287837484, 'Test Statistic p-value': 3.032872810348748e-122, 'F-Statistic': 2.4223809652756585, 'F-Test p-value': 6.251276016208533e-144}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Организаторские навыки
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38568129303321674
# Adj. R-squared: 0.383423753094815
# AIC: 383513.25221471005
# Коеффициенты при параметрах
# const                                       24150.40
# latitude                                      348.15
# longtitude                                    -77.35
# experience                                  18815.85
# has_test                                    16710.28
# Работа в команде                            -2807.33
# Пользователь ПК                             -7560.49
# Грамотная речь                              -1921.14
# Linux                                        3181.58
# Работа в условиях многозадачности           -4531.64
# SQL                                         13151.66
# Работа с большим объемом информации         -9434.51
# Adobe Photoshop                             -9971.49
# Настройка ПК                                -5598.41
# Грамотность                                 -5571.19
# Управление проектами                        22887.63
# Git                                         26241.31
# Умение работать в команде                   -5394.72
# Настройка сетевых подключений               -3997.78
# Английский язык                             14851.02
# Деловая переписка                           -8042.35
# Ремонтные работы                            -8008.54
# JavaScript                                  16420.78
# Ведение переговоров                         14936.15
# Windows 7                                   -8315.16
# MS PowerPoint                                3397.91
# Информационные технологии                   -3892.33
# Ремонт ПК                                   -1230.20
# Техническая поддержка                       -8263.45
# HTML                                        -7280.78
# Точность и внимательность к деталям         -8983.56
# Администрирование сетевого оборудования     -6219.74
# MySQL                                       -2677.61
# Adobe Illustrator                            1701.06
# CorelDRAW                                   -9880.35
# Чтение чертежей                             -2728.63
# Python                                      19193.76
# Креативность                                -4696.37
# Поиск информации в интернет                 -3890.45
# TCP/IP                                      -4100.27
# Монтаж оборудования                         -5248.97
# Станки ЧПУ                                  -3025.07
# CSS                                          1877.24
# ООП                                          8718.05
# Деловая коммуникация                         2434.26
# Информационная безопасность                  5214.45
# PostgreSQL                                  43420.34
# 1С                                          25770.49
# Region_Волго-Камский                        -5875.09
# Region_Волго-Уральский                      -9023.96
# Region_Дальневосточный                      11613.25
# Region_Неизвестно                          137818.71
# Region_Северно-Западный                      6551.73
# Region_Северно-Кавказский                   -3669.65
# Region_Северный и Уральский                -12017.03
# Region_Уральско-Сибирский                   -4494.90
# Region_Центрально-Чернозёмный               -5085.01
# Region_Центральный                          22378.11
# Region_Южно-Сибирский                       -3079.55
# Region_Южный                                -3622.08
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.003714                          const
# 57    53.570008             Region_Центральный
# 52    41.587865        Region_Северно-Западный
# 2     35.185863                     longtitude
# 48    18.036478           Region_Волго-Камский
# 59    16.254941                   Region_Южный
# 49    11.649319         Region_Волго-Уральский
# 56    10.081759  Region_Центрально-Чернозёмный
# 55     9.594486      Region_Уральско-Сибирский
# 53     6.095746      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3047.998925840015, 'Test Statistic p-value': 1.625218069659362e-126, 'F-Statistic': 2.4806321702855167, 'F-Test p-value': 1.4313205436641277e-148}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Ремонт ПК
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3856696463181394
# Adj. R-squared: 0.38345046591744514
# AIC: 383511.55773207784
# Коеффициенты при параметрах
# const                                       24085.95
# latitude                                      348.53
# longtitude                                    -77.07
# experience                                  18820.27
# has_test                                    16690.82
# Работа в команде                            -2815.79
# Пользователь ПК                             -7572.85
# Грамотная речь                              -1916.89
# Linux                                        3180.74
# Работа в условиях многозадачности           -4516.10
# SQL                                         13161.61
# Работа с большим объемом информации         -9438.96
# Adobe Photoshop                             -9970.62
# Настройка ПК                                -5998.80
# Грамотность                                 -5561.13
# Управление проектами                        22892.56
# Git                                         26245.08
# Умение работать в команде                   -5390.21
# Настройка сетевых подключений               -4158.12
# Английский язык                             14858.77
# Деловая переписка                           -8048.63
# Ремонтные работы                            -7991.39
# JavaScript                                  16422.73
# Ведение переговоров                         14940.81
# Windows 7                                   -8338.32
# MS PowerPoint                                3405.12
# Информационные технологии                   -3850.09
# Техническая поддержка                       -8246.65
# HTML                                        -7277.40
# Точность и внимательность к деталям         -8975.62
# Администрирование сетевого оборудования     -6228.69
# MySQL                                       -2677.58
# Adobe Illustrator                            1705.41
# CorelDRAW                                   -9874.27
# Чтение чертежей                             -2720.42
# Python                                      19193.87
# Креативность                                -4691.90
# Поиск информации в интернет                 -3885.99
# TCP/IP                                      -4074.90
# Монтаж оборудования                         -5269.24
# Станки ЧПУ                                  -3012.82
# CSS                                          1877.68
# ООП                                          8719.97
# Деловая коммуникация                         2430.50
# Информационная безопасность                  5202.38
# PostgreSQL                                  43424.08
# 1С                                          25777.04
# Region_Волго-Камский                        -5853.63
# Region_Волго-Уральский                      -9015.48
# Region_Дальневосточный                      11601.42
# Region_Неизвестно                          137889.40
# Region_Северно-Западный                      6566.79
# Region_Северно-Кавказский                   -3656.48
# Region_Северный и Уральский                -12036.51
# Region_Уральско-Сибирский                   -4482.09
# Region_Центрально-Чернозёмный               -5071.59
# Region_Центральный                          22396.54
# Region_Южно-Сибирский                       -3072.43
# Region_Южный                                -3596.71
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1572.829642                          const
# 56    53.567054             Region_Центральный
# 51    41.586695        Region_Северно-Западный
# 2     35.184034                     longtitude
# 47    18.034571           Region_Волго-Камский
# 58    16.253267                   Region_Южный
# 48    11.649120         Region_Волго-Уральский
# 55    10.081481  Region_Центрально-Чернозёмный
# 54     9.593922      Region_Уральско-Сибирский
# 52     6.095604      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3041.7783958021832, 'Test Statistic p-value': 6.227327423580873e-133, 'F-Statistic': 2.55697319102029, 'F-Test p-value': 6.871895865485168e-156}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Adobe Illustrator
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38565536694368274
# Adj. R-squared: 0.38347453340789095
# AIC: 383509.9323016294
# Коеффициенты при параметрах
# const                                       24189.10
# latitude                                      347.56
# longtitude                                    -77.62
# experience                                  18823.40
# has_test                                    16708.55
# Работа в команде                            -2818.35
# Пользователь ПК                             -7576.94
# Грамотная речь                              -1929.96
# Linux                                        3173.42
# Работа в условиях многозадачности           -4525.20
# SQL                                         13157.33
# Работа с большим объемом информации         -9438.97
# Adobe Photoshop                             -9195.06
# Настройка ПК                                -6004.23
# Грамотность                                 -5586.07
# Управление проектами                        22879.24
# Git                                         26239.01
# Умение работать в команде                   -5395.25
# Настройка сетевых подключений               -4160.54
# Английский язык                             14853.63
# Деловая переписка                           -8045.74
# Ремонтные работы                            -7996.26
# JavaScript                                  16405.70
# Ведение переговоров                         14935.14
# Windows 7                                   -8334.76
# MS PowerPoint                                3373.51
# Информационные технологии                   -3853.39
# Техническая поддержка                       -8256.21
# HTML                                        -7303.24
# Точность и внимательность к деталям         -8979.12
# Администрирование сетевого оборудования     -6230.22
# MySQL                                       -2686.79
# CorelDRAW                                   -9684.85
# Чтение чертежей                             -2728.90
# Python                                      19192.25
# Креативность                                -4674.74
# Поиск информации в интернет                 -3905.26
# TCP/IP                                      -4076.46
# Монтаж оборудования                         -5271.67
# Станки ЧПУ                                  -3023.77
# CSS                                          1876.76
# ООП                                          8714.92
# Деловая коммуникация                         2442.68
# Информационная безопасность                  5199.68
# PostgreSQL                                  43426.64
# 1С                                          25770.93
# Region_Волго-Камский                        -5861.41
# Region_Волго-Уральский                      -9034.16
# Region_Дальневосточный                      11623.82
# Region_Неизвестно                          137842.23
# Region_Северно-Западный                      6542.73
# Region_Северно-Кавказский                   -3707.47
# Region_Северный и Уральский                -12071.58
# Region_Уральско-Сибирский                   -4502.65
# Region_Центрально-Чернозёмный               -5092.90
# Region_Центральный                          22372.38
# Region_Южно-Сибирский                       -3071.76
# Region_Южный                                -3611.27
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1572.465973                          const
# 55    53.562911             Region_Центральный
# 50    41.584257        Region_Северно-Западный
# 2     35.178516                     longtitude
# 46    18.034367           Region_Волго-Камский
# 57    16.252817                   Region_Южный
# 47    11.648336         Region_Волго-Уральский
# 54    10.080909  Region_Центрально-Чернозёмный
# 53     9.592735      Region_Уральско-Сибирский
# 51     6.093874      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3035.3028492138274, 'Test Statistic p-value': 6.64610980602736e-138, 'F-Statistic': 2.618128184922118, 'F-Test p-value': 1.569892778759295e-161}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  CSS
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38564129214916487
# Adj. R-squared: 0.38349880319414886
# AIC: 383508.3014962203
# Коеффициенты при параметрах
# const                                       24244.37
# latitude                                      347.10
# longtitude                                    -77.90
# experience                                  18822.26
# has_test                                    16694.07
# Работа в команде                            -2818.53
# Пользователь ПК                             -7578.31
# Грамотная речь                              -1932.20
# Linux                                        3155.48
# Работа в условиях многозадачности           -4524.26
# SQL                                         13171.79
# Работа с большим объемом информации         -9439.36
# Adobe Photoshop                             -9162.60
# Настройка ПК                                -6007.58
# Грамотность                                 -5581.15
# Управление проектами                        22886.14
# Git                                         26239.09
# Умение работать в команде                   -5396.13
# Настройка сетевых подключений               -4156.82
# Английский язык                             14832.73
# Деловая переписка                           -8067.55
# Ремонтные работы                            -7998.37
# JavaScript                                  16863.07
# Ведение переговоров                         14939.13
# Windows 7                                   -8332.39
# MS PowerPoint                                3371.92
# Информационные технологии                   -3865.39
# Техническая поддержка                       -8264.75
# HTML                                        -6394.21
# Точность и внимательность к деталям         -8981.85
# Администрирование сетевого оборудования     -6223.42
# MySQL                                       -2580.51
# CorelDRAW                                   -9706.67
# Чтение чертежей                             -2731.32
# Python                                      19216.14
# Креативность                                -4690.76
# Поиск информации в интернет                 -3905.98
# TCP/IP                                      -4084.73
# Монтаж оборудования                         -5274.00
# Станки ЧПУ                                  -3024.23
# ООП                                          8698.97
# Деловая коммуникация                         2437.33
# Информационная безопасность                  5194.75
# PostgreSQL                                  43381.66
# 1С                                          25761.36
# Region_Волго-Камский                        -5875.61
# Region_Волго-Уральский                      -9046.12
# Region_Дальневосточный                      11637.55
# Region_Неизвестно                          137696.39
# Region_Северно-Западный                      6524.14
# Region_Северно-Кавказский                   -3727.11
# Region_Северный и Уральский                -12082.50
# Region_Уральско-Сибирский                   -4509.12
# Region_Центрально-Чернозёмный               -5122.88
# Region_Центральный                          22356.40
# Region_Южно-Сибирский                       -3064.80
# Region_Южный                                -3614.76
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1572.360017                          const
# 54    53.561073             Region_Центральный
# 49    41.582782        Region_Северно-Западный
# 2     35.177071                     longtitude
# 45    18.033676           Region_Волго-Камский
# 56    16.252791                   Region_Южный
# 46    11.648010         Region_Волго-Уральский
# 53    10.079761  Region_Центрально-Чернозёмный
# 52     9.592616      Region_Уральско-Сибирский
# 50     6.093613      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3003.2676413417075, 'Test Statistic p-value': 9.561986662379546e-141, 'F-Statistic': 2.665805202626127, 'F-Test p-value': 1.8902085154757196e-164}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Region_Северно-Кавказский
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3856196344790632
# Adj. R-squared: 0.3835154611118765
# AIC: 383506.8695799759
# Коеффициенты при параметрах
# const                                       17876.75
# latitude                                      382.10
# longtitude                                    -35.39
# experience                                  18818.86
# has_test                                    16636.08
# Работа в команде                            -2827.55
# Пользователь ПК                             -7588.11
# Грамотная речь                              -1918.57
# Linux                                        3125.23
# Работа в условиях многозадачности           -4545.53
# SQL                                         13171.98
# Работа с большим объемом информации         -9433.80
# Adobe Photoshop                             -9148.78
# Настройка ПК                                -6029.19
# Грамотность                                 -5612.12
# Управление проектами                        22880.06
# Git                                         26244.44
# Умение работать в команде                   -5411.94
# Настройка сетевых подключений               -4128.48
# Английский язык                             14863.74
# Деловая переписка                           -8088.38
# Ремонтные работы                            -7988.09
# JavaScript                                  16888.49
# Ведение переговоров                         14968.48
# Windows 7                                   -8325.67
# MS PowerPoint                                3372.20
# Информационные технологии                   -3894.19
# Техническая поддержка                       -8228.13
# HTML                                        -6386.14
# Точность и внимательность к деталям         -8968.72
# Администрирование сетевого оборудования     -6223.66
# MySQL                                       -2560.73
# CorelDRAW                                   -9704.92
# Чтение чертежей                             -2719.47
# Python                                      19237.52
# Креативность                                -4688.86
# Поиск информации в интернет                 -3918.54
# TCP/IP                                      -4100.24
# Монтаж оборудования                         -5280.29
# Станки ЧПУ                                  -3007.66
# ООП                                          8673.85
# Деловая коммуникация                         2437.25
# Информационная безопасность                  5205.77
# PostgreSQL                                  43379.85
# 1С                                          25755.00
# Region_Волго-Камский                        -3600.26
# Region_Волго-Уральский                      -6707.07
# Region_Дальневосточный                      10797.47
# Region_Неизвестно                          141842.86
# Region_Северно-Западный                      9512.39
# Region_Северный и Уральский                 -9761.02
# Region_Уральско-Сибирский                   -2775.92
# Region_Центрально-Чернозёмный               -2190.07
# Region_Центральный                          25172.87
# Region_Южно-Сибирский                       -2118.44
# Region_Южный                                 -588.51
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                   features
# 0   658.508312                      const
# 49   16.797670    Region_Северно-Западный
# 53   16.441554         Region_Центральный
# 2    13.455746                 longtitude
# 45    6.506698       Region_Волго-Камский
# 1     5.550333                   latitude
# 47    4.755641     Region_Дальневосточный
# 51    4.031575  Region_Уральско-Сибирский
# 46    3.535373     Region_Волго-Уральский
# 55    3.446522               Region_Южный
# Тест Уайта:
# {'Test Statistic': 2984.0588281524742, 'Test Statistic p-value': 1.831014023068878e-146, 'F-Statistic': 2.745124951971266, 'F-Test p-value': 8.911454723259249e-171}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Region_Южный
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38561659110139157
# Adj. R-squared: 0.3835507938361036
# AIC: 383504.9494065987
# Коеффициенты при параметрах
# const                                       17186.89
# latitude                                      381.92
# longtitude                                    -28.69
# experience                                  18817.65
# has_test                                    16636.86
# Работа в команде                            -2827.18
# Пользователь ПК                             -7588.86
# Грамотная речь                              -1918.08
# Linux                                        3124.73
# Работа в условиях многозадачности           -4539.77
# SQL                                         13167.14
# Работа с большим объемом информации         -9440.54
# Adobe Photoshop                             -9144.14
# Настройка ПК                                -6032.26
# Грамотность                                 -5620.24
# Управление проектами                        22884.51
# ...
# Работа в команде                            -3050.54
# Пользователь ПК                             -7949.55
# Linux                                        3071.73
# Работа в условиях многозадачности           -4418.69
# SQL                                         13272.07
# Работа с большим объемом информации         -9169.46
# Adobe Photoshop                             -8844.06
# Настройка ПК                                -5941.00
# Грамотность                                 -6404.66
# Управление проектами                        23266.39
# Git                                         25894.00
# Умение работать в команде                   -5326.95
# Настройка сетевых подключений               -4159.51
# Английский язык                             14926.23
# Деловая переписка                           -7874.02
# Ремонтные работы                            -7872.46
# JavaScript                                  16518.93
# Ведение переговоров                         15059.21
# Windows 7                                   -8143.07
# Информационные технологии                   -3842.58
# Техническая поддержка                       -8363.53
# HTML                                        -6730.79
# Точность и внимательность к деталям         -9464.97
# Администрирование сетевого оборудования     -6212.93
# CorelDRAW                                   -9660.65
# Python                                      19275.91
# Креативность                                -4561.18
# Поиск информации в интернет                 -3956.48
# TCP/IP                                      -4090.75
# Монтаж оборудования                         -5174.20
# ООП                                          8305.86
# Информационная безопасность                  5559.02
# PostgreSQL                                  42990.31
# 1С                                          25815.18
# Region_Волго-Уральский                      -4281.68
# Region_Дальневосточный                       8463.66
# Region_Неизвестно                          140269.12
# Region_Северно-Западный                     14953.57
# Region_Центральный                          28897.31
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     6.010497                                    const
# 15    1.910217            Настройка сетевых подключений
# 10    1.805130                             Настройка ПК
# 9     1.631318                          Adobe Photoshop
# 27    1.511949                                CorelDRAW
# 19    1.457043                               JavaScript
# 13    1.394189                                      Git
# 24    1.295651                                     HTML
# 26    1.289772  Администрирование сетевого оборудования
# 5     1.237512                                    Linux
# Тест Уайта:
# {'Test Statistic': 2474.855641452365, 'Test Statistic p-value': 3.516154333082459e-198, 'F-Statistic': 4.037478358743503, 'F-Test p-value': 2.110977021743971e-222}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  TCP/IP
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38471837952263654
# Adj. R-squared: 0.3831872569135104
# AIC: 383500.4918865753
# Коеффициенты при параметрах
# const                                       33959.11
# experience                                  18852.13
# has_test                                    16588.94
# Работа в команде                            -3039.44
# Пользователь ПК                             -7944.88
# Linux                                        2613.64
# Работа в условиях многозадачности           -4411.98
# SQL                                         13277.87
# Работа с большим объемом информации         -9184.64
# Adobe Photoshop                             -8806.78
# Настройка ПК                                -5653.34
# Грамотность                                 -6388.62
# Управление проектами                        23278.92
# Git                                         25976.16
# Умение работать в команде                   -5311.77
# Настройка сетевых подключений               -4707.14
# Английский язык                             14942.29
# Деловая переписка                           -7845.72
# Ремонтные работы                            -7854.02
# JavaScript                                  16564.88
# Ведение переговоров                         15081.79
# Windows 7                                   -8428.29
# Информационные технологии                   -3872.68
# Техническая поддержка                       -8590.89
# HTML                                        -6789.89
# Точность и внимательность к деталям         -9437.08
# Администрирование сетевого оборудования     -6916.57
# CorelDRAW                                   -9657.19
# Python                                      19313.05
# Креативность                                -4558.86
# Поиск информации в интернет                 -3945.57
# Монтаж оборудования                         -5092.75
# ООП                                          8375.71
# Информационная безопасность                  5489.38
# PostgreSQL                                  43012.00
# 1С                                          25845.93
# Region_Волго-Уральский                      -4271.16
# Region_Дальневосточный                       8485.29
# Region_Неизвестно                          140131.96
# Region_Северно-Западный                     14964.16
# Region_Центральный                          28875.95
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     6.007137                                    const
# 15    1.873905            Настройка сетевых подключений
# 10    1.793702                             Настройка ПК
# 9     1.631124                          Adobe Photoshop
# 27    1.511948                                CorelDRAW
# 19    1.456851                               JavaScript
# 13    1.393301                                      Git
# 24    1.295359                                     HTML
# 26    1.250165  Администрирование сетевого оборудования
# 5     1.204004                                    Linux
# Тест Уайта:
# {'Test Statistic': 2462.8566820146566, 'Test Statistic p-value': 2.6970270511765507e-205, 'F-Statistic': 4.2174471258288175, 'F-Test p-value': 4.952672504033259e-230}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Linux
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38460158079377027
# Adj. R-squared: 0.38310854574872877
# AIC: 383501.55070196296
# Коеффициенты при параметрах
# const                                       34002.46
# experience                                  18870.37
# has_test                                    16592.96
# Работа в команде                            -3062.82
# Пользователь ПК                             -7972.42
# Работа в условиях многозадачности           -4448.92
# SQL                                         13299.93
# Работа с большим объемом информации         -9236.39
# Adobe Photoshop                             -8848.09
# Настройка ПК                                -5770.34
# Грамотность                                 -6408.37
# Управление проектами                        23227.49
# Git                                         26433.96
# Умение работать в команде                   -5318.53
# Настройка сетевых подключений               -4703.74
# Английский язык                             15135.93
# Деловая переписка                           -7777.57
# Ремонтные работы                            -7903.38
# JavaScript                                  16364.17
# Ведение переговоров                         15014.28
# Windows 7                                   -8037.56
# Информационные технологии                   -3771.88
# Техническая поддержка                       -8496.64
# HTML                                        -6663.84
# Точность и внимательность к деталям         -9484.51
# Администрирование сетевого оборудования     -6362.73
# CorelDRAW                                   -9684.40
# Python                                      20069.36
# Креативность                                -4584.52
# Поиск информации в интернет                 -3968.41
# Монтаж оборудования                         -5146.23
# ООП                                          8539.01
# Информационная безопасность                  5580.65
# PostgreSQL                                  43444.13
# 1С                                          25771.76
# Region_Волго-Уральский                      -4277.42
# Region_Дальневосточный                       8500.71
# Region_Неизвестно                          140359.89
# Region_Северно-Западный                     14990.56
# Region_Центральный                          28880.86
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     5.999283                                    const
# 14    1.873903            Настройка сетевых подключений
# 9     1.791615                             Настройка ПК
# 8     1.630862                          Adobe Photoshop
# 26    1.511888                                CorelDRAW
# 18    1.452806                               JavaScript
# 12    1.362861                                      Git
# 23    1.293893                                     HTML
# 25    1.223080  Администрирование сетевого оборудования
# 39    1.194473                       Region_Центральный
# Тест Уайта:
# {'Test Statistic': 2365.971594552415, 'Test Statistic p-value': 3.3579530454931086e-200, 'F-Statistic': 4.264625304112679, 'F-Test p-value': 3.623837798340613e-223}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Информационные технологии
# Обучаем модель на оставшихся колонках:
# R-squared: 0.384465048007522
# Adj. R-squared: 0.3830100636721331
# AIC: 383503.1255922225
# Коеффициенты при параметрах
# const                                       33966.60
# experience                                  18868.87
# has_test                                    16575.71
# Работа в команде                            -3064.54
# Пользователь ПК                             -7953.59
# Работа в условиях многозадачности           -4428.68
# SQL                                         13229.77
# Работа с большим объемом информации         -9211.12
# Adobe Photoshop                             -8831.69
# Настройка ПК                                -5891.73
# Грамотность                                 -6402.46
# Управление проектами                        22978.71
# Git                                         26477.90
# Умение работать в команде                   -5319.94
# Настройка сетевых подключений               -4789.01
# Английский язык                             15085.03
# Деловая переписка                           -7775.00
# Ремонтные работы                            -7876.00
# JavaScript                                  16399.11
# Ведение переговоров                         14971.10
# Windows 7                                   -8373.56
# Техническая поддержка                       -8945.10
# HTML                                        -6749.43
# Точность и внимательность к деталям         -9436.28
# Администрирование сетевого оборудования     -6381.09
# CorelDRAW                                   -9668.19
# Python                                      20086.64
# Креативность                                -4535.77
# Поиск информации в интернет                 -4006.22
# Монтаж оборудования                         -5096.68
# ООП                                          8595.87
# Информационная безопасность                  4202.25
# PostgreSQL                                  43449.97
# 1С                                          25766.48
# Region_Волго-Уральский                      -4304.16
# Region_Дальневосточный                       8477.11
# Region_Неизвестно                          140427.69
# Region_Северно-Западный                     15009.97
# Region_Центральный                          28890.54
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     5.994684                                    const
# 14    1.873072            Настройка сетевых подключений
# 9     1.789693                             Настройка ПК
# 8     1.630827                          Adobe Photoshop
# 25    1.511870                                CorelDRAW
# 18    1.452701                               JavaScript
# 12    1.362621                                      Git
# 22    1.293315                                     HTML
# 24    1.223054  Администрирование сетевого оборудования
# 38    1.194403                       Region_Центральный
# Тест Уайта:
# {'Test Statistic': 2332.5940556261944, 'Test Statistic p-value': 3.1787829251144733e-204, 'F-Statistic': 4.429749141957218, 'F-Test p-value': 4.2149245997928844e-227}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Поиск информации в интернет
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3843286392648225
# Adj. R-squared: 0.3829117181758631
# AIC: 383504.69644281815
# Коеффициенты при параметрах
# const                                       33892.94
# experience                                  18911.98
# has_test                                    16543.28
# Работа в команде                            -3084.26
# Пользователь ПК                             -8240.52
# Работа в условиях многозадачности           -4425.73
# SQL                                         13250.32
# Работа с большим объемом информации         -9381.83
# Adobe Photoshop                             -8858.02
# Настройка ПК                                -5839.54
# Грамотность                                 -6855.32
# Управление проектами                        23021.44
# Git                                         26478.97
# Умение работать в команде                   -5295.17
# Настройка сетевых подключений               -4784.70
# Английский язык                             15107.03
# Деловая переписка                           -7746.76
# Ремонтные работы                            -7796.84
# JavaScript                                  16403.87
# Ведение переговоров                         14948.63
# Windows 7                                   -8441.23
# Техническая поддержка                       -9034.00
# HTML                                        -6724.48
# Точность и внимательность к деталям         -9529.90
# Администрирование сетевого оборудования     -6402.83
# CorelDRAW                                   -9604.04
# Python                                      20104.09
# Креативность                                -4592.28
# Монтаж оборудования                         -5067.31
# ООП                                          8606.42
# Информационная безопасность                  4207.38
# PostgreSQL                                  43452.98
# 1С                                          25790.67
# Region_Волго-Уральский                      -4311.08
# Region_Дальневосточный                       8458.31
# Region_Неизвестно                          140442.12
# Region_Северно-Западный                     15031.77
# Region_Центральный                          28881.73
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     5.975268                                    const
# 14    1.873070            Настройка сетевых подключений
# 9     1.789338                             Настройка ПК
# 8     1.630736                          Adobe Photoshop
# 25    1.511587                                CorelDRAW
# 18    1.452699                               JavaScript
# 12    1.362621                                      Git
# 22    1.293266                                     HTML
# 24    1.223018  Администрирование сетевого оборудования
# 37    1.194346                       Region_Центральный
# Тест Уайта:
# {'Test Statistic': 2328.246720777364, 'Test Statistic p-value': 6.340281503890367e-213, 'F-Statistic': 4.673227548877349, 'F-Test p-value': 1.7364818950849554e-236}
# ____________________________________________________________________________________________________________________
