# %% [markdown]
# ## Предобработка данных

# %%
import pandas as pd
import os
import re
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('../../data/final_data.csv')

# %%
df.premium.value_counts()
# Out:
# False    30705
# True        31
# Name: premium, dtype: int64

# %%
df.has_test.value_counts()
# Out:
# False    30413
# True       323
# Name: has_test, dtype: int64

# %%
df.response_letter_required.value_counts()
# Out:
# False    30407
# True       329
# Name: response_letter_required, dtype: int64

# %%
df.experience.value_counts()
# Out:
# От 1 года до 3 лет    17496
# От 3 до 6 лет          8191
# Нет опыта              4363
# Более 6 лет             686
# Name: experience, dtype: int64

# %%
df.skills
# Out:
# 0        Деловая переписка_Грамотная речь_входящие звон...
# 1        Ведение переговоров_Поиск информации в интерне...
# 2        Работа в команде_Работа с большим объемом инфо...
# 3        Asterisk_Linux_Администрирование серверов Linu...
# 4                                                      NaN
#                                ...
# 30731    1C: Предприятие_Высшее образование_Работа в ко...
# 30732                                Умение читать чертежи
# 30733    Выездное обслуживание_Техническое обслуживание...
# 30734    Администрирование сайтов_Настройка сетевых под...
# 30735    Грамотность_Грамотная речь_Adobe Photoshop_Cor...
# Name: skills, Length: 30736, dtype: object

# %%
df.employment.value_counts()
# Out:
# Полная занятость       30735
# Частичная занятость        1
# Name: employment, dtype: int64

# %%
df.city.value_counts().head(15)
# Out:
# Москва             3337
# Санкт-Петербург    2169
# Екатеринбург        755
# Новосибирск         593
# Нижний Новгород     422
# Челябинск           397
# Краснодар           396
# Казань              384
# Красноярск          382
# Пермь               365
# Уфа                 341
# Ростов-на-Дону      333
# Воронеж             294
# Самара              268
# Омск                263
# Name: city, dtype: int64

# %%
df['salary_from'] = df['salary_from'].fillna(0)
df['salary_to'] = df['salary_to'].fillna(0)
df['salary'] = df.loc[:,'salary_from'] + df.loc[:,'salary_to']
df.loc[(df.salary_from != 0) & (df.salary_to != 0), 'salary'] = df.salary / 2

# %%
df.loc[df.gross == False, 'salary'] = df.salary * 0.87

# %%
df.dropna(axis = 0, subset = ['currency', 'gross'], inplace = True)

# %%
df.drop(['salary_from', 'salary_to', 'gross'], axis = 1, inplace = True)

# %%
df.drop('employment', axis = 1, inplace = True)

# %%
df.to_csv('../../data/final_data_salary.csv', index = False)

# %% [markdown]
# ## Гипотезы

# %%
skills = [i.split('_') for i in df.skills.astype(str)]

# %%
skills
# Out:
# [['Деловая переписка',
#   'Грамотная речь',
#   'входящие звонки',
#   'Деловое общение',
#   'Консультирование клиентов по телефону',
#   'уверенный пользователь ПК'],
#  ['Ведение переговоров',
#   'Поиск информации в интернет',
#   'Анализ рынка',
#   'Грамотная речь',
#   'Телефонные переговоры'],
#  ['Работа в команде',
#   'Работа с большим объемом информации',
#   'Аналитические исследования',
#   'MS PowerPoint',
#   'Аналитическое мышление'],
#  ['Asterisk',
#   'Linux',
#   'Администрирование серверов Linux',
#   'MS SQL',
#   'VoIP',
#   '1С: Предприятие 8',
#   'SQL Server',
#   'Локальные сети',
#   'Ремонт ПК',
#   'Администрирование сетевого оборудования',
#   'Монтаж оборудования',
#   'Настройка ПО',
#   'Windows Os',
#   'Windows Server 2003'],
#  ['nan'],
#  ['Грамотная речь'],
#  ['Управление автопарком грузовых автомобилей. Организация технического обслуживания автомобилей'],
#  ['Монтаж оборудования',
#   'Электрические системы и слаботочные системы',
#   'Техническое обслуживание',
#   'Монтаж инженерных систем'],
#  ['1С программирование', '1С: Бухгалтерия', '1С:Бухгалтерия предприятия 3.0'],
#  ['Техническое обслуживание',
#   'Умение работать в команде',
#   'Контроль исправности оборудования',
#   'Навыки составления отчетности'],
#  ['Работа с большим объемом информации',
#   'Работа с документами',
#   'Сбор и анализ информации'],
#  ['Администрирование сетевого оборудования',
#   'Проектирование ЛВС',
#   'Администрирование серверов Windows',
#   'Active Directory',
#   'Linux'],
#  ['Ремонт ПК', 'Настройка ПК', 'Настройка сетевых подключений'],
#  ['Active Directory',
#   'TCP/IP',
#   'Windows 7',
#   'Настройка сетевых подключений',
#   'DHCP'],
#  ['Работа с базами данных',
#   'MS PowerPoint',
#   'Работа в команде',
#   'Подготовка презентаций',
#   'Аналитические исследования'],
#  ['MS Visio',
#   'MS PowerPoint',
#   'BPMN',
#   'Сбор и анализ информации',
#   'Моделирование бизнес процессов'],
#  ['nan'],
#  ['Asterisk',
#   'VoIP',
#   'Cisco',
#   'Администрирование серверов Linux',
#   'Linux',
#   'Администрирование сетевого оборудования',
#   'Networking',
#   'Zabbix',
#   'Proxmox',
#   'Unix Shell Scripts',
#   'OpenVPN',
#   'BGP',
#   'Billing'],
#  ['nan'],
#  ['jQuery', 'Git', 'JavaScript', 'CSS', 'react', 'vue', 'figma', 'js'],
#  ['Adobe Photoshop',
#   'CorelDRAW',
#   'Креативность',
#   'Грамотность',
#   'Ведение групп в социальных сетях'],
#  ['BPMN', 'UML', 'SQL', 'XML', 'PostgreSQL'],
#  ['SQL', 'Git', 'Python'],
#  ['1С: Предприятие 8',
#   'Точность и внимательность к деталям',
#   '1С программирование',
#   '1С: Управление предприятием',
#   '1C: Предприятие'],
#  ['Пользователь ПК',
#   'Умение работать в коллективе',
#   'Поиск информации в интернет',
#   'Навыки работы с первичной документацией',
#   'Оперативный поиск информации в сети Интернет'],
#  ['Управление проектами',
#   'Организаторские навыки',
#   'Ведение переговоров',
#   'Проведение презентаций',
#   'MS PowerPoint'],
#  ['Деловая переписка',
#   'Работа с поставщиками',
#   'Ориентация на результат',
#   'Документооборот',
#   'Деловое общение'],
#  ['Чтение чертежей', 'Станки ЧПУ'],
#  ['Работа с ТМЦ',
#   'Умение работать в команде',
#   'Учет материалов',
#   'Номенклатуры ГСМ',
#   'Планирование запасов'],
#  ['Подготовка презентаций',
#   'SCADA',
#   'АСУ',
#   'Общение с клиентами',
#   'Проведение презентаций',
#   'Деловое общение',
#   'Грамотная речь',
#   'Автоматизация процессов'],
#  ['Управление проектами',
#   'Работа в команде',
#   'Управление командой',
#   'Обучение и развитие'],
#  ['nan'],
#  ['Пожарная безопасность',
#   'Инженерные системы',
#   '3 группа по электробезопасности',
#   'Техническое обслуживание',
#   'Системы видеонаблюдения',
#   'Электрические системы и слаботочные системы',
#   'слаботочные системы',
#   'Контроль исправности оборудования'],
#  ['Пользователь ПК', 'Грамотная речь'],
#  ['Работа в команде', 'Грамотная речь', 'Многозадачность', 'Чистоплотность'],
#  ['nan'],
#  ['Настройка ПК',
#   'Администрирование серверов Windows',
#   'Настройка серверов',
#   'Проектирование ЛВС',
#   'Обеспечение антивирусной защиты',
#   'Настройка сетевых подключений'],
#  ['1С: Зарплата и управление персоналом',
#   '1С: Бухгалтерия',
#   '1С: Предприятие 8',
#   'Бухгалтерский учет',
#   'ERP-системы на базе 1С'],
#  ['Многозадачность', 'Деловая коммуникация', 'MS Excel'],
#  ['Ответственность', 'Работа с оргтехникой', 'Умение работать в команде'],
#  ['1С программирование',
#   '1С: Предприятие 8',
#   'ERP-системы на базе 1С',
#   '1С: Бухгалтерия'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Грамотная речь',
#   'Способность обучать других',
#   'Работа с оргтехникой'],
#  ['nan'],
#  ['Офисные программы',
#   'Работа в условиях многозадачности',
#   'Высокая энергичность и инициативность',
#   'Высокая энергичность',
#   'Опытный пользователь ПК',
#   'Коммуникабельность, стрессоустойчивость'],
#  ['nan'],
#  ['Настройка ПО',
#   'Настройка ПК',
#   'Настройка сетевых подключений',
#   'Windows 7',
#   'Active Directory'],
#  ['nan'],
#  ['nan'],
#  ['XML', 'REST API', 'JSON API', 'PHP', 'Python', 'Java', 'NET', 'C#'],
#  ['Автоматизация',
#   'Автоматизация технологических процессов',
#   'Управление проектами',
#   'Микроэлектроника',
#   'Электронные компоненты',
#   'Подбор оборудования',
#   'Техническая поддержка'],
#  ['nan'],
#  ['Грамотная речь', 'Пользователь ПК'],
#  ['Креативность', 'Adobe Photoshop', 'illustrator', 'Творческий подход'],
#  ['1С: Документооборот',
#   '1C: Предприятие',
#   'Базы данных',
#   'Работа с базами данных',
#   '1С: Зарплата и управление персоналом',
#   '1C: Бухгалтерия',
#   'Умение находить общий язык с людьми',
#   'Альфа-Авто',
#   'Отличное владение ПК',
#   '1С: Предприятие 8'],
#  ['Wireshark', 'Офисные программы', 'Связь'],
#  ['Windows 7',
#   'Настройка сетевых подключений',
#   'Техническое обслуживание',
#   'Настройка ПК',
#   'Настройка ПО'],
#  ['Python',
#   'Английский язык',
#   'Leadership Skills',
#   'Analytical skills',
#   'Data Analysis'],
#  ['Проектирование и монтаж пожарной сигнализации', 'слаботочные системы'],
#  ['nan'],
#  ['Английский язык',
#   'Разработка технических заданий',
#   'Автоматизация процессов',
#   'Бухгалтерский учет',
#   'Налоговый учет',
#   'Управление проектами'],
#  ['Работа в команде',
#   'Грамотная речь',
#   'Контроль качества',
#   'Деловая переписка',
#   '1С: Предприятие 8'],
#  ['Аsyncio', 'Pydantic', 'Sanic', 'Python', 'Git'],
#  ['Работа с людьми',
#   'Организационные навыки',
#   'Фрезеровщик',
#   'Фрезерование поверхностей разной формы'],
#  ['Настройка сетевых подключений',
#   'Настройка ПО',
#   'Настройка ПК',
#   'Администрирование сетевого оборудования'],
#  ['Настройка ПК',
#   'Сборка ПК',
#   'Техническое обслуживание',
#   'Настройка ПО',
#   'Ремонт ПК'],
#  ['Формирование бюджета',
#   'Учет материалов',
#   'Планирование',
#   'Умение принимать решения',
#   'Умение работать с людьми',
#   'Техническая грамотность',
#   'Умение расставлять приоритеты',
#   'Взаимодействие с контролирующими органами'],
#  ['nan'],
#  ['Пользователь ПК',
#   'Умение работать в команде',
#   'Охрана труда и техника безопасности',
#   'Ведение документации'],
#  ['Настройка ПО',
#   'Ремонт ПК',
#   'Техническое обслуживание',
#   'Сборка ПК',
#   'Настройка ПК'],
#  ['Чертежи', 'конструкторская документация', 'составление программ'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Принтер',
#   'CorelDRAW',
#   'Adobe Acrobat'],
#  ['1С программирование',
#   'Моделирование бизнес процессов',
#   'Оптимизация бизнес процессов',
#   'стандартизация бизнес процессов',
#   'Git'],
#  ['nan'],
#  ['Работа в команде',
#   'внимательность к деталям, умение работать с большими объемами информации'],
#  ['1С программирование',
#   'Scrum',
#   'Постановка задач разработчикам',
#   'Teamleading',
#   'КИС',
#   'Альфа-Авто',
#   'Оптимизация кода',
#   '1С: УНФ',
#   '1С: Розница'],
#  ['Пользователь ПК',
#   'Настройка ПК',
#   'Настройка ПО',
#   'Водительское удостоверение категории B',
#   'Техническое обслуживание'],
#  ['C#',
#   'Unity',
#   'Android',
#   'Git',
#   'ООП',
#   'NET Framework',
#   'MVC',
#   'MS Visual Studio',
#   'SQL',
#   'iOS',
#   'Visual Studio C#',
#   'C++',
#   'C/C++',
#   'Computer Vision',
#   'Machine Learning',
#   'Data Science',
#   'Python',
#   'Математическая статистика',
#   'Теория машинного обучения',
#   'scipy',
#   'Deep Learning',
#   'Нейронные сети',
#   'VR',
#   'AR'],
#  ['Настройка сетевых подключений',
#   'Монтаж оборудования',
#   'Настройка ПО',
#   'Монтаж инженерных систем'],
#  ['1С-Битрикс',
#   'Linux',
#   'HTML5',
#   'PHP5',
#   'SQL',
#   'CSS3',
#   'XML',
#   'Ajax',
#   'Bootstrap',
#   'ООП',
#   'SOAP',
#   'REST',
#   'Git',
#   'Битрикс24',
#   'Bitrix24',
#   'Bitrix',
#   'MySQL'],
#  ['Python',
#   'Git',
#   'SQL',
#   'Java',
#   'Hadoop',
#   'Data scientist',
#   'Computer vision'],
#  ['Грамотная речь',
#   'Деловая переписка',
#   'Деловое общение',
#   'Обучение и развитие',
#   'Телефонные переговоры',
#   'Планирование карьеры'],
#  ['nan'],
#  ['Работа в команде',
#   'Навыки составления отчетности',
#   'Оперативный поиск информации в сети Интернет',
#   'Оформление возврата продукции',
#   'Массовое производство'],
#  ['C',
#   'язык С',
#   'ARP',
#   'BFD',
#   'DHCP',
#   'DHCP Server/Relay',
#   'VRRP',
#   'OSPF',
#   'ISIS',
#   'BGP',
#   'Broadcom',
#   'Intel',
#   'Marvel'],
#  ['Грамотная речь', 'Пользователь ПК'],
#  ['Ремонт ПК',
#   'Администрирование сетевого оборудования',
#   'Настройка сетевых подключений',
#   'Windows 7',
#   'Настройка ПО'],
#  ['1С программирование',
#   '1С: Комплексная автоматизация',
#   'XML',
#   '1С: Зарплата и управление персоналом',
#   '1С: Предприятие 8',
#   '1С: Управление предприятием',
#   '1С: Бухгалтерия',
#   '1С: Управление Торговлей',
#   '1С: Розница',
#   '1С: ERP',
#   '1С: Торговля',
#   'Автоматизация документооборота',
#   '1С: Документооборот'],
#  ['Adobe Illustrator', 'Adobe Photoshop', 'Графический дизайн'],
#  ['nan'],
#  ['nan'],
#  ['Техническое обслуживание',
#   'Ремонтные работы',
#   'Диагностика',
#   'Умение работать в команде'],
#  ['Ведение переговоров',
#   'Проведение презентаций',
#   'Управление проектами',
#   'Инженерные системы',
#   'Проектные институты',
#   'Системы канализации и водоснабжения',
#   'Наружные инженерные сети',
#   'Продажа комплексных проектов'],
#  ['Пользователь ПК', 'Работа в команде', 'Умение работать в команде'],
#  ['nan'],
#  ['1С: Управление предприятием',
#   '1C: Предприятие',
#   'ERP',
#   'Консультирование',
#   '1С: Логистика'],
#  ['Знание устройства автомобиля',
#   'Работа в команде',
#   'Автомобильные перевозки'],
#  ['Ремонт ПК',
#   'Техническое обслуживание',
#   '3 группа по электробезопасности',
#   'Техническая эксплуатация',
#   'Работа с ТМЦ'],
#  ['Точность и внимательность к деталям',
#   'Организационные навыки',
#   'системы вентиляции и кондиционирования'],
#  ['Английский язык',
#   'НИОКР',
#   'Готовность к командировкам',
#   'Разработка электросхем',
#   'Разработка проектной документации'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Грамотная речь',
#   'Умение работать в команде'],
#  ['nan'],
#  ['Деловая переписка',
#   '1С: Предприятие 8',
#   'Документальное сопровождение',
#   'Деловое общение',
#   '1С: Документооборот'],
#  ['nan'],
#  ['Ценообразование',
#   'Ведение переговоров',
#   'Планирование продаж',
#   'MS PowerPoint',
#   'Проведение презентаций'],
#  ['Работа в команде',
#   'MS Visio',
#   'Аналитическое мышление',
#   'Atlassian Confluence',
#   'Анализ данных'],
#  ['Java', 'PostgreSQL', 'Spring Framework', 'Git', 'SQL'],
#  ['iOS', 'Git', 'SQL', 'Swift', 'MVC', 'MVP', 'VIPER', 'MVVM'],
#  ['ГОСТ34',
#   'Разработка инструкций',
#   'Техническая документация',
#   'Эксплуатационные документы',
#   'MS Office',
#   'WiKi'],
#  ['Linux',
#   'Kaspersky Labs',
#   'УЦ VipNet',
#   'Системное мышление',
#   'VipNet',
#   'Установка и настройка ПО',
#   'Профессиональный пользователь ПК'],
#  ['Пользователь ПК',
#   'Грамотная речь',
#   'Ведение документации',
#   'Работать в команде',
#   'Работа в условиях многозадачности'],
#  ['Jenkins', 'kafka', 'Docker', 'Linux', 'SQL', 'ООП', 'Ansible'],
#  ['изготовление корпусной мебели', 'кромление'],
#  ['1С: Склад', '1С: Торговля'],
#  ['Грамотная речь',
#   'Грамотность',
#   'Точность и внимательность к деталям',
#   'Администрирование',
#   'Высшее образование'],
#  ['производство',
#   'Станки ЧПУ',
#   'Siemens 828d',
#   'металлообработка',
#   'оператор ЧПУ'],
#  ['Мобильность', 'Ответственность', 'Исполнительность'],
#  ['Системы охранно-тревожной сигнализации', 'Системы видеонаблюдения'],
#  ['Техническое обслуживание',
#   'Информационные технологии',
#   'Техническая грамотность',
#   'уверенный пользователь ПК'],
#  ['nan'],
#  ['TCP/IP'],
#  ['Работа в команде',
#   'Точность и внимательность к деталям',
#   'токарная обработка деталей',
#   'Чтение чертежей'],
#  ['Знание устройства автомобиля', 'Умение работать в команде', 'Мобильность'],
#  ['nan'],
#  ['nan'],
#  ['Фрезеровщик'],
#  ['nan'],
#  ['nan'],
#  ['Администрирование серверов Windows',
#   'Linux',
#   'Администрирование серверов Linux',
#   'Windows 7',
#   'Администрирование сетевого оборудования'],
#  ['nan'],
#  ['HTML', 'CSS', 'Веб-аналитика', 'Bitrix', 'Битрикс'],
#  ['Работа с оргтехникой',
#   'Техническое обслуживание',
#   'Коммуникабельность, ответственность',
#   'Свободное владение компьютером',
#   'Образованность'],
#  ['Администрирование сетевого оборудования',
#   'Аутсорсинг',
#   'Работа с юридическими лицами',
#   'Администрирование',
#   'NAT'],
#  ['Linux',
#   'Active Directory',
#   'Администрирование серверов Windows',
#   'Администрирование сетевого оборудования',
#   'Обеспечение антивирусной защиты'],
#  ['Компас-3D', '1С: Производство', 'производство'],
#  ['1С программирование',
#   'ERP',
#   'ERP-системы на базе 1С',
#   'Работа в режиме многозадачности',
#   'Честный знак'],
#  ['Чтение электросхем',
#   'Linux',
#   'Схемотехника электронного оборудования',
#   'Монтаж оборудования'],
#  ['Деловая коммуникация',
#   'Организаторские навыки',
#   'Организация мероприятий',
#   'Навыки презентации',
#   'Системное мышление',
#   'Широкий кругозор',
#   'GR',
#   'Коммуникативная стратегия',
#   'Организация переговоров с представителями государственных органов',
#   'Создание презентационных материалов о компании',
#   'Высокие коммуникативные навыки',
#   'Знание английского языка',
#   'Деловая этика',
#   'Планирование и организация рабочего процесса',
#   'Высокая ответственность',
#   'Партнерский маркетинг',
#   'Федеральные органы государственной власти'],
#  ['Мобильность',
#   'Стрессоустойчивость',
#   'Инициативность',
#   'Коммуникабельность',
#   'Желание работать',
#   'Дружелюбность',
#   'Пунктуальность',
#   'Собранность'],
#  ['Работа с чертежами', 'Станки ЧПУ'],
#  ['nan'],
#  ['nan'],
#  ['Резка фанеры',
#   'CorelDRAW',
#   'Пользователь ПК',
#   'Деревообработка',
#   'Желание обучаться',
#   'Станки ЧПУ',
#   'Лазерная техника'],
#  ['Металлообработка', 'Массовое производство', 'Желание зарабатывать'],
#  ['Управление проектами',
#   'MS Project',
#   'Организаторские навыки',
#   'Управление рисками',
#   'MS Visio',
#   'Многозадачность',
#   'Планирование',
#   'Контроль исполнения решений',
#   'Проектный менеджмент',
#   'Оптимизация бизнес-процессов',
#   'Бизнес-процессы',
#   'Разработка технических заданий',
#   'Постановка задач разработчикам',
#   'Эффективная коммуникация',
#   'Проектная деятельность',
#   'Ориентация на результат',
#   'Организация бизнес-процессов'],
#  ['Разработка технических заданий',
#   '1С: Предприятие 8',
#   '1С программирование',
#   '1С: Комплексная автоматизация',
#   'Системное мышление'],
#  ['nan'],
#  ['Работа в условиях многозадачности',
#   'Высокая энергичность и инициативность',
#   'Технический склад ума'],
#  ['Работа в команде',
#   'Лояльность',
#   'Умение работать в условиях многозадачности',
#   'Умение работать в коллективе'],
#  ['Работа с большим объемом информации',
#   'Умение работать в коллективе',
#   'Анализ данных',
#   'MC Excel',
#   'Опытный пользователь ПК',
#   'Умение работать в условиях многозадачности'],
#  ['1C: Бухгалтерия',
#   '1С: Зарплата и управление персоналом',
#   '1С: Управление Торговлей',
#   '1С: Розница'],
#  ['nan'],
#  ['Node.js', 'Java', 'Teamleading', 'Team management', 'Blockchain'],
#  ['Мобильность'],
#  ['Станки ЧПУ'],
#  ['Гранд-смета'],
#  ['Офисная техника',
#   'Техническая поддержка',
#   'Настройка ПК',
#   'Администрирование',
#   'Windows 7'],
#  ['Организация внешнего обучения',
#   'Администрирование процесса обучения',
#   'Организация обучения для специалистов',
#   'Организация обучения для производственного персонала',
#   'Работа в команде',
#   'Стрессоустойчивость'],
#  ['nan'],
#  ['nan'],
#  ['Разработка технических заданий',
#   'SQL',
#   'MS SQL',
#   'Ориентация на результат',
#   'MS Excel',
#   'Высшее образование',
#   'Аналитическое мышление',
#   'Быстрое обучение',
#   'Грамотная речь',
#   'Работа в команде',
#   'Деловое общение',
#   'Работа с большим объемом информации',
#   'Деловая коммуникация',
#   'Atlassian Jira',
#   'UML',
#   'Python',
#   'BPMN'],
#  ['Поиск и привлечение клиентов',
#   'Организаторские навыки',
#   'Управление продажами',
#   'Управление проектами',
#   'Выявление потребностей',
#   'Составление и заключение договоров',
#   'Умение вести переговоры',
#   'Мебель',
#   'Сопровождение клиентов',
#   'Аналитическое мышление'],
#  ['Станки ЧПУ', 'fanuc', 'фанук'],
#  ['Фрезерные работы',
#   'Станочные работы',
#   'Работа на станке',
#   'Слесарные работы',
#   'Чтение чертежей',
#   'технологические карты',
#   'Металлообработка',
#   'Умение читать чертежи',
#   'Работа с чертежами',
#   'Чертежи',
#   'Терпеливость',
#   'Работа в команде',
#   'Технический склад ума',
#   'Внимательность',
#   'Восстребованность',
#   'Опыт работы на производстве',
#   'Массовое производство'],
#  ['C++',
#   'Python',
#   'Linux',
#   'Bash',
#   'микросервисы',
#   'многопоточное программирование'],
#  ['Adobe Photoshop',
#   'Управление временем',
#   'Стабильность',
#   'Пакет MS Office',
#   'Грамотная письменная речь',
#   'Ведение социальных сетей'],
#  ['Водительское удостоверение категории BCE'],
#  ['Настройка сетевых подключений', 'Windows 7', 'Настройка ПО', 'Windows Xp'],
#  ['Водительское удостоверение категории BCE'],
#  ['1С программирование',
#   '1С: Управление Торговлей',
#   '1С: Зарплата и управление персоналом',
#   '1С: Предприятие 8',
#   '1С: Розница',
#   '1С: Бухгалтерия',
#   'Обновление конфигурации 1С',
#   '1С: Управление персоналом',
#   'Бухгалтерская отчетность',
#   'MS SQL Server'],
#  ['Работа с большим объемом информации',
#   'Аналитическое мышление',
#   'MS PowerPoint',
#   'Аналитика продаж',
#   'Контроль дебиторской задолженности'],
#  ['ERP Systems', 'BPMN', 'EPC', 'IDEF0', 'Servicedesk', 'Helpdesk'],
#  ['MS Outlook',
#   'Составление договоров',
#   'Транспортная логистика',
#   'Работа с базами данных',
#   'Пользователь ПК'],
#  ['nan'],
#  ['Сборочное производство', 'Сосредоточенность'],
#  ['nan'],
#  ['Linux',
#   'Администрирование сетевого оборудования',
#   'Bash',
#   'Mac Os',
#   'Windows 7'],
#  ['Постановка задач разработчикам',
#   'Разработка технических заданий',
#   'Разработка инструкций',
#   'Бизнес-анализ',
#   'MS Visio'],
#  ['nan'],
#  ['Производство строительно-монтажных работ', 'Мобильность'],
#  ['Станки ЧПУ', 'CAD', 'Металлообработка', 'Работа с чертежами'],
#  ['Металлообработка',
#   'Кинематические схемы',
#   'Контрольно-измерительный инструмент',
#   'ДИП- 300',
#   'Токарная обработка',
#   '7 – 10-му квалитет',
#   '1А64',
#   'Заточка и доводка нормального и специального режущего инструмента'],
#  ['Ремонт телефонов',
#   'Работа в команде',
#   'Диагностика',
#   'Пайка',
#   'Ремонт',
#   'Технический склад ума',
#   'Готовность к командному труду'],
#  ['Cisco',
#   'Active Directory',
#   'Администрирование сетевого оборудования',
#   'Настройка сетевых подключений',
#   'Умение работать в команде',
#   'Точность и внимательность к деталям'],
#  ['Работа в команде',
#   'Умение работать в команде',
#   'Работа с документами',
#   'MS PowerPoint',
#   'Обучение и развитие'],
#  ['Пользователь ПК',
#   'Умение работать в команде',
#   'Чтение чертежей',
#   'Станки ЧПУ',
#   'Металлообработка',
#   'Технический склад ума'],
#  ['Настройка ПО',
#   'Настройка ПК',
#   'Работа с оргтехникой',
#   'Сборка ПК',
#   'Ремонт ПК',
#   'Администрирование сетевого оборудования',
#   'Настройка сетевых подключений',
#   'TCP/IP',
#   'Microsoft Office',
#   'Windows 7',
#   'Microsoft Windows',
#   'Установка ОС',
#   'Офисные программы',
#   'Настройка сетевого оборудования',
#   'Техническая поддержка'],
#  ['1С: Зарплата и управление персоналом',
#   '1С: Предприятие 8',
#   '1С: Бухгалтерия',
#   '1С: Управление Производственным Предприятием',
#   '1С: Документооборот'],
#  ['Active Directory',
#   'Администрирование серверов Windows',
#   'DHCP',
#   'Администрирование сетевого оборудования',
#   'Zabbix'],
#  ['Работа с большим объемом информации',
#   'Работа в команде',
#   'MS PowerPoint',
#   'MS Outlook',
#   'Умение работать в команде'],
#  ['nan'],
#  ['Продвижение бренда',
#   'Запуск новых продуктов',
#   'Маркетинговые коммуникации',
#   'Маркетинговый анализ',
#   'Маркетинговые исследования',
#   'Планирование рекламных кампаний',
#   'Анализ конкурентной среды',
#   'Разработка нового продукта',
#   'Формирование продуктовой линейки',
#   'Развитие'],
#  ['Точность и внимательность к деталям',
#   'Умение планировать',
#   'Умение организовывать работу'],
#  ['Работа в команде',
#   'Английский язык',
#   'Грамотная речь',
#   'Ориентация на результат',
#   'MS PowerPoint'],
#  ['nan'],
#  ['Аккуратность', 'Умение работать головой'],
#  ['Windows 7', 'Windows Os', 'СКУД', 'Trassir', 'MS Dos'],
#  ['Статистический анализ',
#   'Деловая переписка',
#   'Креативность',
#   'Аналитические исследования',
#   'MS PowerPoint',
#   'Эконометрика'],
#  ['Git', 'CSS', 'ООП', 'HTML', 'SVN'],
#  ['Adobe Photoshop',
#   'Adobe Illustrator',
#   'CorelDRAW',
#   'Графический дизайн',
#   'Грамотная речь'],
#  ['Работа в команде', 'Работа в условиях многозадачности'],
#  ['1С программирование',
#   '1С: Зарплата и управление персоналом',
#   '1С: Управление Производственным Предприятием',
#   '1С: Предприятие 8',
#   '1С: Документооборот'],
#  ['Грамотность',
#   'Написание текстов',
#   'Написание статей',
#   'Копирайтинг',
#   'Редактирование'],
#  ['Охрана труда и техника безопасности',
#   'Деловая коммуникация',
#   'Управленческая отчетность',
#   'Контроль исполнения решений',
#   'Расстановка приоритетов',
#   'Обеспечение техники безопасности',
#   'Работа в условиях многозадачности'],
#  ['PHP', 'HTML', 'HTML5', 'Linux', 'Git', 'ООП', 'MySQL', 'CSS', 'SQL'],
#  ['Разработка инструкций',
#   'Написание процедур',
#   '1С: Управление предприятием',
#   'Автоматизированное рабочее место (АРМ)',
#   '1C: Зарплата и кадры',
#   'SQL',
#   'ERP-системы на базе 1С',
#   '1С программирование',
#   'Системное мышление',
#   'Коммуникабельность',
#   'Целеустремленность',
#   'Работа в команде'],
#  ['nan'],
#  ['Пользователь ПК', 'Клиентоориентированность'],
#  ['Пользователь ПК',
#   'Умение работать в команде',
#   'Умение принимать решения',
#   'оформление документации',
#   'Оперативный поиск информации в сети Интернет'],
#  ['Вентиляция и кондиционирование',
#   'системы вентиляции и кондиционирования',
#   'Монтаж инженерных систем',
#   'Монтаж оборудования',
#   'Системы видеонаблюдения',
#   'Электрические системы и слаботочные системы',
#   'Системы охранно-тревожной сигнализации',
#   'Техническое обслуживание',
#   'Системы безопасности'],
#  ['Информационная безопасность',
#   'Технические средства информационной защиты',
#   'Антивирусная защита сети',
#   'Обеспечение антивирусной защиты',
#   'Защита информации',
#   'Администрирование серверов Windows',
#   'Windows Server 2003',
#   'Настройка DNS',
#   'Администрирование серверов',
#   'Администрирование',
#   'Настройка серверов'],
#  ['Пользователь ПК', 'Google Chrome', 'MS Word', 'Умение планировать'],
#  ['MS Office', 'OC Windows'],
#  ['Умение принимать решения',
#   'Умение слушать',
#   'Работа в команде',
#   'Работа в условиях многозадачности',
#   'Умение работать самостоятельно',
#   'Навыки презентации',
#   'Ориентация на результат',
#   'Постановка задач разработчикам',
#   'Проектирование пользовательских интерфейсов',
#   'ServiceDesk',
#   'ITIL',
#   'ITSM'],
#  ['Опыт работы',
#   'Работа в условиях многозадачности',
#   'Работа с компьютером',
#   'Умение работать в условиях многозадачности',
#   'Многовекторность'],
#  ['Linux', 'Bash', 'Python', 'Git', 'Debian'],
#  ['nan'],
#  ['PHP', 'Symfony'],
#  ['Работа с базами данных',
#   'Internet',
#   'MS Access',
#   'Высшее образование',
#   'Работа с ПК'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['1С программирование',
#   '1С: Управление Торговлей',
#   '1С: Зарплата и управление персоналом',
#   '1С: Комплексная автоматизация',
#   '1С: Предприятие 8'],
#  ['Точность и внимательность к деталям', 'токарь'],
#  ['Настройка сетевых подключений',
#   'Техническая поддержка',
#   'Windows 7',
#   'Internet',
#   'Умение работать в условиях многозадачности',
#   'Продвинутый пользователь ПК'],
#  ['Точность и внимательность'],
#  ['Разработка технических заданий',
#   'Аналитическое мышление',
#   'Разработка инструкций',
#   'Анализ данных'],
#  ['SQL', 'Анализ данных', 'MS SQL', 'Аналитическое мышление', 'MS PowerPoint'],
#  ['Базис Мебельщик',
#   'Станки ЧПУ',
#   'Опытный пользовать ПК',
#   'Ответственность и пунктуальность',
#   'Работа в команде'],
#  ['JavaScript',
#   'PHP',
#   'CSS',
#   'MySQL',
#   'HTML',
#   '1С-Битрикс',
#   'CMS MODX',
#   'Bitrix',
#   'MODX'],
#  ['Adobe Photoshop', 'Ретушь', 'Обработка изображений', 'Грамотность'],
#  ['Python', 'Machine Learning', 'Английский язык', 'Tensorflow', 'Java'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['Единичное производство', 'Работа с чертежами', 'Металлообработка', 'вахта'],
#  ['Грамотность',
#   'Мотивация',
#   'Математический склад ума',
#   '1С: Торговля',
#   'Аналитический склад ума',
#   'Аналитика продаж',
#   'Аналитические исследования',
#   'Оптимизация логистических процессов',
#   'Экономический анализ'],
#  ['Умение читать чертежи',
#   'Работа с чертежами',
#   'Ответственный подход к работе',
#   'Стремление к профессиональному развитию',
#   'Работа в условиях многозадачности'],
#  ['Пользователь ПК', 'Умение работать в команде', 'Google Chrome', 'MS Paint'],
#  ['UML',
#   'XML',
#   'SQL',
#   'Разработка проектной документации',
#   'Разработка технических заданий'],
#  ['Информационные технологии', 'SaaS', 'Управление проектами'],
#  ['nan'],
#  ['Сантехнические работы', 'Системы канализации и водоснабжения'],
#  ['Настройка ПК',
#   'Автоматизированное рабочее место (АРМ)',
#   'Ремонт ПК',
#   'Windows 7',
#   '1С: Предприятие 8',
#   'Сборка ПК',
#   'Настройка ПО',
#   'Internet',
#   'TCP/IP',
#   'Локальные сети',
#   'Linux',
#   'Офисные программы',
#   'Техническая поддержка',
#   'Windows Os',
#   'Продвинутый пользователь ПК',
#   'Hardware',
#   'Администрирование Windows',
#   '1C: Предприятие',
#   'SSH',
#   'Установка ПО'],
#  ['Системы видеонаблюдения',
#   'Пользователь ПК',
#   'Прокладка кабелей',
#   'Монтаж оборудования',
#   'Работа в команде',
#   'Электрические системы и слаботочные системы',
#   'Монтаж инженерных систем'],
#  ['Работа с оргтехникой',
#   'Навыки работы с первичной документацией',
#   'Меркурий',
#   'Корпоративная этика',
#   'Знание 1С',
#   '1C: Торговля и склад'],
#  ['nan'],
#  ['Выездное обслуживание',
#   'Техническое обслуживание',
#   'Работа в команде',
#   'Ремонтные работы',
#   'Ориентация на результат',
#   'Диагностика',
#   'Гарантийное обслуживание',
#   'Механик'],
#  ['Умение работать в команде'],
#  ['1С: Торговля и склад',
#   '1С: Документооборот',
#   'Excel',
#   '1C: Предприятие',
#   'Офисные программы'],
#  ['Настройка ПК',
#   'Сборка ПК',
#   'Ремонт ПК',
#   'Настройка ПО',
#   'Настройка сетевых подключений'],
#  ['Уверенный пользователь ПК',
#   'Офисные программы',
#   '1С: Зарплата и управление персоналом',
#   '1С: Бухгалтерия',
#   '1С: Документооборот'],
#  ['nan'],
#  ['Active Directory',
#   'Закупка оргтехники и оборудования',
#   'Сборка ПК',
#   'Windows 7',
#   'Ремонт ПК',
#   'VMware',
#   'MS Exchange',
#   'TCP/IP',
#   'MS SQL',
#   'PowerShell',
#   'Настройка ПК',
#   'Настройка ПО',
#   'Настройка сетевых подключений',
#   'Техническая поддержка',
#   'Офисная техника',
#   'Helpdesk',
#   'Информационные технологии',
#   'Монтаж оборудования',
#   'Работа с оргтехникой',
#   'Диагностика',
#   'Администрирование',
#   'готовность к переезду'],
#  ['Работа в команде',
#   'умение проявлять внимание, заинтересованность, дружелюбие',
#   'Стремление к профессиональному развитию',
#   'Внимательность, ответственность',
#   'Обеспечение техники безопасности'],
#  ['Точность и внимательность к деталям', 'Работа в команде'],
#  ['Работа с базами данных',
#   'СУБД',
#   'MS Access',
#   'Microsoft Access',
#   'Google таблицы'],
#  ['Работа в команде',
#   'Грамотность',
#   'умение проявлять внимание, заинтересованность, дружелюбие',
#   'Работа в условиях многозадачности',
#   'Ответственность и пунктуальность',
#   'Коммуникабельность, ответственность'],
#  ['nan'],
#  ['nan'],
#  ['Английский язык',
#   'Написание текстов',
#   'Написание сценариев',
#   'Работа с большим объемом информации',
#   'Креативность',
#   'Удаленная работа',
#   'Знание английского языка',
#   'Грамотность',
#   'Грамотная письменная речь',
#   'Редактирование текстов'],
#  ['Чтение чертежей',
#   'Станки ЧПУ',
#   'FANUC',
#   'Фрезерные станки',
#   'Металлообработка',
#   'Наладчик станков с ЧПУ'],
#  ['Анализ бизнес показателей',
#   'B2C исследования',
#   'Анализ поведения пользователей',
#   'Статистический анализ',
#   'MS Excel',
#   '1С: CRM ПРОФ'],
#  ['Работа в команде', 'Web-сервис', 'Тестирование'],
#  ['Умение работать в команде',
#   'Internet',
#   'Навыки составления отчетности',
#   'Опыт работы в 1С',
#   'Опытный пользователь ПК',
#   'Работа в условиях многозадачности',
#   'Базовый английский'],
#  ['nan'],
#  ['Автомобильные грузоперевозки',
#   'Автомобильные перевозки',
#   'Знание устройства автомобиля',
#   'Производственное планирование',
#   'Организаторские навыки'],
#  ['Документальное сопровождение'],
#  ['Adobe Illustrator',
#   'CorelDRAW',
#   'Графический дизайн',
#   'Adobe Photoshop',
#   'Графические редакторы'],
#  ['Ремонт ПК',
#   'Настройка ПК',
#   'Настройка ПО',
#   'Выездное обслуживание',
#   'Установка ОС',
#   'Сервисное обслуживание',
#   'Техническое обслуживание',
#   'Работа с банками',
#   'ОС Windows',
#   'Настройка оборудования',
#   'Ремонт оборудования'],
#  ['nan'],
#  ['1С: Зарплата и управление персоналом',
#   '1С: Бухгалтерия',
#   '1С: Предприятие 8',
#   '1С: Управление Торговлей',
#   '1С: Управление Производственным Предприятием',
#   'Бюджетирование',
#   'ERP'],
#  ['Разработка инструкций',
#   'Проведение тестирований',
#   'Базы данных',
#   '1С: Документооборот',
#   'ERP-системы на базе 1С'],
#  ['API', 'SQL', 'Функциональное тестирование', 'JavaScript'],
#  ['Гарантийное обслуживание',
#   'Работа с ПК',
#   'Высшее образование',
#   'Работа в условиях многозадачности',
#   'Работа с компьютером'],
#  ['Мобильность',
#   'Капитальный ремонт помещений',
#   'косметический ремонт помещений',
#   'Ремонтные работы'],
#  ['Критическое мышление', 'АСУ', 'Опытный пользователь ПК'],
#  ['nan'],
#  ['Пользователь ПК',
#   'Грамотная речь',
#   'Поиск информации в интернет',
#   'оформление документации',
#   'Продажа дополнительных услуг и оборудования',
#   'Наличие перфоратора'],
#  ['nan'],
#  ['AutoCAD',
#   'MS Visio',
#   'Статистический анализ',
#   'Экономический анализ',
#   'Автоматизация технологических процессов',
#   'Анализ затрат',
#   'Расчет и анализ себестоимости продукции и услуг',
#   'Складское ПО',
#   'Excel'],
#  ['Умение работать в команде',
#   'Навыки составления отчетности',
#   'Работа с оргтехникой'],
#  ['nan'],
#  ['1С программирование',
#   '1С: Бухгалтерия',
#   'ERP-системы на базе 1С',
#   '1С: ERP',
#   'Налоговая отчетность',
#   'Бухгалтерский учет'],
#  ['Экономика',
#   'Управление проектами',
#   'Разработка технических заданий',
#   'Точность и внимательность к деталям',
#   'Составление отчетности',
#   'Автоматизация процессов'],
#  ['CAD'],
#  ['Умение принимать решения',
#   'Мотивация',
#   'Гибкость',
#   'Материальная ответственность',
#   'Гарантийное обслуживание',
#   'Механик',
#   'Эксплуатационные документы',
#   'Техническая грамотность',
#   'Высшее образование',
#   'Работа с технической документацией',
#   'Улаживание конфликтов',
#   'Претензионная работа с клиентами',
#   'Желание расти и развиваться',
#   'Работа в условиях многозадачности',
#   'Готовность к командировкам',
#   'Умение вести деловую переписку',
#   'Коммуникабельность, ответственность'],
#  ['Проведение тестирований',
#   'Бизнес-анализ',
#   'Должностные инструкции',
#   'Моделирование бизнес процессов',
#   'UML'],
#  ['Грамотная речь',
#   'Поиск информации в интернет',
#   'Internet',
#   'Грамотность',
#   'Корректура текстов',
#   'Высокая скорость печати',
#   'Высшее образование',
#   'Грамотная письменная речь',
#   'Ответственность и пунктуальность'],
#  ['TCP/IP',
#   'Active Directory',
#   'VPN',
#   'VMware',
#   'Hyper-V',
#   'Администрирование',
#   'Администрирование серверов',
#   'Администрирование сетевого оборудования',
#   'Средства защиты от несанкционированного доступа',
#   'Антивирусная защита сети',
#   'Обеспечение антивирусной защиты',
#   'Информационная безопасность',
#   'Защита информации',
#   'Технические средства информационной защиты',
#   'Построение систем защиты информации',
#   'Аттестация объектов информатизации',
#   'Внедрение систем информационной безопасности',
#   'Установка ПО',
#   'Настройка ПО',
#   'НСД "SecretNet"',
#   'НСД Dallas Lock',
#   'Astra Linux',
#   'Alt Linux'],
#  ['Управление проектами',
#   'MS Project',
#   'Ведение переговоров',
#   'Управление отношениями с клиентами'],
#  ['nan'],
#  ['чтение конструкторской документации', 'работа мерительным инструментом'],
#  ['Работа с претензиями', 'Опытный пользователь ПК', 'Excel'],
#  ['Ответственность',
#   'Работа в команде',
#   'технические навыки',
#   'Выездное обслуживание',
#   'Водительское удостоверение категории B'],
#  ['ремонт техники', 'Техническое обслуживание', 'Ведение отчетности'],
#  ['Организаторские навыки',
#   'Управление персоналом',
#   'Ведение переговоров',
#   'Деловая переписка',
#   'Деловое общение',
#   'Заключение договоров',
#   'Управление проектами'],
#  ['nan'],
#  ['Английский язык',
#   'Windows 7',
#   'Грамотность',
#   'Офисная техника',
#   'Windows Os',
#   'PrintServer',
#   'Установка и настройка ПО',
#   'Настройка ПК',
#   'Автоматизированное рабочее место (АРМ)',
#   'WSUS',
#   'GPO',
#   'Service Desk',
#   'Linux',
#   'Диагностика и устранение неполадок АРМ',
#   'видеоконференцсвязь'],
#  ['Разработка технических заданий',
#   'Постановка задач разработчикам',
#   'Бизнес-анализ',
#   'Оптимизация бизнес-процессов',
#   'Управление проектами',
#   'BPMN',
#   'Разработка инструкций',
#   '1С: Бухгалтерия',
#   'Системный анализ'],
#  ['Администрирование серверов Windows',
#   'Настройка сетевых подключений',
#   'Windows 7',
#   'Настройка ПК',
#   'Настройка ПО'],
#  ['Администрирование серверов Linux',
#   'Администрирование серверов Windows',
#   'Mac Os',
#   'iOS',
#   'SIP-телефония',
#   'SIP',
#   'Офисная техника',
#   'Debian',
#   'TCP/IP',
#   'IPTables',
#   'ЭЦП',
#   'VPN'],
#  ['Наполнение контентом',
#   'Написание текстов',
#   'Копирайтинг',
#   'Корректура текстов',
#   'SEO-копирайтинг',
#   'Написание рекламных статей',
#   'Креативность',
#   'CMS',
#   'Грамотность',
#   'Написание статей',
#   'Базовые знания HTML',
#   'Желание учиться и развиваться',
#   'Adobe Photoshop',
#   'CSS'],
#  ['nan'],
#  ['XML', '1С программирование', '1С: Документооборот'],
#  ['Выставочная деятельность',
#   'Английский язык',
#   'Организаторские навыки',
#   'B2B Продажи',
#   'Деловое общение'],
#  ['Работа в команде',
#   'Internet',
#   'Google Chrome',
#   'Планирование карьеры',
#   'обучение сотрудников'],
#  ['Умение работать в коллективе',
#   'Навыки работы с первичной документацией',
#   'Пользователь ПК'],
#  ['nan'],
#  ['Ремонт ПК',
#   'Настройка ПК',
#   'Сборка ПК',
#   'Настройка ПО',
#   'Настройка сетевых подключений'],
#  ['ArchiCAD',
#   '3ds Max',
#   'Adobe Photoshop',
#   'Дизайн интерьера',
#   '3D Моделирование',
#   'Визуализация',
#   'Дизайн',
#   '3D-графика',
#   'CorelDRAW',
#   'Жилая недвижимость',
#   'Элитная недвижимость'],
#  ['1С: Зарплата и управление персоналом', '1С: Бухгалтерия предприятия'],
#  ['Выездное обслуживание',
#   'Техническое обслуживание',
#   'Работа в команде',
#   'Ремонтные работы',
#   'Ориентация на результат',
#   'Диагностика',
#   'Гарантийное обслуживание',
#   'Механик'],
#  ['HTML5', 'CSS3', 'JavaScript', 'Git', 'HTML'],
#  ['nan'],
#  ['Работа в команде', 'Точность и внимательность'],
#  ['Образованность',
#   'Внимательность, ответственность',
#   'Работа с чертежами',
#   'Работа в команде',
#   'Грамотность'],
#  ['Аналитическое мышление',
#   'Инициативность',
#   'CRM',
#   '1С-Битрикс',
#   '1С: Бухгалтерия',
#   '1С: Управление Торговлей',
#   'MS Office',
#   'MS Excel',
#   'Моделирование бизнес процессов'],
#  ['Организаторские навыки',
#   'Руководство коллективом',
#   'Управление проектами',
#   'Управление персоналом',
#   'Многозадачность',
#   'Проектная деятельность',
#   'Работа с проектной документацией',
#   'Способность обучать',
#   'Планирование и организация'],
#  ['HTML5',
#   'CSS3',
#   'React',
#   'TypeScript',
#   'Svelte',
#   'React Native',
#   'Node.js',
#   'Docker',
#   'JavaScript',
#   'Git',
#   'Vue.js'],
#  ['Blockchain', 'Teamplayer', 'GitHub', 'web3', 'Bash', 'etherium', 'evmos'],
#  ['Мобильность',
#   'Настройка сетевых подключений',
#   'TCP/IP',
#   'Настройка ПО',
#   'Настройка ПК'],
#  ['nan'],
#  ['Adobe Photoshop',
#   'CorelDRAW',
#   'оформление документации',
#   'Работа с документами',
#   'CorelDRAW Photo Draw'],
#  ['Gitlab CI', 'Kubernetes', 'Docker', 'DevOps', 'SaaS'],
#  ['nan'],
#  ['nan'],
#  ['Работа с людьми', 'Сосредоточенность', 'Работа с чертежами'],
#  ['Oracle Pl/SQL', 'SQL', 'PostgreSQL', 'Английский язык', 'ORACLE'],
#  ['Стратегическое мышление',
#   'Многозадачность',
#   'Управление временем',
#   'Предпринимательское право',
#   'Проектное управление',
#   'Управленческие навыки',
#   'Управление коллективом от 500 человек'],
#  ['nan'],
#  ['Техническое обслуживание',
#   'Грамотная речь',
#   'Ремонт ПК',
#   'Настройка ПК',
#   'Выездное обслуживание',
#   'Работа с людьми',
#   'Самостоятельное принятие решений и ответственность за них',
#   'Внимательность, ответственность'],
#  ['Java', 'ООП', 'Английский язык'],
#  ['C#',
#   'Visual Studio C#',
#   'СУБД',
#   'MS SQL Server',
#   'Cистемы управления базами данных',
#   'MS SQL',
#   'T-SQL',
#   'Transact-SQL',
#   'Разработка ПО'],
#  ['Пользователь ПК',
#   'Прокладка кабелей',
#   'Монтаж оборудования',
#   'Настройка сетевых подключений'],
#  ['Настройка сетевых подключений', 'Администрирование сетевого оборудования'],
#  ['Работа в команде',
#   'Умение работать в команде',
#   'Навыки составления отчетности',
#   'Internet'],
#  ['Настройка ПК',
#   'Настройка ПО',
#   'Ремонт ПК',
#   'Техническое обслуживание',
#   'Mac Os',
#   'iOS',
#   'Linux',
#   'Helpdesk'],
#  ['nan'],
#  ['Креативность',
#   'Грамотность',
#   'Грамотная речь',
#   'Написание текстов',
#   'Копирайтинг'],
#  ['Техническая поддержка',
#   'Helpdesk',
#   'Управление проектами',
#   'HTML',
#   'Adobe Photoshop',
#   'Информационные технологии',
#   'Заключение договоров',
#   '1С-Битрикс',
#   'Деловое общение',
#   'Менеджер проектов',
#   'Организаторские навыки',
#   'Работа в команде',
#   'Грамотная речь'],
#  ['Рерайтинг',
#   'Написание текстов',
#   'Копирайтинг',
#   'Написание статей',
#   'Грамотность',
#   'SEO-копирайтинг',
#   'Высокая скорость печати',
#   'Написание рекламных статей',
#   'Редактирование',
#   'Наполнение контентом',
#   'Копирайт',
#   'PR-консультирование',
#   'Грамотная письменная речь',
#   'PR',
#   'PR первых лиц компании',
#   'Электронные СМИ',
#   'Федеральные СМИ',
#   'Формирование пула лояльных СМИ',
#   'Деловые СМИ'],
#  ['Поиск информации в интернет',
#   'Точность и внимательность к деталям',
#   'Проведение опросов клиентов',
#   'MS Paint'],
#  ['1С: Комплексная автоматизация',
#   '1С: Управление Торговлей',
#   '1С программирование',
#   '1С: Предприятие 8',
#   'ERP-системы на базе 1С',
#   'Бухгалтерский учет',
#   '1С: ERP',
#   'Создание конфигурации 1С',
#   '1С Бит Финанс',
#   'Бизнес-консультирование'],
#  ['nan'],
#  ['Техническое обслуживание',
#   'Технический контроль производства',
#   'Управление производственным персоналом'],
#  ['1С программирование'],
#  ['nan'],
#  ['Творческие навыки', 'Ответственный подход к работе'],
#  ['AutoCAD',
#   'Строительство',
#   'Управление проектами',
#   'Сопровождение строительства',
#   'Выбор подрядных организаций',
#   'Системы канализации и водоснабжения',
#   'Наружные инженерные сети'],
#  ['PHP', '1С: Предприятие 8', 'ООП', 'Работа с базами данных', 'MS Access'],
#  ['Копирайтинг',
#   'Написание текстов',
#   'SEO-копирайтинг',
#   'Грамотная речь',
#   'Грамотность',
#   'Удаленная работа',
#   'SEO',
#   'Опытный пользователь ПК',
#   'Корректура текстов',
#   'Написание пресс-релизов',
#   'Написание рекламных сценариев',
#   'Работа с большим объемом информации',
#   'Поисковые системы',
#   'Информационные сайты',
#   'Написание статей',
#   'Креативность',
#   'Написание рекламных статей',
#   'Лендинг',
#   'Создание лендингов',
#   'Google Docs',
#   'Грамотная письменная речь',
#   'Многозадачность',
#   'Усердие',
#   'Стабильность',
#   'Умение слушать',
#   'Работа в условиях многозадачности',
#   'Энтузиазм',
#   'Желание расти и развиваться',
#   'Умение организовать работу'],
#  ['Helpdesk',
#   'ServiceDesk',
#   'Microsoft Office',
#   'ВПР',
#   '1С8',
#   'Умение находить общий язык',
#   'Ответственный подход к работе',
#   '1С: Предприятие 8'],
#  ['nan'],
#  ['nan'],
#  ['оформление документации', 'Мобильность', 'Офисная техника'],
#  ['Спортивные мероприятия',
#   'Pascal',
#   'Adobe Acrobat',
#   'Чтение чертежей',
#   'MS Paint'],
#  ['Ремонт ПК', 'Техническое обслуживание', 'Windows 7', 'Ремонтные работы'],
#  ['Должностные инструкции',
#   'ПК',
#   'Работа в условиях многозадачности',
#   'Ответственное отношение к работе',
#   'Внимательность к деталям, способность работать с большими массивами информации'],
#  ['Пользователь ПК',
#   'Поиск информации в интернет',
#   'Грамотность',
#   'Станки ЧПУ',
#   'MS Internet Explorer'],
#  ['ANSYS',
#   'Altium Designer',
#   'MATLAB',
#   'Компас-3D',
#   'Схемотехника электронного оборудования'],
#  ['CorelDRAW',
#   'Adobe Illustrator',
#   'Пользователь ПК',
#   'Графический дизайн',
#   'Adobe Photoshop'],
#  ['Ремонтные работы', 'Ответственность и исполнительность', 'Чтение чертежей'],
#  ['nan'],
#  ['Работа с автомобилями в собственности',
#   'Организация страхования автомобилей',
#   'Работа с автомобилями в лизинге',
#   'Аренда автомобилей',
#   '1С: Документооборот'],
#  ['Токарные работы', 'Умение читать чертежи', 'Точность', 'Аккуратность'],
#  ['Способности к межличностному деловому общению',
#   'Точность и внимательность к деталям',
#   'Знание компьютера',
#   'Работа в условиях многозадачности',
#   'Коммуникабельность, ответственность',
#   'Высокая степень ответственности'],
#  ['Настройка ПО',
#   'Active Directory',
#   'Настройка ПК',
#   'Настройка сетевых подключений',
#   'Администрирование серверов Windows'],
#  ['nan'],
#  ['Работа с большим объемом информации',
#   'Работа с базами данных',
#   'Документооборот',
#   '1С: Предприятие 8',
#   'Первичные документы',
#   'MS Outlook',
#   'Бумажный документооборот',
#   '1С: Склад',
#   '1С: Бухгалтерия и склад',
#   'Уверенный пользователь ПК'],
#  ['CorelDRAW',
#   'Декоратор',
#   'Adobe Photoshop',
#   'Креативность',
#   'Грамотная речь'],
#  ['Active Directory', 'DHCP', 'Cisco', 'Hyper-V', 'TCP/IP'],
#  ['Delphi', 'Ориентация на результат', 'MS Visual Studio'],
#  ['Git',
#   'PostgreSQL',
#   'Оптимизация кода',
#   'Удаленная работа',
#   'Ruby',
#   'Ruby On Rails'],
#  ['Администрирование серверов Linux',
#   'Zabbix',
#   'Nginx',
#   'Debian',
#   'Linux',
#   'Asterisk',
#   'Администрирование сетевого оборудования',
#   'Hyper-V',
#   'Proxmox',
#   'MySQL'],
#  ['Техническое обслуживание',
#   'Выездное обслуживание',
#   'Монтаж оборудования',
#   'Клиентоориентированность',
#   'Офисная техника',
#   'Настройка ПО',
#   'Ремонт ПК',
#   'Настройка ПК',
#   'Ремонтные работы'],
#  ['Windows 7',
#   'Linux',
#   'Настройка сетевых подключений',
#   'Настройка ПО',
#   'Windows Os',
#   'Настройка ПК',
#   'Техническая поддержка'],
#  ['Технические системы и средства безопасности',
#   'Системы видеонаблюдения',
#   'Системы охранно-тревожной сигнализации',
#   'Монтаж оборудования',
#   'слаботочные системы',
#   'Автоматизация',
#   'СКУД'],
#  ['Умение работать в команде',
#   'Поиск информации в интернет',
#   'Управление офисными водителями'],
#  ['Пользователь ПК', 'оформление документации', '1С: Документооборот'],
#  ['Работа в команде',
#   'Организаторские навыки',
#   'Умение работать в режиме многозадачности',
#   'Умение добиваться поставленных целей',
#   'Многозадачность',
#   'Способность быстро обучаться',
#   'Навыки разрешения спорных ситуаций',
#   'Организация и планирование рабочего времени',
#   'Управление персоналом'],
#  ['Автоматизация производства',
#   'SCADA',
#   'АСУ ТП',
#   'Автоматизация технологических процессов',
#   'MS SQL Server',
#   'HMI Weintek',
#   'CODESYS',
#   'SIMATIC',
#   'Modbus',
#   'Profibus',
#   'Profinet'],
#  ['1С программирование',
#   '1С: Предприятие 8',
#   'Обновление конфигурации 1С',
#   '1С: Документооборот',
#   '1С: Зарплата и управление персоналом',
#   '1С: Управление предприятием',
#   'ERP-системы на базе 1С'],
#  ['Git', 'MySQL', 'jQuery', 'PHP7', 'JavaScript', 'Ajax', 'CMS OpenCart'],
#  ['Дизайн интерфейсов', 'Проектирование пользовательских интерфейсов'],
#  ['Cisco',
#   'Active Directory',
#   'VPN',
#   'TCP/IP',
#   'Администрирование сетевого оборудования'],
#  ['Информационная безопасность',
#   'Внедрение систем информационной безопасности',
#   'Внешний аудит информационных систем',
#   'Пользователь ПК',
#   'Составление отчетности',
#   'Уверенный пользователь ПК',
#   'Техническая грамотность'],
#  ['Active Directory',
#   'DHCP',
#   'AD',
#   'DNS',
#   'VPN',
#   'Коммуникабельность',
#   'Стрессоустойчивость',
#   'Тактичность'],
#  ['Пользователь ПК',
#   'Делопроизводство',
#   'Ведение отчетности',
#   'Поиск информации в интернет',
#   'исполнение поручений руководителя'],
#  ['Пользователь ПК', 'Умение работать в команде', 'Ответственность'],
#  ['Проектно-конструкторская деятельность',
#   'Разработка технических заданий',
#   'Деловое общение',
#   'Пользователь ПК',
#   'Работа в команде',
#   'Управление проектами',
#   'Ведение переговоров',
#   'Деловая переписка',
#   'Грамотная речь'],
#  ['Активные продажи',
#   'Телефонные переговоры',
#   'Ведение переговоров',
#   'Холодные продажи',
#   'Деловая переписка',
#   'CRM',
#   'Ориентация на результат',
#   'Работа с возражениями',
#   'Ведение переписки',
#   'Грамотная речь',
#   'Навыки продаж'],
#  ['nan'],
#  ['Английский язык',
#   'Windows Os',
#   'Windows 7',
#   'Креативность',
#   'Автоматизированное рабочее место (АРМ)',
#   'Linux'],
#  ['1С: Предприятие 8',
#   '1С: Зарплата и управление персоналом',
#   '1С программирование',
#   '1С: Документооборот',
#   '1C: Бухгалтерия'],
#  ['1С: Предприятие 8',
#   '1С: Зарплата и управление персоналом',
#   '1С программирование',
#   '1С: Документооборот',
#   '1С: Бухгалтерия'],
#  ['Пользователь ПК', 'Умение принимать решения', 'Умение работать в команде'],
#  ['nan'],
#  ['Монтаж оборудования', 'Мобильность', 'Механик'],
#  ['CorelDRAW', 'lasercut'],
#  ['Администрирование'],
#  ['nan'],
#  ['Деловая коммуникация',
#   'Helpdesk',
#   '1С программирование',
#   'Разработка технических заданий',
#   'Техническая поддержка'],
#  ['HTML', 'CSS', 'JavaScript', 'Git'],
#  ['nan'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Точность и внимательность к деталям'],
#  ['Excel',
#   '1C: Предприятие',
#   'Ответственный подход к работе',
#   'Механик',
#   'Ответственность и пунктуальность'],
#  ['Мобильность',
#   'Работа в команде',
#   'Деловое общение',
#   'Деловая переписка',
#   'Деловая коммуникация',
#   'MS Excel'],
#  ['Настройка ПК', 'Настройка ПО', 'Ремонт ПК'],
#  ['AutoCAD',
#   'Adobe Photoshop',
#   'Управление проектами',
#   'Дизайн интерьера',
#   'Adobe InDesign'],
#  ['3D Max'],
#  ['nan'],
#  ['Работа с документами',
#   'Водительское удостоверение категории BC',
#   'Путевые листы',
#   'ТО автомобилей'],
#  ['Linux',
#   'СУБД',
#   'Настройка DNS',
#   'Администрирование',
#   'Cистемы управления базами данных',
#   'Unix',
#   'Продвинутый пользователь ПК'],
#  ['CUCM',
#   'VoIP',
#   'Разработка инструкций',
#   'Cisco',
#   'SIP',
#   'ISDN',
#   'MGCP',
#   'H.323',
#   'OpenVox'],
#  ['Пользователь ПК',
#   'Организация мероприятий',
#   'Работа в команде',
#   'Организаторские навыки',
#   'Грамотная речь'],
#  ['nan'],
#  ['Ремонт ПК',
#   'Android',
#   'CRM',
#   'Развитие продаж',
#   'Активные продажи',
#   'Пользователь ПК',
#   'Ремонт телефонов',
#   'Ремонт ноутбуков',
#   'Ремонт планшетов',
#   'Ремонт компьютеров',
#   'Продажи аксессуаров',
#   'Общение с клиентами',
#   'Навыки продаж',
#   'Ведение переговоров',
#   'iOS',
#   'Установка ПО'],
#  ['1С: Бухгалтерия',
#   '1С: Зарплата и управление персоналом',
#   '1С: Предприятие 8',
#   '1С программирование'],
#  ['Станки ЧПУ'],
#  ['Учет ТМЦ',
#   '1С: Склад',
#   'Знание устройства автомобиля',
#   'Грузовой транспорт',
#   'Работа с ТМЦ',
#   'Excel'],
#  ['Инженерные системы',
#   'Деловая коммуникация',
#   'Контроль исполнения решений',
#   'Тайм-менеджмент',
#   'Фитнес',
#   'Пожарная безопасность',
#   'Пожарная сигнализация'],
#  ['nan'],
#  ['B2B маркетинг',
#   'Системное мышление',
#   'Умение принимать решения',
#   'Анализ бизнес показателей',
#   'Excel',
#   'Сегментация рынка',
#   'Аналитика продаж',
#   'Конкурентная аналитика'],
#  ['Бюджетирование',
#   'Финансовый анализ',
#   'Государственные структуры',
#   'Планирование',
#   'Финансовое планирование'],
#  ['Информационная безопасность',
#   'Внедрение систем информационной безопасности',
#   'Cisco',
#   'Fortinet',
#   'VPN'],
#  ['Умение работать в коллективе',
#   'Работа в условиях многозадачности',
#   'Работа с компьютером',
#   'Умение работать в условиях многозадачности',
#   'тревизан',
#   'Непрерывное производство'],
#  ['Adobe Photoshop',
# ...
#   'разряд 4-6',
#   'чтение чертежей'],
#  ['Работа в команде'],
#  ['MS PowerPoint', 'Подготовка презентаций', 'Аналитические исследования'],
#  ['Настройка ПК',
#   'Сборка ПК',
#   'Настройка сетевых подключений',
#   'Настройка ПО',
#   'Ремонт ПК'],
#  ['Станки ЧПУ', 'Техническое обслуживание', 'танки с ЧПУ'],
#  ['Пользователь ПК',
#   'Способность обучать других',
#   'Работа в условиях многозадачности',
#   'Высокая трудоспособность',
#   'Работа в команде',
#   'Работа с компьютером',
#   'Коммуникабельность, ответственность'],
#  ['Навыки написания скриптов PowerShell, Python',
#   'Навыки монтажа СКС',
#   'Умение работать с большим объемом информации',
#   'Навыки технической поддержки пользователей',
#   'Опыт установки и настройки пользовательского ПО',
#   'Навыки диагностики, ремонта компьютерной техники',
#   'Навыки учета и инвентаризации компьютерного оборудования',
#   'Умение работать в режиме многозадачности',
#   'Грамотная устная и письменная речь',
#   'Тактичное общение с пользователями',
#   'Инициативность',
#   'Ответственность',
#   'Логическое мышление',
#   'Внимательность'],
#  ['умение свободно общаться с людьми, мобильность'],
#  ['nan'],
#  ['AutoCAD',
#   'Деловая переписка',
#   'Проектная документация',
#   'Графические редакторы'],
#  ['Работа с большим объемом информации',
#   'MS PowerPoint',
#   'Мониторинг цен',
#   'Поиск информации в интернет',
#   'Работа с документами',
#   'Анализ текущей ситуации',
#   '1C: Финансы',
#   'Excel',
#   'Знание программ'],
#  ['Строительство',
#   'Производство строительно-монтажных работ',
#   'оформление документации',
#   'Капитальный ремонт',
#   'Умение работать в условиях многозадачности',
#   'Оперативное принятие решений'],
#  ['nan'],
#  ['AutoCAD',
#   'Схемотехника электронного оборудования',
#   'Чтение электросхем',
#   'SolidWorks',
#   'Английский язык',
#   'С++',
#   'Готовность к командировкам',
#   'Опытный пользователь ПК'],
#  ['Английский язык',
#   'Подготовка презентаций',
#   'подготовка технико-коммерческих предложений',
#   'Проведение презентаций'],
#  ['nan'],
#  ['Монтаж оборудования', 'Грамотность', 'Мобильность', 'Многозадачность'],
#  ['Подготовка коммерческих предложений',
#   'Производственное планирование',
#   '1С: Производство',
#   'Документальное сопровождение',
#   '1С: Документооборот'],
#  ['Чтение чертежей', 'Токарь', 'Фрезеровщик'],
#  ['Техническое обслуживание', 'Электротехнические работы'],
#  ['nan'],
#  ['Linux',
#   'Документальное сопровождение',
#   'Windows 7',
#   'Разработка инструкций',
#   'MS Office'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Организаторские навыки',
#   'Управление персоналом'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Контроль качества',
#   'Сосредоточенность'],
#  ['Работа в команде', 'оформление документации', 'MS Dos', 'Механик'],
#  ['Git',
#   'Kotlin',
#   'Java',
#   'Android SDK',
#   'ООП',
#   'Android',
#   'Design Patterns',
#   'Unit Testing',
#   'API',
#   'Material Design',
#   'Английский язык'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   '1С: Предприятие 8',
#   'Поиск информации в интернет',
#   '1C: Предприятие',
#   'Гарантийное обслуживание',
#   'Техническая грамотность',
#   'Сервис',
#   'Разрешение спорных ситуаций',
#   'Ремонт'],
#  ['1С: Предприятие 8', '1С программирование', 'ERP', 'ERP-системы на базе 1С'],
#  ['AutoCAD',
#   'Проектная документация',
#   'Умение работать в коллективе',
#   'Проектирование',
#   'Умение принимать решения'],
#  ['Управление проектами',
#   'Бизнес-анализ',
#   'Системный анализ',
#   '1C: Финансы',
#   '1С: Управление холдингом',
#   '1С: Управление предприятием',
#   '1С: Управление Производственным Предприятием',
#   'ERP-системы на базе 1С',
#   'ERP',
#   'Kanban',
#   'Разработка технических заданий',
#   'Работа в команде',
#   'Автоматизация процессов',
#   '1С: Документооборот',
#   'Бизнес-моделирование'],
#  ['Linux'],
#  ['Аналитическое мышление',
#   'Грамотная речь',
#   'MS PowerPoint',
#   'Бизнес-анализ',
#   'BPMN'],
#  ['JavaScript', 'CSS', 'HTML', 'ООП', 'Design Patterns'],
#  ['ООП',
#   'Английский язык',
#   'Linux',
#   'Gitlab',
#   'JavaScript',
#   'Vue.js',
#   'Docker-compose',
#   'CRM системы',
#   'SQL',
#   'HTML/CSS'],
#  ['Высокий уровень самоорганизации',
#   'Golang',
#   'Git',
#   'Go',
#   'Kafka',
#   'Работа в команде',
#   'SQL',
#   'MySQL',
#   'Умение работать в условиях многозадачности',
#   'Unit Testing'],
#  ['nan'],
#  ['AutoCAD',
#   'VBA',
#   'Проектная документация',
#   'Разработка проектной документации',
#   'Проектирование',
#   'САПР',
#   'Программирование',
#   'Автоматизация проектирования',
#   'VB',
#   'C#'],
#  ['1С программирование',
#   '1С: Документооборот',
#   '1С: Комплексная автоматизация',
#   'Решение нестандартных задач'],
#  ['C/C++', 'SQL', 'АСУ ТП', 'Микроконтроллеры', 'Python', 'ARM Contex M'],
#  ['nan'],
#  ['Atlassian Jira',
#   'Linux',
#   'Английский язык',
#   'Информационные технологии',
#   'Тестирование'],
#  ['nan'],
#  ['Медицинское оборудование',
#   'Готовность к командировкам',
#   'Высшее образование',
#   'Ремонт',
#   'Английский язык (Intermediate)'],
#  ['Администрирование',
#   'ЭЦП',
#   'КриптоПро',
#   'ПАК "КриптоПро УЦ"',
#   'LAN',
#   'Настройка ПО',
#   'Ремонт ПК',
#   'Работа в команде',
#   'Пользователь ПК',
#   'Настройка ПК',
#   'Работа с оргтехникой',
#   'Консультирование',
#   'Настройка сетевых подключений',
#   'Active Directory',
#   'TCP/IP',
#   'Офисная техника',
#   'Техническое обслуживание'],
#  ['nan'],
#  ['Ремонт ПК',
#   'Пользователь ПК',
#   'Работа в команде',
#   'Техническое обслуживание',
#   'Сборка ПК',
#   'Ремонт смартфонов',
#   'Ремонт планшетов',
#   'Пайка',
#   'Ремонт телевизоров'],
#  ['Администрирование серверов Windows',
#   'Настройка сетевых подключений',
#   'Администрирование сетевого оборудования',
#   'Active Directory',
#   'Настройка ПК'],
#  ['nan'],
#  ['Ведение переговоров', 'Ведение и сдача документации'],
#  ['nan'],
#  ['Пользователь ПК', 'Ремонт бытовой техники'],
#  ['Пользователь ПК',
#   'Деловая переписка',
#   'Деловое общение',
#   'Ведение переписки'],
#  ['Cisco', 'Администрирование сетевого оборудования', 'TCP/IP', 'OSPF', 'BGP'],
#  ['Умение работать в коллективе',
#   'Service Desk',
#   'Продвинутый пользователь ПК',
#   'Телефония',
#   'Сетевые технологии',
#   'MS SQL',
#   'DNS',
#   'Active Directory',
#   'RDP',
#   'DHCP',
#   'Windows Server 2012',
#   'WSUS',
#   'IIS',
#   'Zabbix'],
#  ['1C: Бухгалтерия',
#   '1С: Бухгалтерия',
#   '1С: Зарплата и кадры',
#   'Бухгалтерская отчетность',
#   '1С: Предприятие 8'],
#  ['Adobe Photoshop',
#   'Графический дизайн',
#   'Навыки продаж',
#   'Дизайн интерьера',
#   'Ориентация на клиента'],
#  ['nan'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Контроль качества',
#   'Умение работать в команде'],
#  ['BPMN', 'IDEF', 'Грамотная речь', 'Грамотность', 'Навыки презентации'],
#  ['Строительство ВОЛС', 'Строительство сетей связи'],
#  ['Статистический анализ',
#   'Статистика',
#   'Анализ данных',
#   'Spark',
#   'Big Data',
#   'Коммуникабельность',
#   'Желание заниматься исследовательской работой'],
#  ['Сертификация продукции',
#   'Обучение персонала',
#   'Грамотность',
#   'Многозадачность',
#   'Работа с технической документацией',
#   'Техническая грамотность'],
#  ['Мобильность',
#   'Капитальный ремонт помещений',
#   'косметический ремонт помещений',
#   'Ремонтные работы',
#   'Техническая эксплуатация'],
#  ['Поиск и привлечение клиентов',
#   'Работа в команде',
#   'Активные продажи',
#   'Ведение переговоров',
#   'Навыки продаж'],
#  ['знание электротехники',
#   'возможность выезда в командировки',
#   'опыт работы с оборудованием и программными продуктами фирмы Siemens'],
#  ['Металлообработка',
#   'Желание обучаться',
#   'Контроль качества',
#   'нормативно-техническая документация'],
#  ['Должностные инструкции'],
#  ['Грамотная речь',
#   'Грамотность',
#   'Планирование карьеры',
#   'Расчет премий и бонусов',
#   'Удаленная работа'],
#  ['Желание работать и зарабатывать', 'Ответственность и пунктуальность'],
#  ['Настройка ПК',
#   'Сборка ПК',
#   'Ремонт ПК',
#   'Настройка ПО',
#   'Настройка сетевых подключений'],
#  ['Организаторские навыки',
#   'Руководство коллективом',
#   'Способность обучать других',
#   'принимать решения и за их результаты отвечать самостоятельно',
#   'Работа в условиях многозадачности'],
#  ['Точность и внимательность к деталям', 'Металлообработка'],
#  ['Active Directory',
#   'MS SQL Server',
#   'Работа с базами данных',
#   'Администрирование серверов Windows',
#   'PostgreSQL',
#   'Cистемы управления базами данных',
#   'Администрирование серверов Linux'],
#  ['Мобильность',
#   'Техническое обслуживание',
#   'Выездное обслуживание',
#   'Ремонтные работы',
#   'Диагностика',
#   'Слесарные работы',
#   'Чтение электросхем',
#   'Работа с людьми'],
#  ['Active Directory',
#   'Закупка оргтехники и оборудования',
#   'Сборка ПК',
#   'Windows 7',
#   'Ремонт ПК',
#   'VMware',
#   'MS Exchange',
#   'TCP/IP',
#   'MS SQL',
#   'PowerShell',
#   'Настройка ПК',
#   'Настройка ПО',
#   'Настройка сетевых подключений',
#   'Техническая поддержка',
#   'Офисная техника',
#   'Helpdesk',
#   'Информационные технологии',
#   'Монтаж оборудования',
#   'Работа с оргтехникой',
#   'Диагностика',
#   'Администрирование'],
#  ['Adobe Photoshop',
#   'Adobe Illustrator',
#   'Adobe InDesign',
#   'Креативность',
#   'Дизайн',
#   'маркетплейсы'],
#  ['Умение работать в команде',
#   'MS Visio',
#   'Бизнес-консультирование',
#   'Планирование карьеры',
#   'Консалтинг'],
#  ['Информационные технологии',
#   '1С: Зарплата и управление персоналом',
#   '1С программирование',
#   '1С: Комплексная автоматизация'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['3 группа по электробезопасности',
#   'Автоматизация технологических процессов',
#   'Чтение электросхем',
#   'Компас-3D',
#   'Техническое обслуживание'],
#  ['nan'],
#  ['Atlassian Jira',
#   'Функциональное тестирование',
#   'Тестирование',
#   'Git',
#   'Test case'],
#  ['AutoCAD',
#   'Дизайн интерьера',
#   'Adobe Photoshop',
#   'ArchiCAD',
#   'Строительно-отделочные работы',
#   'V-Ray',
#   'CorelDRAW',
#   'Авторский надзор',
#   'Креативность',
#   'Строительно-отделочные материалы'],
#  ['Работа в команде',
#   'Английский язык',
#   'Грамотность',
#   'Стремление к профессиональному развитию',
#   'Уверенный пользователь ПК (MS Office)',
#   'Готовность обучаться',
#   'Высшее образование',
#   'Работа с базами данных',
#   'Работа с большим объемом информации',
#   'Разработка технических заданий',
#   'Сбор и анализ информации'],
#  ['Умение работать в коллективе', 'Организаторские навыки'],
#  ['1С: Предприятие 8',
#   'Управление персоналом',
#   '1С: Управление Торговлей',
#   '1C: Бухгалтерия',
#   '1С: Торговля',
#   'Аналитическое мышление',
#   'Работа в условиях многозадачности'],
#  ['nan'],
#  ['Высшее образование'],
#  ['Настройка оборудования',
#   'Продвинутый пользователь ПК',
#   'Работа с электроинструментом',
#   'Стремление к профессиональному развитию',
#   'Индивидуальный подход',
#   'Быстрое обучение'],
#  ['nan'],
#  ['1С программирование',
#   '1С: Предприятие 8',
#   '1С: Документооборот',
#   'Альфа-Авто',
#   'Гибкость'],
#  ['1С программирование',
#   '1С: Предприятие 8',
#   '1С: Зарплата и управление персоналом',
#   '1С: Управление Торговлей',
#   'Обновление конфигурации 1С',
#   '1С: CRM ПРОФ',
#   'MS SQL Server',
#   'SQL Server',
#   'СУБД',
#   '1С: Бухгалтерия предприятия',
#   'Контур.Диадок',
#   '1С: ERP',
#   '1С: Документооборот',
#   '1С-Битрикс',
#   'ЭДО',
#   'Битрикс 24',
#   '1С: Комплексная автоматизация'],
#  ['Пользователь ПК',
#   'Выездное обслуживание',
#   'Работа в команде',
#   'Техническое обслуживание'],
#  ['Работа с оргтехникой',
#   'Windows 7',
#   'Локальные сети',
#   'Видеонаблюдение',
#   'MS Windows'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['Знание устройства автомобиля', 'оформление документации', 'Мобильность'],
#  ['Blender 3D',
#   'Substance Painter',
#   'Английский язык',
#   'Adobe Photoshop',
#   '3D Моделирование',
#   'Грамотность',
#   'Работа в команде',
#   'Работа в условиях многозадачности'],
#  ['Ведение документации', 'Выездное обслуживание', 'Сервисное обслуживание'],
#  ['Военный билет (для военнообязанных)'],
#  ['nan'],
#  ['Знание одной или нескольких типовых конфигураций 1С',
#   'Многозадачность',
#   'Коммуникабельность'],
#  ['Сборка КМС',
#   'Монтаж металлоконструкций',
#   'Монтаж оборудования',
#   'Производство строительно-монтажных работ'],
#  ['Работа в команде',
#   'Аналитическое мышление',
#   'Работа с большим объемом информации',
#   'Анализ данных',
#   'MS PowerPoint',
#   'MS Excel',
#   'Яндекс.Метрика',
#   'SQL запросы',
#   'Аналитика'],
#  ['Пользователь ПК',
#   'Знание устройства автомобиля',
#   'Ремонтные работы',
#   'Техническая эксплуатация',
#   'Ведение отчетности',
#   'Организация технического обслуживания автомобилей',
#   'Контроль оформления документов'],
#  ['Пользователь ПК',
#   'Работа в команде',
#   'Ведение документации',
#   'оформление документации'],
#  ['Анализ конкурентной среды',
#   'Поиск информации в интернет',
#   'Конкурентная аналитика',
#   'конкурентный анализ',
#   'маркетинг',
#   'Исследование рынка',
#   'B2B Marketing'],
#  ['Электрика', 'Механик', 'Опыт работы на производстве'],
#  ['Грамотная речь', 'Пользователь ПК'],
#  ['nan'],
#  ['Производство пусконаладочных работ',
#   'Системы видеонаблюдения',
#   'Электрические системы и слаботочные системы',
#   'Монтаж инженерных систем'],
#  ['Работа в команде',
#   'оформление документации',
#   'MS Dos',
#   'Материальная ответственность'],
#  ['Linux', 'C/C++', 'Телеком/передача данных'],
#  ['Ремонт ПК',
#   'Ремонт ККТ',
#   'Настройка ПО',
#   'Выездное обслуживание',
#   'Настройка видеонаблюдения',
#   'Техническая поддержка',
#   'Администрирование сетевого оборудования'],
#  ['Электрические системы и слаботочные системы',
#   'Техническое обслуживание',
#   'работа с технической документацией',
#   'Аварийно-восстановительные работы',
#   'Умение работать самостоятельно',
#   'Пользователь ПК'],
#  ['Confluence',
#   'Bug Tracking Systems',
#   'Test cases',
#   'SQL',
#   'Тестовая документация',
#   'QA',
#   'Selenium IDE'],
#  ['Active Directory',
#   'Закупка оргтехники и оборудования',
#   'Сборка ПК',
#   'Windows 7',
#   'Ремонт ПК',
#   'VMware',
#   'MS Exchange',
#   'TCP/IP',
#   'MS SQL',
#   'PowerShell',
#   'Настройка ПК',
#   'Настройка ПО',
#   'Настройка сетевых подключений',
#   'Техническая поддержка',
#   'Офисная техника',
#   'Helpdesk',
#   'Информационные технологии',
#   'Монтаж оборудования',
#   'Работа с оргтехникой',
#   'Диагностика',
#   'Администрирование',
#   'готовность к переезду'],
#  ['1С: Предприятие 8',
#   'ERP-системы на базе 1С',
#   'Разработка технических заданий',
#   'ERP',
#   '1C ERP',
#   'Постановка задач разработчикам',
#   'Анализ бизнес-процессов',
#   'Деловая переписка'],
#  ['Ремонт ПК',
#   'Настройка ПК',
#   'Настройка ПО',
#   'Поиск информации в интернет',
#   '1С: Предприятие 8',
#   'Администрирование серверов Windows',
#   'Настройка сетевых подключений',
#   'Администрирование сетевого оборудования',
#   'Системы видеонаблюдения',
#   'Онлайн кассы'],
#  ['Laravel', 'MySQL', 'PHP', 'Scrum'],
#  ['Управление проектами',
#   'SAP ERP',
#   'Системный анализ',
#   'Автоматизация',
#   'Системное мышление'],
#  ['опыт работы на деревообрабатывающих станках',
#   'кромление',
#   'услуги цеха распила',
#   'раскрой ЛДСП, МДФ',
#   'опыт на мебельном производстве'],
#  ['Обучение и развитие',
#   'MS Access',
#   'MS CRM',
#   '1C: Предприятие',
#   'Умение адаптироваться'],
#  ['nan'],
#  ['ПЛИС',
#   'Verilog HDL',
#   'FPGA',
#   'Ethernet',
#   'САПР',
#   'Gowin EDA',
#   'Vivado',
#   'Git',
#   'Python',
#   'C'],
#  ['Металлообработка'],
#  ['Adobe Illustrator',
#   'Adobe Photoshop',
#   'Графический дизайн',
#   'Figma',
#   'Web-дизайн'],
#  ['1С: Зарплата и управление персоналом',
#   '1С: Предприятие 8',
#   '1С: Бухгалтерия',
#   'Тестирование',
#   '1С: Документооборот'],
#  ['nan'],
#  ['nan'],
#  ['nan'],
#  ['1С программирование',
#   '1С: Предприятие 8',
#   '1С: Бухгалтерия',
#   '1С: Управление Торговлей',
#   '1С: Розница'],
#  ['MySQL',
#   'Git',
#   'Linux',
#   'REST',
#   'SOAP',
#   'Python',
#   'Django Framework',
#   'RESTful'],
#  ['Работоспособность', 'Ответственность'],
#  ['1С программирование',
#   '1С: Документооборот',
#   '1С: Зарплата и управление персоналом',
#   'Пользователь ПК'],
#  ['Ведение документации',
#   'Многозадачность',
#   'Работа в условиях многозадачности',
#   'Многофункциональный комплекс',
#   'Работа с чертежами'],
#  ['Знание устройства автомобиля',
#   'Техническое обслуживание',
#   'Мобильность',
#   'Расстановка приоритетов'],
#  ['nan'],
#  ['Грамотная речь',
#   'Работа в команде',
#   'Обучение и развитие',
#   'Деловое общение',
#   'Клиентоориентированность',
#   'Работа с большим объемом информации',
#   'Поддержка пользователей'],
#  ['nan'],
#  ...]

# %%
skills = pd.Series([item for sublist in skills for item in sublist]).value_counts()

# %%
skills[skills.index.str.contains('анали', flags=re.IGNORECASE)].head(30)
# Out:
# Аналитическое мышление                 720
# Анализ данных                          299
# Бизнес-анализ                          261
# Анализ рынка                           168
# Аналитические исследования             138
# Сбор и анализ информации               118
# Аналитика                              115
# Системный анализ                       103
# Статистический анализ                   95
# Аналитические способности               92
# Маркетинговый анализ                    78
# Аналитический склад ума                 71
# Анализ бизнес показателей               70
# Анализ конкурентной среды               64
# Аналитика продаж                        59
# SWOT анализ                             43
# Конкурентная аналитика                  43
# Анализ ассортиментной линейки           42
# Экономический анализ                    42
# Аналитические навыки                    38
# Анализ продаж                           35
# Системы канализации и водоснабжения     34
# Умение анализировать                    32
# Анализ поведения пользователей          29
# Анализ финансовых показателей           28
# Анализ текущей ситуации                 28
# Финансовый анализ                       27
# Математический анализ                   26
# Анализ бизнес-процессов                 26
# ABC-анализ                              18
# dtype: int64

# %%
skills[skills.index.str.contains('SAP', flags=re.IGNORECASE)].head(60)
# Out:
# SAP             18
# SAP ERP         15
# Работа в SAP     6
# SAP CRM          5
# SAP FI           5
# SAP HANA         3
# sapr             3
# SAP BW           3
# SAP CO           2
# SAP EWM          2
# My SAP ERP       1
# SAP FI AA        1
# SAP FI-AA        1
# SAP HR           1
# SAP BO           1
# dtype: int64

# %%
skills[skills.index.str.contains('angular', flags=re.IGNORECASE)].head(60)
# Out:
# AngularJS           56
# Angular             42
# angular              3
# Angular Material     2
# Angular2             2
# angular 2            2
# dtype: int64

# %%
skills[skills.index.str.contains('react', flags=re.IGNORECASE)].head(60)
# Out:
# React           142
# ReactJS          31
# React.js         26
# React Native     23
# react            19
# React/Redux      12
# react-native      4
# React JS          3
# React.JS          2
# react native      2
# React-saga        1
# dtype: int64

# %%
skills[skills.index.str.contains('node', flags=re.IGNORECASE)].head(60)
# Out:
# Node.js    129
# NodeJS       5
# Node         2
# dtype: int64

# %%
skills[skills.index.str.contains('образование', flags=re.IGNORECASE)].head(60)
# Out:
# Высшее образование                425
# Ценообразование                    52
# Постоянное самообразование          7
# Техническое образование             6
# Командообразование                  4
# Наука,образование                   3
# Образование                         2
# самообразование                     2
# техническое образование             2
# Инженерное образование              2
# Высшее техническое образование      1
# высшее образование                  1
# dtype: int64

# %%
skills[skills.index.str.contains('безопас', flags=re.IGNORECASE)].head(60)
# Out:
# Информационная безопасность                                                               458
# Технические системы и средства безопасности                                               140
# 3 группа по электробезопасности                                                           140
# Охрана труда и техника безопасности                                                       107
# Внедрение систем информационной безопасности                                               85
# Системы безопасности                                                                       79
# Аудит безопасности                                                                         74
# Обеспечение техники безопасности                                                           56
# Пожарная безопасность                                                                      56
# Безопасность                                                                               46
# Системы пожарной безопасности                                                              38
# Компьютерная безопасность                                                                   8
# Организация безопасной эксплуатации оборудования                                            7
# Безопасность дорожного движения                                                             6
# Построение системы пожарной безопасности с «0»                                              5
# Обеспечение внутренней безопасности                                                         5
# Правила безопасности                                                                        5
# 4 группа по электробезопасности                                                             4
# 2 группа по электробезопасности                                                             4
# 1 группа по электробезопасности                                                             4
# Знание техники безопасности на производстве                                                 3
# Экологическая безопасность                                                                  3
# Моделирование угроз безопасности                                                            3
# Соблюдение техники безопасности                                                             3
# Безопасность дорожного двидения                                                             3
# основные понятия и определения в сфере информационной безопасности и защиты информации      2
# безопасность КИИ                                                                            2
# ПНР систем безопасности                                                                     2
# Монтаж систем безопасности                                                                  2
# расследования инцидентов информационной безопасности                                        1
# разрабатывать модели угроз информационной безопасности                                      1
# Сканеры безопасности                                                                        1
# Безопасное вождение                                                                         1
# Паспорт обеспечения транспортной безопасности ОТИ и ТС                                      1
# План обеспечения транспортной безопасности ОТИ                                              1
# Знание законодательства в области обеспечения транспортной безопасности                     1
# Знание нормативных документов по пожарной безопасности                                      1
# Вводный инструктаж о мерах пожарной безопасности                                            1
# Промышленная безопасность                                                                   1
# безопасность дорожного движения                                                             1
# Код безопасности                                                                            1
# Знание Правил устройства и безопасной эксплуатации грузоподъемных кранов,                   1
# Вводный инструктаж по охране труда и технике безопасности                                   1
# разработка инструкций по пожарной безопасности                                              1
# 5 группа по электробезопасности                                                             1
# Безопасность пассажирских перевозок                                                         1
# dtype: int64

# %%
skills[skills.index.str.contains('английс', flags=re.IGNORECASE)].head(60)
# Out:
# Английский язык                         1089
# Знание английского языка                  34
# Английский язык (Upper-Intermediate)       6
# Английский — B2 — Средне-продвинутый       5
# Разговорный английский                     4
# Владение английским языком                 3
# Английский — B1 — Средний                  3
# Технический английский язык                3
# Английский язык pre-intermediate           3
# Технический английский                     2
# Свободное владение английским языком       2
# Английский язык (Intermediate)             2
# Базовый английский                         2
# Английский                                 2
# Английский язык С1                         1
# Английский(технический)                    1
# Английский -B1- Средний                    1
# Английский - B2 - Средне-продвинутый       1
# Английский — A1 — Начальный                1
# dtype: int64

# %%
skills[skills.index.str.contains('mach', flags=re.IGNORECASE)].head(60)
# Out:
# Machine Learning    28
# mach3                1
# Mach 3               1
# dtype: int64

# %%
names = df.name.value_counts()

# %%
names.head(50)
# Out:
# Системный администратор                       1114
# Токарь                                         795
# Программист 1С                                 628
# Фрезеровщик                                    505
# Механик                                        408
# Токарь-универсал                               406
# Сервисный инженер                              269
# Инженер-программист                            247
# Графический дизайнер                           218
# Специалист технической поддержки               217
# Главный механик                                209
# Оператор станков с ЧПУ                         207
# Оператор 1C                                    200
# Инженер-механик                                193
# Программист 1C                                 179
# Токарь-расточник                               175
# Дизайнер                                       165
# Монтажник слаботочных систем                   149
# Оператор станка с ЧПУ                          140
# Аналитик                                       139
# Инженер технической поддержки                  125
# Программист                                    123
# Руководитель проекта                           121
# Специалист по информационной безопасности      100
# Шлифовщик                                       93
# Компьютерный мастер                             86
# Наладчик станков с ЧПУ                          85
# Оператор станков с программным управлением      83
# Ведущий программист 1С                          75
# Механик по транспорту                           75
# Инженер-программист АСУ ТП                      74
# Менеджер проектов                               74
# Frontend-разработчик                            73
# Системный аналитик                              70
# Бизнес-аналитик                                 70
# Ведущий системный администратор                 69
# Токарь-карусельщик                              67
# Инженер по гарантии                             66
# Технический специалист                          65
# Токарь-фрезеровщик                              65
# Помощник системного администратора              65
# Инженер слаботочных систем                      62
# Менеджер проекта                                62
# Ведущий инженер-программист                     59
# Маркетолог-аналитик                             59
# Техник                                          58
# Разработчик 1С                                  57
# Оператор телефонной поддержки Директа           56
# Руководитель проектов                           55
# Консультант 1С                                  55
# Name: name, dtype: int64

# %%
names[names.index.str.contains('системный адми', flags=re.IGNORECASE)].head(60)
# Out:
# Системный администратор                                                                   1114
# Ведущий системный администратор                                                             69
# Старший системный администратор                                                             39
# Младший системный администратор                                                             30
# Системный администратор Linux                                                               29
# Системный администратор Windows                                                              8
# Сервисный инженер/Системный администратор/Выездной технический специалист                    6
# Системный администратор (на сезон)                                                           6
# Системный администратор (инженер)                                                            6
# Ведущий программист (системный администратор)                                                6
# Программист (системный администратор)                                                        5
# Системный администратор, о. Шикотан                                                          5
# Территориальный системный администратор                                                      4
# Системный администратор, Эникей (Программист)                                                4
# Системный администратор 1С                                                                   4
# Системный администратор (администратор безопасности)(4604)                                   3
# Системный администратор Linux / DevOps инженер                                               3
# Системный администратор Ohana Мытищи (м.Медвдеково)                                          3
# Системный администратор / Программист / IT-специалист                                        3
# Инженер технической поддержки/Специалист технической поддержки/Системный администратор       3
# Начинающий системный администратор/специалист Linux                                          3
# Системный администратор/специалист технической поддержки                                     3
# Системный администратор/специалист по компьютерным сетям и системам                          3
# Системный администратор/IT-специалист в МФЦ (ст. Динская)                                    3
# Специалист технической поддержки/Системный администратор                                     3
# Системный администратор / сетевой администратор (Linux/Windows, облачный провайдер)          3
# Системный администратор первой линии поддержки                                               3
# Системный администратор – программист 1С                                                     3
# Системный администратор.                                                                     3
# Специалист отдела информационных технологий (системный администратор)                        3
# Специалист (системный администратор)                                                         3
# Инженер - электроник 1 кат. (системный администратор, ИТ-специалист) БТС и Э                 3
# Системный администратор/IT-Специалист                                                        3
# Системный администратор/специалист техподдержки (ночные смены)                               3
# Системный администратор (программист)                                                        3
# Системный администратор 1-С                                                                  3
# Системный администратор (г. Красноярск, ул.Солнечная, д. 1)                                  3
# Системный администратор 1 категории                                                          3
# Системный администратор\ IT-специалист                                                       3
# Системный администратор (пос.Волово)                                                         3
# Системный администратор / IT менеджер                                                        3
# Системный администратор (junior)                                                             3
# Специалист технической поддержки (системный администратор)                                   3
# Системный администратор / Помощник системного администратора                                 3
# Системный администратор Windows/Linux                                                        3
# Территориальный Системный администратор                                                      3
# Специалист технической поддержки/системный администратор                                     3
# Системный администратор (Инженер-электронщик)                                                2
# Системный администратор (IT, защита информации)                                              2
# Ассистент руководителя / системный администратор                                             2
# Главный системный администратор                                                              2
# Системный администратор/Старший инженер                                                      2
# Старший системный администратор / Менеджер ИТ Проектов                                       2
# Специалист по IT/Системный администратор                                                     2
# Системный администратор / Технический специалист                                             2
# Системный администратор (главный специалист)                                                 2
# IT специалист / системный администратор                                                      2
# Системный администратор Linux (DevOps)                                                       2
# Системный администратор (Усады, Высокогорский р-н)                                           2
# Системный администратор Ауди Витебский                                                       2
# Name: name, dtype: int64

# %%
names[names.index.str.contains('тока', flags=re.IGNORECASE)].sum()
# Out:
# 2266

# %%
names[names.index.str.contains('фрезе', flags=re.IGNORECASE)].sum()
# Out:
# 1016

# %%
df.skills = df.skills.astype(str)
df.name = df.name.astype(str)

# %%
js_skills = df[df.skills.str.contains('Javascri', flags=re.IGNORECASE)]

# %%
js_skills.shape
# Out:
# (822, 17)

# %%
import numpy as np

# %%
js_skills['salary_from'] = js_skills['salary_from'].fillna(0)
js_skills['salary_to'] = js_skills['salary_to'].fillna(0)
js_skills['salary'] = js_skills.loc[:,'salary_from'] + js_skills.loc[:,'salary_to']
js_skills.loc[(js_skills.salary_from != 0) & (js_skills.salary_to != 0), 'salary'] = js_skills.salary / 2

js_skills.groupby("experience").agg({"salary": [np.mean, 'count']}).round(0)
# Out:
# C:\Users\Denis\AppData\Local\Temp\ipykernel_484\3147198672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   js_skills['salary_from'] = js_skills['salary_from'].fillna(0)
# C:\Users\Denis\AppData\Local\Temp\ipykernel_484\3147198672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   js_skills['salary_to'] = js_skills['salary_to'].fillna(0)
# C:\Users\Denis\AppData\Local\Temp\ipykernel_484\3147198672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   js_skills['salary'] = js_skills.loc[:,'salary_from'] + js_skills.loc[:,'salary_to']
#                       salary
#                         mean count
# experience
# Более 6 лет         245289.0    19
# Нет опыта            73667.0    51
# От 1 года до 3 лет  103065.0   475
# От 3 до 6 лет       156201.0   277

# %%
js_skills.shape
# Out:
# (822, 18)

# %%
ones_skills = df[df.skills.str.contains('1с', flags=re.IGNORECASE)]

# %%
ones_skills.shape
# Out:
# (2950, 17)

# %%
ones_skills['salary_from'] = ones_skills['salary_from'].fillna(0)
ones_skills['salary_to'] = ones_skills['salary_to'].fillna(0)
ones_skills['salary'] = ones_skills.loc[:,'salary_from'] + ones_skills.loc[:,'salary_to']
ones_skills.loc[(ones_skills.salary_from != 0) & (ones_skills.salary_to != 0), 'salary'] = ones_skills.salary / 2

ones_skills.groupby("experience").agg({"salary": [np.mean, 'count']}).round(0)
# Out:
# C:\Users\Denis\AppData\Local\Temp\ipykernel_484\2360568520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ones_skills['salary_from'] = ones_skills['salary_from'].fillna(0)
# C:\Users\Denis\AppData\Local\Temp\ipykernel_484\2360568520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ones_skills['salary_to'] = ones_skills['salary_to'].fillna(0)
# C:\Users\Denis\AppData\Local\Temp\ipykernel_484\2360568520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ones_skills['salary'] = ones_skills.loc[:,'salary_from'] + ones_skills.loc[:,'salary_to']
#                       salary
#                         mean count
# experience
# Более 6 лет         166527.0    73
# Нет опыта            59239.0   207
# От 1 года до 3 лет   93770.0  1747
# От 3 до 6 лет       133308.0   923

# %%
df[df.skills.str.contains('английс', flags=re.IGNORECASE)]['salary'].mean()
# Out:
# 93191.9803883495

# %%
df[~df.skills.str.contains('английс', flags=re.IGNORECASE)]['salary'].mean()
# Out:
# 72110.09955325475

# %%
tokar = df[df.name.str.contains('токар', flags=re.IGNORECASE)]

# %%
tokar.groupby("experience").agg({"salary": [np.mean, 'count']}).round(0)
# Out:
#                      salary
#                        mean count
# experience
# Более 6 лет         71205.0    59
# Нет опыта           51878.0   176
# От 1 года до 3 лет  61459.0  1347
# От 3 до 6 лет       63702.0   684

# %%
freze = df[df.name.str.contains('механи', flags=re.IGNORECASE)]

# %%
freze.groupby("experience").agg({"salary": [np.mean, 'count']}).round(0)
# Out:
#                      salary
#                        mean count
# experience
# Более 6 лет         72169.0    36
# Нет опыта           44524.0   154
# От 1 года до 3 лет  56255.0  1261
# От 3 до 6 лет       69127.0   868

# %% [markdown]
# ## Анализ качественных признаков

# %%
df = pd.read_csv('../../data/final_data_salary.csv')

# %%
df.isna().sum()
# Out:
# premium                         0
# name                            0
# response_letter_required        0
# city                        10502
# latitude                    10367
# longtitude                  10367
# raw                          9886
# experience                      0
# schedule                        0
# skills                       5989
# has_test                        0
# employer                        0
# currency                        0
# salary                          0
# dtype: int64

# %%
df.describe()
# Out:
#            latitude    longtitude         salary
# count  20272.000000  20272.000000   30639.000000
# mean      54.683699     50.353548   73089.764381
# std        5.985706     23.390196   50047.255734
# min        0.000000   -117.780920      31.320000
# 25%       54.172901     37.539401   41760.000000
# 50%       55.747115     39.764932   60000.000000
# 75%       56.836101     56.377491   87000.000000
# max       69.496790    158.679625  522000.000000

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Города

# %% [markdown]
# В большом количестве(10 тысяч) вакансий город не указан. Такие значения мы заполним категорией "Неизвестно". Города, которые попадаются меньше трех раз мы объеденим в одну категорию "Другие", т.к. в таком случае эта категория получается не такой большой по сравнению с другими категориями.

# %%
rare_cat = df['city'].value_counts()

# %%
df.loc[df.city.isin(rare_cat[rare_cat < 3].index), 'city'] = 'Другие'

# %%
df['city'].fillna('Неизвестно', inplace=True)

# %%
df['city'].value_counts()[:20]
# Out:
# Неизвестно         10502
# Москва              3320
# Санкт-Петербург     2161
# Другие               784
# Екатеринбург         755
# Новосибирск          591
# Нижний Новгород      422
# Краснодар            396
# Челябинск            396
# Казань               384
# Красноярск           380
# Пермь                365
# Уфа                  341
# Ростов-на-Дону       333
# Воронеж              293
# Самара               268
# Омск                 260
# Владивосток          242
# Ижевск               239
# Барнаул              219
# Name: city, dtype: int64

# %%
sns.countplot(x ='city', data = df)
 
# Show the plot
plt.show()

# %% [markdown]
# ## Сопроводительное письмо

# %% [markdown]
# Данная переменная очень сильно не сбалансирована и вакансии, для которых сопроводительное письмо обязательно для ~1% вакансий.

# %%
df.response_letter_required.value_counts()
# Out:
# False    30311
# True       328
# Name: response_letter_required, dtype: int64

# %%
df.response_letter_required = df.response_letter_required.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
from matplotlib.pyplot import figure

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.response_letter_required.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость сопроводительного письма', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()}) 
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ## Премиум

# %% [markdown]
# Переменная так же очень несбалансирована с ~0.1% вакансий являющихся эксклюзивными для премиум пользователей

# %%
df.isna().sum()
# Out:
# premium                         0
# name                            0
# response_letter_required        0
# city                            0
# latitude                    10367
# longtitude                  10367
# raw                          9886
# experience                      0
# schedule                        0
# skills                       5989
# has_test                        0
# employer                        0
# currency                        0
# salary                          0
# dtype: int64

# %%
df.premium.value_counts()
# Out:
# False    30608
# True        31
# Name: premium, dtype: int64

# %%
df.premium = df.premium.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.premium.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость наличия премиум аккаунта', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ## График работы

# %% [markdown]
# График работы имеет сильный дисбаланс, так как подавляющее большинство технических вакансий требуют полный 8 часовой рабочий день, лишь малая часть предлагает удаленную работу

# %%
df.schedule.value_counts()
# Out:
# Полный день         30609
# Удаленная работа       22
# Сменный график          5
# Вахтовый метод          2
# Гибкий график           1
# Name: schedule, dtype: int64

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.schedule.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('График работы', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ## Работодатель

# %%
df.employer.value_counts()
# Out:
# Ростелеком                 370
# Калашников                 120
# Первый Бит                 117
# МАГНИТ, Розничная сеть     100
# Группа компаний Система     90
#                           ...
# ВПК-Полимеры                 1
# Mekashron                    1
# МИТ КИНГ                     1
# НЦК                          1
# Панацея                      1
# Name: employer, Length: 11322, dtype: int64

# %%
rare_employer = df['employer'].value_counts()

# %%
rare_employer[rare_employer < 2]
# Out:
# Таганрогская Кондитерская Фабрика                   1
# Ювента                                              1
# Петербургская строительная компания Северо-Запад    1
# ПКФ Стройторг                                       1
# Ginza Project                                       1
#                                                    ..
# ВПК-Полимеры                                        1
# Mekashron                                           1
# МИТ КИНГ                                            1
# НЦК                                                 1
# Панацея                                             1
# Name: employer, Length: 5126, dtype: int64

# %%
df.loc[df.employer.isin(rare_employer[rare_employer < 2].index), 'employer'] = 'Другие'

# %%
df.employer.value_counts()
# Out:
# Другие                        5126
# Ростелеком                     370
# Калашников                     120
# Первый Бит                     117
# МАГНИТ, Розничная сеть         100
#                               ...
# ГРАНТ-СИСТЕМЫ И ТЕХНОЛОГИИ       2
# Домкомплект                      2
# Hant                             2
# МПК Петровские деликатесы        2
# АСЦ-Климат                       2
# Name: employer, Length: 6197, dtype: int64

# %% [markdown]
# ## Тест

# %% [markdown]
# Лишь около 1% вакансий требуют прохождение тестового задания для отклика на вакансию, эта переменная очень не сбалансирована

# %%
df.has_test.value_counts()
# Out:
# False    30316
# True       323
# Name: has_test, dtype: int64

# %%
df.has_test = df.has_test.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.has_test.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость прохождения тестового задания', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ## Опыт работы

# %% [markdown]
# Требования к опыту работы несбалансированы

# %%
df.experience.value_counts()
# Out:
# 1    17462
# 2     8140
# 0     4353
# 3      684
# Name: experience, dtype: int64

# %%
experience_map = {'Нет опыта': 0, 'От 1 года до 3 лет' : 1, 'От 3 до 6 лет': 2, 'Более 6 лет': 3}

# %%
df.experience = df.experience.map(experience_map)

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.experience.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Опыт работы', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1', '2', '3']
labels = experience_map.keys()

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()
